# %% [markdown]
# ## Findings
#     -> We can see different heat map for differnt test data, while most of them have different error rate.
#     -> We can see that the heat map would be different consideing the fact that, error rate is different.
#     -> We would probbaly generate different heat map, for different range of errors.

# %% [markdown]
# ## Research path -
#     -> Ways to improve the model performace using/through/by XAI
# ## Tasks -
#     -> Generate Attention Map
#     -> Do perturbation analysis/ add or remove data points/ Use any classification technique to improve model performance
#     -> Use some other technique using XAI and compare the results
#     -> Propose some novel technique
#     -> Create seperate model for different cities

# %% [markdown]
# ## Writing suggession
#     -> Have to write why, demand forecasting is important
#     -> The money issue, And what we are tring to achieve from the thesis

# %% [markdown]
# # Improvements suggested -
#     -> Add window feature
#     -> Add lag feature from previous week same day
#     -> Add skill score
#     -> Use absolute error for test data
#     -> Use baseline forescast to evaluate the model

# %%
# %reload_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '../helper/')

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from scipy import stats
import data as data_helper
import model as model_helper
import config
import localStorage
# Out:
# Choosen device cuda

# %% [markdown]
# ## Global Variables

# %%
city_name = "helsingfors"
summery = { city_name: {} }

# %% [markdown]
# ## Load the data

# %%
train = data_helper.load_train_data(city_name)

# %%
train = data_helper.filter_train_data(train)

# %%
train.head()
# Out:
#                            place  temperature  demand
# time
# 2022-07-15 00:00:00  helsingfors         15.3     0.0
# 2022-07-15 01:00:00  helsingfors         14.8     0.0
# 2022-07-15 02:00:00  helsingfors         14.9     0.0
# 2022-07-15 03:00:00  helsingfors         14.3     0.0
# 2022-07-15 04:00:00  helsingfors         14.6     0.0

# %% [markdown]
# # Data analysis

# %%
data_helper.show_density_plot(train)

# %%
train.isna().sum()
# Out:
# place          0
# temperature    0
# demand         0
# dtype: int64

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# - Time Feature Extraction\
#   -> Year\
#   -> month_cos\
#   -> month_sin\
#   -> day_cos\
#   -> day_sin\
#   -> hour_cos\
#   -> hour_sin\
#   -> Public holiday or not\
#   -> Daylight savings or not\
#   -> Weekend or not\
#   -> Business hour or not\
#   -> Season of the year

# %%
train_1 = data_helper.add_feature(train)

# %%
train_1.head()
# Out:
#                            place  temperature  demand  month_sin  month_cos  \
# time
# 2022-07-15 00:00:00  helsingfors         15.3     0.0       -0.5  -0.866025
# 2022-07-15 01:00:00  helsingfors         14.8     0.0       -0.5  -0.866025
# 2022-07-15 02:00:00  helsingfors         14.9     0.0       -0.5  -0.866025
# 2022-07-15 03:00:00  helsingfors         14.3     0.0       -0.5  -0.866025
# 2022-07-15 04:00:00  helsingfors         14.6     0.0       -0.5  -0.866025
#
#                       day_sin   day_cos  hour_sin  hour_cos  business_hour  \
# time
# 2022-07-15 00:00:00 -0.230306 -0.973118  0.000000  1.000000              0
# 2022-07-15 01:00:00 -0.230306 -0.973118  0.269797  0.962917              0
# 2022-07-15 02:00:00 -0.230306 -0.973118  0.519584  0.854419              0
# 2022-07-15 03:00:00 -0.230306 -0.973118  0.730836  0.682553              0
# 2022-07-15 04:00:00 -0.230306 -0.973118  0.887885  0.460065              0
#
#                      season  weekend  daylight  holiday
# time
# 2022-07-15 00:00:00  summer        0         1        0
# 2022-07-15 01:00:00  summer        0         1        0
# 2022-07-15 02:00:00  summer        0         1        0
# 2022-07-15 03:00:00  summer        0         1        0
# 2022-07-15 04:00:00  summer        0         1        0

# %% [markdown]
# - One hot encode

# %%
train_2 = data_helper.one_hot_encoding(train_1, ['season'])

# %%
train_2.head()
# Out:
#                            place  temperature  demand  month_sin  month_cos  \
# time
# 2022-07-15 00:00:00  helsingfors         15.3     0.0       -0.5  -0.866025
# 2022-07-15 01:00:00  helsingfors         14.8     0.0       -0.5  -0.866025
# 2022-07-15 02:00:00  helsingfors         14.9     0.0       -0.5  -0.866025
# 2022-07-15 03:00:00  helsingfors         14.3     0.0       -0.5  -0.866025
# 2022-07-15 04:00:00  helsingfors         14.6     0.0       -0.5  -0.866025
#
#                       day_sin   day_cos  hour_sin  hour_cos  business_hour  \
# time
# 2022-07-15 00:00:00 -0.230306 -0.973118  0.000000  1.000000              0
# 2022-07-15 01:00:00 -0.230306 -0.973118  0.269797  0.962917              0
# 2022-07-15 02:00:00 -0.230306 -0.973118  0.519584  0.854419              0
# 2022-07-15 03:00:00 -0.230306 -0.973118  0.730836  0.682553              0
# 2022-07-15 04:00:00 -0.230306 -0.973118  0.887885  0.460065              0
#
#                      weekend  daylight  holiday  autumn  spring  summer
# time
# 2022-07-15 00:00:00        0         1        0       0       0       1
# 2022-07-15 01:00:00        0         1        0       0       0       1
# 2022-07-15 02:00:00        0         1        0       0       0       1
# 2022-07-15 03:00:00        0         1        0       0       0       1
# 2022-07-15 04:00:00        0         1        0       0       0       1

# %% [markdown]
# - Scale the data

# %%
x_scaler, y_scaler, train_3 = data_helper.scale(train_2)

# %%
train_3.head()
# Out:
#                      autumn  business_hour   day_cos   day_sin  daylight  \
# time
# 2022-07-15 00:00:00       0              0 -0.973118 -0.230306         1
# 2022-07-15 01:00:00       0              0 -0.973118 -0.230306         1
# 2022-07-15 02:00:00       0              0 -0.973118 -0.230306         1
# 2022-07-15 03:00:00       0              0 -0.973118 -0.230306         1
# 2022-07-15 04:00:00       0              0 -0.973118 -0.230306         1
#
#                      holiday  hour_cos  hour_sin  month_cos  month_sin  \
# time
# 2022-07-15 00:00:00        0  1.000000  0.000000  -0.866025       -0.5
# 2022-07-15 01:00:00        0  0.962917  0.269797  -0.866025       -0.5
# 2022-07-15 02:00:00        0  0.854419  0.519584  -0.866025       -0.5
# 2022-07-15 03:00:00        0  0.682553  0.730836  -0.866025       -0.5
# 2022-07-15 04:00:00        0  0.460065  0.887885  -0.866025       -0.5
#
#                            place  spring  summer  weekend  temperature  demand
# time
# 2022-07-15 00:00:00  helsingfors       0       1        0     0.489736    -1.0
# 2022-07-15 01:00:00  helsingfors       0       1        0     0.460411    -1.0
# 2022-07-15 02:00:00  helsingfors       0       1        0     0.466276    -1.0
# 2022-07-15 03:00:00  helsingfors       0       1        0     0.431085    -1.0
# 2022-07-15 04:00:00  helsingfors       0       1        0     0.448680    -1.0

# %% [markdown]
# - Rearrange the columns

# %%
train_4 = train_3[config.COLUMN_NAMES]

# %%
train_4.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-07-15 00:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 01:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 02:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 03:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 04:00:00       0       1       0       -0.5  -0.866025 -0.230306
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-07-15 00:00:00 -0.973118  0.000000  1.000000              0        0
# 2022-07-15 01:00:00 -0.973118  0.269797  0.962917              0        0
# 2022-07-15 02:00:00 -0.973118  0.519584  0.854419              0        0
# 2022-07-15 03:00:00 -0.973118  0.730836  0.682553              0        0
# 2022-07-15 04:00:00 -0.973118  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature  demand
# time
# 2022-07-15 00:00:00         1        0     0.489736    -1.0
# 2022-07-15 01:00:00         1        0     0.460411    -1.0
# 2022-07-15 02:00:00         1        0     0.466276    -1.0
# 2022-07-15 03:00:00         1        0     0.431085    -1.0
# 2022-07-15 04:00:00         1        0     0.448680    -1.0

# %% [markdown]
# - Lag feature

# %%
train_5 = data_helper.add_lag(train_4, 1)

# %%
train_5.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-07-15 00:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 01:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 02:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 03:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 04:00:00       0       1       0       -0.5  -0.866025 -0.230306
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-07-15 00:00:00 -0.973118  0.000000  1.000000              0        0
# 2022-07-15 01:00:00 -0.973118  0.269797  0.962917              0        0
# 2022-07-15 02:00:00 -0.973118  0.519584  0.854419              0        0
# 2022-07-15 03:00:00 -0.973118  0.730836  0.682553              0        0
# 2022-07-15 04:00:00 -0.973118  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature  demand-1  demand
# time
# 2022-07-15 00:00:00         1        0     0.489736       0.0    -1.0
# 2022-07-15 01:00:00         1        0     0.460411      -1.0    -1.0
# 2022-07-15 02:00:00         1        0     0.466276      -1.0    -1.0
# 2022-07-15 03:00:00         1        0     0.431085      -1.0    -1.0
# 2022-07-15 04:00:00         1        0     0.448680      -1.0    -1.0

# %% [markdown]
# - Baseline feature

# %%
train_6 = data_helper.add_baseline_feature(train_5)

# %%
train_6.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-07-15 00:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 01:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 02:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 03:00:00       0       1       0       -0.5  -0.866025 -0.230306
# 2022-07-15 04:00:00       0       1       0       -0.5  -0.866025 -0.230306
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-07-15 00:00:00 -0.973118  0.000000  1.000000              0        0
# 2022-07-15 01:00:00 -0.973118  0.269797  0.962917              0        0
# 2022-07-15 02:00:00 -0.973118  0.519584  0.854419              0        0
# 2022-07-15 03:00:00 -0.973118  0.730836  0.682553              0        0
# 2022-07-15 04:00:00 -0.973118  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature  base_line_demand  \
# time
# 2022-07-15 00:00:00         1        0     0.489736              -1.0
# 2022-07-15 01:00:00         1        0     0.460411              -1.0
# 2022-07-15 02:00:00         1        0     0.466276              -1.0
# 2022-07-15 03:00:00         1        0     0.431085              -1.0
# 2022-07-15 04:00:00         1        0     0.448680              -1.0
#
#                      demand-1  demand
# time
# 2022-07-15 00:00:00       0.0    -1.0
# 2022-07-15 01:00:00      -1.0    -1.0
# 2022-07-15 02:00:00      -1.0    -1.0
# 2022-07-15 03:00:00      -1.0    -1.0
# 2022-07-15 04:00:00      -1.0    -1.0

# %% [markdown]
# - Split the final data for Base-line model

# %%
train_split_base_X = train_6.iloc[:, :-1]
train_split_base_Y = train_6.iloc[:, -1]

# %%
X_train_base, X_test_base, Y_train_base, Y_test_base = train_test_split(train_split_base_X, train_split_base_Y, test_size=0.2, random_state=0)

# %% [markdown]
# - Create sequence

# %%
train_split_X, train_split_Y = data_helper.split_sequences(train_6, config.WINDOW_SIZE)

# %% [markdown]
# - Train test split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train_split_X, train_split_Y, test_size=0.2, random_state=0)

# %% [markdown]
# - Model preparation

# %%
model_helper.show_me()

# %%
PATH = f"./data/{city_name}_model_XAI"
model = model_helper.train_model(np.shape(X_train[0])[-1], X_train, Y_train, X_test, Y_test, False, config.BATCH_SIZE, config.NUM_EPOCHS, config.PRC_EPOCH, PATH, True)
# Out:
# the model  ./data/helsingfors_model_XAI has beed loaded !

# %% [markdown]
# - Test the performance

# %%
base_model_actual_value, base_model_predicted_value, base_model_RSME_score, base_model_R2_score, base_model_MAE_score, _, _ = model_helper.display_results(model, X_test, Y_test, y_scaler, (0, 6.8), (200, 400))
# print(actual), print(predicted)
# Comment about the result:: Capture variation but missing trend
# Out:
#   0%|          | 0/1220 [00:00<?, ?it/s]
# d:\Semester 4\XAI\../helper\model.py:316: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
#   seq = torch.FloatTensor([X[index]]).to(device=config.DEVICE)
# Rmse lsoss -> 0.6291938503237071
# Mean absolute error -> 0.33075210452079773
# R2 score -> 45.0

# %% [markdown]
# - Generate the explaination (global)

# %%
# compute global attention
meanAttn, meanScores = model_helper.generate_global_heatmap(model, X_test, "Global Heat Map")
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]

# %% [markdown]
# - How's the heatmap looks like, for good and bad predictions

# %%
good_pred, bad_pred = model_helper.split_good_bad_data(X_train, Y_train, model, y_scaler)
# Out:
#   0%|          | 0/4876 [00:00<?, ?it/s]

# %%
model_helper.generate_global_heatmap(model, good_pred, "Good Prediction Heat Map")
model_helper.generate_global_heatmap(model, bad_pred, "Bad Predictin Heat Map")
# Out:
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/147 [00:00<?, ?it/s]
# (array([[ 1.6578567e-09, -1.3386376e-08, -3.5237822e-09, ...,
#           2.1614190e-09,  3.9560355e-09,  1.0810958e-08],
#         [ 1.7833048e-09, -1.4464099e-08, -3.4274716e-09, ...,
#           2.6875600e-09,  3.7241465e-09,  1.0832979e-08],
#         [ 1.9263713e-09, -1.5058266e-08, -3.2948440e-09, ...,
#           2.9220504e-09,  3.7354302e-09,  1.0964100e-08],
#         ...,
#         [ 1.9199318e-09, -5.9929772e-09, -7.2405693e-10, ...,
#           2.1455457e-09,  1.4526608e-09,  4.7605262e-09],
#         [ 1.2932472e-09, -3.4173557e-09, -3.5549305e-10, ...,
#           1.4571057e-09,  7.7539158e-10,  2.8375324e-09],
#         [ 5.4228799e-10, -1.1925787e-09, -9.3758924e-11, ...,
#           6.5470912e-10,  2.4046568e-10,  1.0666525e-09]], dtype=float32),
#  array([[0.00610171],
#         [0.00605935],
#         [0.0060291 ],
#         [0.00600681],
#         [0.00599042],
#         [0.00597857],
#         [0.00597019],
#         [0.00596434],
#         [0.00596028],
#         [0.00595747],
#         [0.00595549],
#         [0.00595405],
#         [0.00595297],
#         [0.00595212],
#         [0.00595142],
#         [0.00595083],
#         [0.00595033],
#         [0.00594992],
#         [0.00594956],
#         [0.00594928],
#         [0.0059491 ],
#         [0.00594901],
#         [0.005949  ],
#         [0.00594906],
#         [0.00594917],
#         [0.00594934],
#         [0.00594957],
#         [0.00594983],
#         [0.00595008],
#         [0.00595033],
#         [0.00595055],
#         [0.00595072],
#         [0.00595085],
#         [0.00595091],
#         [0.00595091],
#         [0.00595082],
#         [0.00595068],
#         [0.00595047],
#         [0.00595022],
#         [0.00594994],
#         [0.00594966],
#         [0.00594938],
#         [0.00594913],
#         [0.00594892],
#         [0.00594878],
#         [0.00594872],
#         [0.00594871],
#         [0.00594878],
#         [0.00594891],
#         [0.00594909],
#         [0.00594932],
#         [0.00594958],
#         [0.00594985],
#         [0.00595009],
#         [0.0059503 ],
#         [0.00595048],
#         [0.0059506 ],
#         [0.00595065],
#         [0.00595064],
#         [0.00595055],
#         [0.00595038],
#         [0.00595016],
#         [0.00594989],
#         [0.0059496 ],
#         [0.00594931],
#         [0.00594901],
#         [0.00594877],
#         [0.00594854],
#         [0.0059484 ],
#         [0.00594833],
#         [0.00594832],
#         [0.00594839],
#         [0.00594852],
#         [0.0059487 ],
#         [0.00594892],
#         [0.00594917],
#         [0.00594944],
#         [0.00594968],
#         [0.0059499 ],
#         [0.00595008],
#         [0.00595019],
#         [0.00595024],
#         [0.00595024],
#         [0.00595015],
#         [0.00595   ],
#         [0.00594978],
#         [0.00594952],
#         [0.00594924],
#         [0.00594894],
#         [0.00594866],
#         [0.0059484 ],
#         [0.00594819],
#         [0.00594806],
#         [0.00594801],
#         [0.00594801],
#         [0.00594808],
#         [0.00594822],
#         [0.00594842],
#         [0.00594865],
#         [0.00594891],
#         [0.00594917],
#         [0.00594942],
#         [0.00594964],
#         [0.00594983],
#         [0.00594995],
#         [0.00595001],
#         [0.00595   ],
#         [0.00594991],
#         [0.00594975],
#         [0.00594954],
#         [0.00594927],
#         [0.00594898],
#         [0.00594869],
#         [0.00594841],
#         [0.00594815],
#         [0.00594795],
#         [0.00594782],
#         [0.00594774],
#         [0.00594773],
#         [0.00594781],
#         [0.00594793],
#         [0.00594811],
#         [0.00594834],
#         [0.0059486 ],
#         [0.00594888],
#         [0.00594911],
#         [0.00594934],
#         [0.00594953],
#         [0.00594964],
#         [0.0059497 ],
#         [0.00594969],
#         [0.00594961],
#         [0.00594945],
#         [0.00594926],
#         [0.00594901],
#         [0.00594873],
#         [0.00594846],
#         [0.00594819],
#         [0.00594794],
#         [0.00594776],
#         [0.00594762],
#         [0.00594755],
#         [0.00594755],
#         [0.00594762],
#         [0.00594776],
#         [0.00594795],
#         [0.00594818],
#         [0.00594843],
#         [0.00594869],
#         [0.00594895],
#         [0.00594916],
#         [0.00594934],
#         [0.00594946],
#         [0.00594952],
#         [0.00594949],
#         [0.0059494 ],
#         [0.00594925],
#         [0.00594903],
#         [0.00594877],
#         [0.00594848],
#         [0.00594818],
#         [0.00594792],
#         [0.00594766],
#         [0.00594746],
#         [0.00594733],
#         [0.00594725],
#         [0.00594726],
#         [0.00594734]], dtype=float32))

# %% [markdown]
# - Generate the explaination (Local)

# %%
heat_index = 1
res = model_helper.disp_grads_rk(model_helper.compute_grads(None, model, X_test[heat_index]))
print(f"Actual result -> {Y_test[heat_index]} && Predicted result -> {res}")
print(f"Error - {np.mean(np.abs(Y_test[heat_index] - res))}")
# Out:
# Actual result -> 0.5486005089058525 && Predicted result -> 0.5845668911933899
# Error - 0.035966382287537346

# %% [markdown]
# - Partial dependency plt, to manipulate the data

# %%
X, y = train_6.iloc[:, :-1], np.reshape(y_scaler.inverse_transform(np.reshape(train_6.iloc[:, -1].to_numpy(), (-1, 1))), (-1))

# %%
# polyreg = model_helper.train_plyrg_model(4, X, y)

# %%
# model_helper.generate_feature_graph(polyreg, X, 3, int(len(X.columns)/3), X.columns[:-1])

# %% [markdown]
# - Perturbation analysis or replace less important data with random noise, K-nearest neighbor, Augmented data

# %% [markdown]
# - Random noise

# %%
# Add random noise based on the heatmap
light_blue = (0.00594, 0.00596)
dark_red = (0.00597, )
X_train_with_noise = data_helper.add_random_noise(X_train, light_blue, dark_red, model)

# %%
# Retrain the model with the new data
PATH_NOISE = f"./data/{city_name}_model_XAI_Noise"
model_noise = model_helper.train_model(np.shape(X_train[0])[-1], X_train_with_noise, Y_train, X_test, Y_test, False, config.BATCH_SIZE, 6, config.PRC_EPOCH, PATH_NOISE, True)
# Out:
# the model  ./data/helsingfors_model_XAI_Noise has beed loaded !

# %%
# Check the performance
noise_model_actual_value, noise_model_predicted_value, noise_model_RSME_score, noise_model_R2_score, noise_model_MAE_score, _, _ = model_helper.display_results(model_noise, X_test, Y_test, y_scaler, (4, 7), [200, 400])
print(noise_model_actual_value), print(noise_model_predicted_value)
# Out:
#   0%|          | 0/1220 [00:00<?, ?it/s]
# Rmse lsoss -> 0.617213188312815
# Mean absolute error -> 0.2822631001472473
# R2 score -> 57.99999999999999
# [4.992, 6.0859995, 6.7070003, 6.5239997, 4.928, 6.2130003, 6.435, 5.7339997, 6.527, 6.397, 6.52, 6.443, 6.471, 6.5099998, 6.2669997, 6.2970004, 6.0859995, 6.409, 6.319, 6.4550004, 6.425, 5.178, 6.543, 5.008, 6.312, 6.374, 6.599, 5.6959996, 5.16, 6.412, 6.435, 5.152, 6.229, 6.5559998, 6.301, 6.42, 6.1870003, 6.401, 6.39, 6.2079997, 6.401, 5.008, 6.3349996, 6.4969997, 6.417, 6.591, 2.506, 6.3519998, 6.2860003, 6.279, 6.349, 6.31, 6.301, 6.235, 6.4339995, 2.5180001, 6.407, 6.2970004, 6.242, 6.5350003, 5.116, 6.2070003, 6.5249996, 6.4950004, 6.3710003, 6.3170004, 6.415, 6.9909997, 6.211, 6.4769998, 4.9490004, 6.253, 6.4649997, 5.795, 6.486, 6.644, 6.539, 6.4179997, 5.857, 6.4080005, 6.243, 6.16, 6.7400002, 6.4240003, 6.3680005, 6.48, 6.514, 6.454, 6.4360003, 6.538, 5.9119997, 6.5690002, 6.302, 6.283, 6.528, 6.4160004, 6.351, 6.3170004, 6.294, 6.5, 6.293, 6.358, 6.5940003, 6.333, 6.701, 6.283, 5.2239995, 6.2180004, 6.348, 7.046, 6.31, 6.502, 4.9300003, 6.545, 5.423, 6.389, 6.98, 4.963, 6.377, 6.293, 5.816, 6.468, 6.219, 6.974, 6.44, 6.272, 6.163, 6.5490003, 6.227, 6.5169997, 6.29, 5.701, 5.709, 6.3939996, 6.46, 5.158, 6.277, 6.243, 6.409, 6.3450003, 6.3469996, 6.887, 6.4179997, 6.3589997, 4.963, 6.71, 6.2479997, 6.263, 6.412, 6.489, 6.409, 5.19, 6.422, 6.685, 6.3859997, 6.225, 6.255, 5.7520003, 5.1940002, 6.727, 6.308, 6.321, 6.601, 6.71, 5.626, 6.501, 6.252, 6.4259996, 6.372, 6.329, 6.171, 4.934, 6.449, 6.46, 6.6159997, 6.433, 5.039, 6.271, 6.311, 6.39, 6.469, 6.249, 6.324, 6.298, 6.494, 5.748, 5.779, 6.827, 6.514, 5.78, 5.017, 6.235, 6.1190004, 6.2580004, 6.399, 6.501, 6.1310005, 5.2400002, 6.43, 4.992, 6.719, 6.2460003, 6.272, 6.199, 6.5439997, 6.698, 6.773, 6.4969997, 6.336, 5.1819997, 6.43, 6.462, 6.214, 7.105, 5.66, 6.2159996, 6.2260003, 4.9669995, 6.595, 5.236, 6.541, 6.451, 6.5620003, 6.344, 6.25, 6.468, 6.299, 6.2359996, 6.429, 6.2669997, 6.241, 6.296, 6.668, 6.5169997, 5.118, 6.678, 6.504, 6.3389997, 6.565, 6.336, 6.486, 6.2970004, 6.382, 6.521, 6.402, 4.993, 6.5, 6.273, 6.3459997, 6.1819997, 6.577, 6.251, 6.4309998, 6.565, 6.3570004, 6.496, 6.399, 6.4649997, 6.598, 6.447, 6.358, 6.38, 6.3960004, 6.541, 6.4929996, 5.49, 5.802, 5.6619997, 6.2920003, 6.45, 6.15, 6.2850003, 6.3659997, 6.33, 6.933, 5.8900003, 6.4, 2.548, 6.458, 6.379, 6.351, 2.517, 6.617, 6.453, 6.249, 6.312, 6.422, 6.1470003, 6.293, 6.284, 6.728, 6.7120004, 5.812, 6.251, 6.378, 6.244, 6.4309998, 6.509, 6.054, 6.3960004, 6.405, 6.3589997, 6.199, 6.41, 5.754, 6.28, 5.0969996, 6.398, 6.547, 6.3659997, 6.36, 6.5239997, 6.38, 6.528, 6.293, 6.385, 6.1369996, 4.879, 6.427, 6.265, 4.996, 5.136, 6.095, 6.31, 5.2079997, 6.4309998, 6.392, 6.397, 6.35, 6.466, 6.2759995, 5.676, 2.5080001, 6.3589997, 6.575, 6.539, 6.409, 6.334, 6.565, 6.788, 6.5030003, 5.881, 6.509, 6.457, 5.686, 5.716, 6.328, 5.021, 4.801, 6.362, 6.314, 6.234, 6.481, 6.532, 6.561, 6.451, 6.867, 6.458, 6.316, 6.802, 6.5639997, 6.2159996, 5.124, 7.014, 5.3680005, 5.769, 6.353, 6.392, 6.421, 6.401, 6.553, 6.5719995, 6.421, 6.585, 6.4449997, 6.622, 4.9839997, 6.35, 6.354, 6.288, 2.556, 6.1849995, 5.748, 6.458, 6.468, 6.5099998, 6.158, 5.2, 6.2469997, 5.035, 6.3370004, 6.4630003, 6.4059997, 6.249, 6.5249996, 5.19, 6.5230002, 6.025, 6.405, 6.312, 6.557, 6.375, 6.34, 6.4040003, 5.008, 6.3549995, 6.398, 6.409, 5.235, 6.502, 6.31, 6.489, 6.76, 5.202, 6.4360003, 6.3519998, 6.423, 6.411, 6.42, 6.443, 6.295, 5.731, 6.6650004, 5.834, 6.249, 6.547, 6.449, 5.8259997, 6.28, 6.551, 5.849, 6.425, 6.482, 6.451, 6.639, 6.4, 5.5969996, 6.252, 5.0039997, 6.4179997, 5.849, 6.949, 6.452, 6.385, 5.098, 6.2679996, 5.731, 5.256, 6.466, 6.428, 6.541, 6.5439997, 6.377, 6.527, 6.3250003, 5.1419997, 6.1080003, 5.729, 6.547, 6.8900003, 6.372, 6.356, 6.1689997, 5.771, 6.9509997, 6.543, 5.2409997, 6.708, 6.7200003, 6.827, 6.4309998, 5.757, 5.81, 6.19, 5.461, 6.473, 6.4240003, 6.322, 6.421, 6.4630003, 6.452, 5.207, 6.249, 6.395, 5.207, 6.4139996, 6.331, 6.735, 6.3, 6.291, 6.794, 6.2869997, 6.403, 6.1849995, 6.259, 6.511, 6.353, 6.904, 6.5 ...
# [4.        4.905548  5.727295  ... 6.401184  6.2671967 6.660263 ]
# (None, None)

# %% [markdown]
# ## Analysis from the PDP -
#     -> OSLO is the only city that consume a tons of electricy compare to the other ctities
#     -> All the other cities might have a normal electricity demand
#     -> It, would be a good experiment, to see, if the deduct Bergen data from the training data set, it might overall improve the model performance
#     -> From the month graph - it seems like, at the end of the year (11, 12), consumption really spikes
#     -> From the day graph - it seems like, on the day (3,4) the consumption spikes
#     -> From the daylight graph - it seems like, if the daylight increase, consumption decrease
#     -> From the holiday graph - it seems like, during the hoiliday consumption increase
#     -> And, all the other feature, doesnt have that much deviative impact

# %% [markdown]
# ## The whole hypothesis, is based on our specific model perforrmance, we we can call it model(technique) dependent
#     -> As we can see from the model performace that, its under performing for some prediction, that is preety low compare to the average demand

# %% [markdown]
# - Try to adjust the training data with all the others finding and see if that improves the performance
# - The hypothesis is that, from the prediction graph, we can see that, mostly our model is not performing well when the consumption is going down
# - For all the spikes, the model is performing well, to solve the problem we could use different hypothesis, we could add some penalize terms to the model for lower consumption mitchmatch
# - Or we could modify some traing data and convert some somple to more lower degree and see how the model perform, Or add some bias(lower consumption example) to the trainign data and see how the model perform.

# %% [markdown]
# # Lets try the data modification

# %%
train_low_demand = data_helper.adjust_train_data(train_6)

# %%
train_low_demand_split_X, train_low_demand_split_Y = data_helper.split_sequences(train_low_demand, config.WINDOW_SIZE)
X_train_low_demand, X_test_low_demand, Y_train_low_demand, Y_test_low_demand = train_test_split(train_low_demand_split_X, train_low_demand_split_Y, test_size=0.2, random_state=0)

# %%
# Retrain the model with the new data
PATH_LOW_DEMAND = f"./data/{city_name}_model_XAI_low_demand"
model_low_demand = model_helper.train_model(np.shape(X_train[0])[-1], X_train_low_demand, Y_train_low_demand, X_test_low_demand,
                               Y_test_low_demand, False, config.BATCH_SIZE, 10, config.PRC_EPOCH, PATH_LOW_DEMAND, True)
# Out:
# the model  ./data/helsingfors_model_XAI_low_demand has beed loaded !

# %%
# Check the performance
low_demand_model_actual_value, low_demand_model_predicted_value, low_demand_model_RSME_score, low_demand_model_R2_score, low_demand_model_MAE_score, _, _ = model_helper.display_results(
    model_low_demand, X_test_low_demand, Y_test_low_demand, y_scaler, (2, 7.2), (400, 700))
print(low_demand_model_actual_value), print(low_demand_model_predicted_value)
# Out:
#   0%|          | 0/1220 [00:00<?, ?it/s]
# Rmse lsoss -> 0.6252827004991567
# Mean absolute error -> 0.3005967438220978
# R2 score -> 56.99999999999999
# [4.992, 6.0859995, 6.7070003, 6.5239997, 4.928, 6.2130003, 6.435, 5.7339997, 6.527, 6.397, 6.52, 6.443, 6.471, 6.5099998, 6.2669997, 6.2970004, 6.0859995, 6.409, 6.319, 6.4550004, 6.425, 5.178, 6.543, 5.008, 6.312, 6.374, 6.599, 5.6959996, 5.16, 6.412, 6.435, 5.152, 6.229, 6.5559998, 6.301, 6.42, 6.1870003, 6.401, 6.39, 6.2079997, 6.401, 5.008, 6.3349996, 6.4969997, 6.417, 6.591, 2.506, 6.3519998, 6.2860003, 6.279, 6.349, 6.31, 6.301, 6.235, 6.4339995, 2.5180001, 6.407, 6.2970004, 6.242, 6.5350003, 5.116, 6.2070003, 6.5249996, 6.4950004, 6.3710003, 6.3170004, 6.415, 6.9909997, 6.211, 6.4769998, 4.9490004, 6.253, 6.4649997, 5.795, 6.486, 6.644, 6.539, 6.4179997, 5.857, 6.4080005, 6.243, 6.16, 6.7400002, 6.4240003, 6.3680005, 6.48, 6.514, 6.454, 6.4360003, 6.538, 5.9119997, 6.5690002, 6.302, 6.283, 6.528, 6.4160004, 6.351, 6.3170004, 6.294, 6.5, 6.293, 6.358, 6.5940003, 6.333, 6.701, 6.283, 5.2239995, 6.2180004, 6.348, 7.046, 6.31, 6.502, 4.9300003, 6.545, 5.423, 6.389, 6.98, 4.963, 6.377, 6.293, 5.816, 6.468, 6.219, 6.974, 6.44, 6.272, 6.163, 6.5490003, 6.227, 6.5169997, 6.29, 5.701, 5.709, 6.3939996, 6.46, 5.158, 6.277, 6.243, 6.409, 6.3450003, 6.3469996, 6.887, 6.4179997, 6.3589997, 4.963, 6.71, 6.2479997, 6.263, 6.412, 6.489, 6.409, 5.19, 6.422, 6.685, 6.3859997, 6.225, 6.255, 5.7520003, 5.1940002, 6.727, 6.308, 6.321, 6.601, 6.71, 5.626, 6.501, 6.252, 6.4259996, 6.372, 6.329, 6.171, 4.934, 6.449, 6.46, 6.6159997, 6.433, 5.039, 6.271, 6.311, 6.39, 6.469, 6.249, 6.324, 6.298, 6.494, 5.748, 5.779, 6.827, 6.514, 5.78, 5.017, 6.235, 6.1190004, 6.2580004, 6.399, 6.501, 6.1310005, 5.2400002, 6.43, 4.992, 6.719, 6.2460003, 6.272, 6.199, 6.5439997, 6.698, 6.773, 6.4969997, 6.336, 5.1819997, 6.43, 6.462, 6.214, 7.105, 5.66, 6.2159996, 6.2260003, 4.9669995, 6.595, 5.236, 6.541, 6.451, 6.5620003, 6.344, 6.25, 6.468, 6.299, 6.2359996, 6.429, 6.2669997, 6.241, 6.296, 6.668, 6.5169997, 5.118, 6.678, 6.504, 6.3389997, 6.565, 6.336, 6.486, 6.2970004, 6.382, 6.521, 6.402, 4.993, 6.5, 6.273, 6.3459997, 6.1819997, 6.577, 6.251, 6.4309998, 6.565, 6.3570004, 6.496, 6.399, 6.4649997, 6.598, 6.447, 6.358, 6.38, 6.3960004, 6.541, 6.4929996, 5.49, 5.802, 5.6619997, 6.2920003, 6.45, 6.15, 6.2850003, 6.3659997, 6.33, 6.933, 5.8900003, 6.4, 2.548, 6.458, 6.379, 6.351, 2.517, 6.617, 6.453, 6.249, 6.312, 6.422, 6.1470003, 6.293, 6.284, 6.728, 6.7120004, 5.812, 6.251, 6.378, 6.244, 6.4309998, 6.509, 6.054, 6.3960004, 6.405, 6.3589997, 6.199, 6.41, 5.754, 6.28, 5.0969996, 6.398, 6.547, 6.3659997, 6.36, 6.5239997, 6.38, 6.528, 6.293, 6.385, 6.1369996, 4.879, 6.427, 6.265, 4.996, 5.136, 6.095, 6.31, 5.2079997, 6.4309998, 6.392, 6.397, 6.35, 6.466, 6.2759995, 5.676, 2.5080001, 6.3589997, 6.575, 6.539, 6.409, 6.334, 6.565, 6.788, 6.5030003, 5.881, 6.509, 6.457, 5.686, 5.716, 6.328, 5.021, 4.801, 6.362, 6.314, 6.234, 6.481, 6.532, 6.561, 6.451, 6.867, 6.458, 6.316, 6.802, 6.5639997, 6.2159996, 5.124, 7.014, 5.3680005, 5.769, 6.353, 6.392, 6.421, 6.401, 6.553, 6.5719995, 6.421, 6.585, 6.4449997, 6.622, 4.9839997, 6.35, 6.354, 6.288, 2.556, 6.1849995, 5.748, 6.458, 6.468, 6.5099998, 6.158, 5.2, 6.2469997, 5.035, 6.3370004, 6.4630003, 6.4059997, 6.249, 6.5249996, 5.19, 6.5230002, 6.025, 6.405, 6.312, 6.557, 6.375, 6.34, 6.4040003, 5.008, 6.3549995, 6.398, 6.409, 5.235, 6.502, 6.31, 6.489, 6.76, 5.202, 6.4360003, 6.3519998, 6.423, 6.411, 6.42, 6.443, 6.295, 5.731, 6.6650004, 5.834, 6.249, 6.547, 6.449, 5.8259997, 6.28, 6.551, 5.849, 6.425, 6.482, 6.451, 6.639, 6.4, 5.5969996, 6.252, 5.0039997, 6.4179997, 5.849, 6.949, 6.452, 6.385, 5.098, 6.2679996, 5.731, 5.256, 6.466, 6.428, 6.541, 6.5439997, 6.377, 6.527, 6.3250003, 5.1419997, 6.1080003, 5.729, 6.547, 6.8900003, 6.372, 6.356, 6.1689997, 5.771, 6.9509997, 6.543, 5.2409997, 6.708, 6.7200003, 6.827, 6.4309998, 5.757, 5.81, 6.19, 5.461, 6.473, 6.4240003, 6.322, 6.421, 6.4630003, 6.452, 5.207, 6.249, 6.395, 5.207, 6.4139996, 6.331, 6.735, 6.3, 6.291, 6.794, 6.2869997, 6.403, 6.1849995, 6.259, 6.511, 6.353, 6.904, 6.5 ...
# [2.        4.8236694 5.550873  ... 6.5671387 6.5108337 6.569763 ]
# (None, None)

# %% [markdown]
# ## Base-line model
#
#     -> https://machinelearningmastery.com/persistence-time-series-forecasting-with-python/
#
# ## Skill score
#
# You are told that your skill score for temperature forecasts last month was +0.25 (25%). The standard forecast used for comparison was in error by 2 degrees on average. This means:
#
#     -> Your error is 0.25 degrees smaller than the standard score.
#     -> The error of your forecasts is 2.5 degrees.
#     -> The error of your forecasts is 1.5 degrees.

# %%
base_line_model_predicted_value, base_line_model_actual_value = model_helper.model_base_line(X_test_base, Y_test_base, y_scaler)
base_line_model_MAE_score = np.mean(np.abs(np.subtract(base_line_model_actual_value, base_line_model_predicted_value)))
print(f"Base model MAE - {base_line_model_MAE_score}")
# Out:
# Base model MAE - 0.6897765363128492

# %% [markdown]
#  * Base model skill

# %%
base_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, base_model_predicted_value, base_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.6087465500689325

# %% [markdown]
#  * Noise model skill

# %%
noise_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, noise_model_predicted_value, noise_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.690962442679196

# %% [markdown]
#  * Low-demnad model skill

# %%
low_demand_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, low_demand_model_predicted_value, low_demand_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.6598766965600502

# %% [markdown]
# ## Cross validation

# %%
matrix_cv_base = model_helper.cross_validation(X_train, Y_train, 10, y_scaler, (0, 6.8))
matrix_cv_noise = model_helper.cross_validation(X_train_with_noise, Y_train, 10, y_scaler, (4, 7))
matrix_cv_low_demand = model_helper.cross_validation(X_train_low_demand, Y_train_low_demand, 10, y_scaler, (2, 7.2))
# Out:
# Training...
# Train_loss 0.35466476, Test loss : 0.25164655, Epoch 1
# Train_loss 0.19939567, Test loss : 0.20363905, Epoch 2
# Train_loss 0.17161528, Test loss : 0.20368356, Epoch 3
# Train_loss 0.17075302, Test loss : 0.20452035, Epoch 4
# Train_loss 0.17287099, Test loss : 0.20326964, Epoch 5
# Train_loss 0.16794210, Test loss : 0.20280430, Epoch 6
# Train_loss 0.16791194, Test loss : 0.20214238, Epoch 7
# Train_loss 0.16768246, Test loss : 0.20204344, Epoch 8
# Train_loss 0.16762361, Test loss : 0.20207218, Epoch 9
# Train_loss 0.16779646, Test loss : 0.20205214, Epoch 10
# Rmse lsoss -> 0.792949244066683
# Mean absolute error -> 1.8415178060531616
# R2 score -> -810.0
# Training...
# Train_loss 0.33141903, Test loss : 0.13839645, Epoch 1
# Train_loss 0.15868607, Test loss : 0.10874756, Epoch 2
# Train_loss 0.14726221, Test loss : 0.10946112, Epoch 3
# Train_loss 0.14675960, Test loss : 0.10979130, Epoch 4
# Train_loss 0.14636343, Test loss : 0.11007951, Epoch 5
# Train_loss 0.14572913, Test loss : 0.11016713, Epoch 6
# Train_loss 0.14591482, Test loss : 0.11015709, Epoch 7
# Train_loss 0.14571376, Test loss : 0.11017056, Epoch 8
# Train_loss 0.14582013, Test loss : 0.11009225, Epoch 9
# Train_loss 0.14569604, Test loss : 0.11009292, Epoch 10
# Rmse lsoss -> 0.4344989160759052
# Mean absolute error -> 2.1971099376678467
# R2 score -> -3144.0
# Training...
# Train_loss 0.33757445, Test loss : 0.21520801, Epoch 1
# Train_loss 0.14426420, Test loss : 0.17643851, Epoch 2
# Train_loss 0.13095559, Test loss : 0.17630136, Epoch 3
# Train_loss 0.13026833, Test loss : 0.17612849, Epoch 4
# Train_loss 0.13045984, Test loss : 0.17543264, Epoch 5
# Train_loss 0.12992594, Test loss : 0.17518613, Epoch 6
# Train_loss 0.12994545, Test loss : 0.17533648, Epoch 7
# Train_loss 0.12991525, Test loss : 0.17529238, Epoch 8
# Train_loss 0.12998153, Test loss : 0.17516090, Epoch 9
# Train_loss 0.12982102, Test loss : 0.17516886, Epoch 10
# Rmse lsoss -> 0.6895985652551307
# Mean absolute error -> 4.339380264282227
# R2 score -> -4312.0
# Training...
# Train_loss 0.34008469, Test loss : 0.22586647, Epoch 1
# Train_loss 0.17491354, Test loss : 0.18337937, Epoch 2
# Train_loss 0.16463911, Test loss : 0.18366915, Epoch 3
# Train_loss 0.16490930, Test loss : 0.18460466, Epoch 4
# Train_loss 0.16564435, Test loss : 0.18480489, Epoch 5
# Train_loss 0.16418306, Test loss : 0.18556691, Epoch 6
# Train_loss 0.16352398, Test loss : 0.18653587, Epoch 7
# Train_loss 0.16372495, Test loss : 0.18638714, Epoch 8
# Train_loss 0.16378297, Test loss : 0.18632857, Epoch 9
# Train_loss 0.16362083, Test loss : 0.18634064, Epoch 10
# Rmse lsoss -> 0.7333248015109733
# Mean absolute error -> 3.802082061767578
# R2 score -> -2728.0
# Training...
# Train_loss 0.42705825, Test loss : 0.11179549, Epoch 1
# Train_loss 0.18078909, Test loss : 0.13327082, Epoch 2
# Train_loss 0.16932340, Test loss : 0.11918177, Epoch 3
# Train_loss 0.16755369, Test loss : 0.11414240, Epoch 4
# Train_loss 0.16688991, Test loss : 0.11472366, Epoch 5
# Train_loss 0.16651199, Test loss : 0.11172305, Epoch 6
# Train_loss 0.16588861, Test loss : 0.11040612, Epoch 7
# Train_loss 0.16582878, Test loss : 0.11052119, Epoch 8
# Train_loss 0.16597727, Test loss : 0.11042250, Epoch 9
# Train_loss 0.16589785, Test loss : 0.11032850, Epoch 10
# Rmse lsoss -> 0.43586898661831186
# Mean absolute error -> 3.5927629470825195
# R2 score -> -8386.0
# Training...
# Train_loss 0.41609836, Test loss : 0.15289547, Epoch 1
# Train_loss 0.16675374, Test loss : 0.16073003, Epoch 2
# Train_loss 0.15768362, Test loss : 0.15682641, Epoch 3
# Train_loss 0.15747132, Test loss : 0.15560101, Epoch 4
# Train_loss 0.15691368, Test loss : 0.15544246, Epoch 5
# Train_loss 0.15454987, Test loss : 0.15519636, Epoch 6
# Train_loss 0.15405926, Test loss : 0.15537904, Epoch 7
# Train_loss 0.15386046, Test loss : 0.15534035, Epoch 8
# Train_loss 0.15385921, Test loss : 0.15531699, Epoch 9
# Train_loss 0.15376871, Test loss : 0.15534203, Epoch 10
# Rmse lsoss -> 0.6097122872855549
# Mean absolute error -> 2.544934034347534
# R2 score -> -1973.0
# Training...
# Train_loss 0.34619589, Test loss : 0.10457327, Epoch 1
# Train_loss 0.17252039, Test loss : 0.10821401, Epoch 2
# Train_loss 0.15472896, Test loss : 0.09228191, Epoch 3
# Train_loss 0.15427507, Test loss : 0.09117401, Epoch 4
# Train_loss 0.15503435, Test loss : 0.09171205, Epoch 5
# Train_loss 0.15218204, Test loss : 0.09187068, Epoch 6
# Train_loss 0.15208418, Test loss : 0.09259123, Epoch 7
# Train_loss 0.15205494, Test loss : 0.09281238, Epoch 8
# Train_loss 0.15207709, Test loss : 0.09273526, Epoch 9
# Train_loss 0.15205088, Test loss : 0.09270534, Epoch 10
# Rmse lsoss -> 0.36783581172864077
# Mean absolute error -> 3.1379733085632324
# R2 score -> -8092.0
# Training...
# Train_loss 0.40612406, Test loss : 0.20082119, Epoch 1
# Train_loss 0.16200634, Test loss : 0.18158567, Epoch 2
# Train_loss 0.15208462, Test loss : 0.18184868, Epoch 3
# Train_loss 0.15502118, Test loss : 0.18291962, Epoch 4
# Train_loss 0.15530540, Test loss : 0.18293778, Epoch 5
# Train_loss 0.15089708, Test loss : 0.18397931, Epoch 6
# Train_loss 0.15021707, Test loss : 0.18559053, Epoch 7
# Train_loss 0.15023737, Test loss : 0.18550550, Epoch 8
# Train_loss 0.15008144, Test loss : 0.18542051, Epoch 9
# Train_loss 0.15013004, Test loss : 0.18519828, Epoch 10
# Rmse lsoss -> 0.7317843905422778
# Mean absolute error -> 3.588819742202759
# R2 score -> -2724.0
# Training...
# Train_loss 0.28998757, Test loss : 0.17964489, Epoch 1
# Train_loss 0.16646369, Test loss : 0.12846184, Epoch 2
# Train_loss 0.15655681, Test loss : 0.12866299, Epoch 3
# Train_loss 0.15291000, Test loss : 0.13038144, Epoch 4
# Train_loss 0.15338990, Test loss : 0.13045397, Epoch 5
# Train_loss 0.15039792, Test loss : 0.13079511, Epoch 6
# Train_loss 0.15026296, Test loss : 0.13004753, Epoch 7
# Train_loss 0.15031893, Test loss : 0.12991013, Epoch 8
# Train_loss 0.15026456, Test loss : 0.13001737, Epoch 9
# Train_loss 0.15024879, Test loss : 0.12996575, Epoch 10
# Rmse lsoss -> 0.5121320846026617
# Mean absolute error -> 2.8345959186553955
# R2 score -> -3892.0
# Training...
# Train_loss 0.33049023, Test loss : 0.13821015, Epoch 1
# Train_loss 0.15387094, Test loss : 0.09945413, Epoch 2
# Train_loss 0.14380616, Test loss : 0.10038029, Epoch 3
# Train_loss 0.14273251, Test loss : 0.09940508, Epoch 4
# Train_loss 0.14239336, Test loss : 0.09867613, Epoch 5
# Train_loss 0.14148896, Test loss : 0.09821595, Epoch 6
# Train_loss 0.14133109, Test loss : 0.09839641, Epoch 7
# Train_loss 0.14101434, Test loss : 0.09825746, Epoch 8
# Train_loss 0.14078431, Test loss : 0.09814103, Epoch 9
# Train_loss 0.14087763, Test loss : 0.09806549, Epoch 10
# Rmse lsoss -> 0.3859515623858907
# Mean absolute error -> 2.8587863445281982
# R2 score -> -6225.0
# Training...
# Train_loss 0.31693381, Test loss : 0.25013334, Epoch 1
# Train_loss 0.19567062, Test loss : 0.20416675, Epoch 2
# Train_loss 0.17122017, Test loss : 0.20466769, Epoch 3
# Train_loss 0.17113882, Test loss : 0.20358298, Epoch 4
# Train_loss 0.17178833, Test loss : 0.20266174, Epoch 5
# Train_loss 0.16779706, Test loss : 0.20250796, Epoch 6
# Train_loss 0.16766947, Test loss : 0.20203911, Epoch 7
# Train_loss 0.16737728, Test loss : 0.20192445, Epoch 8
# Train_loss 0.16765903, Test loss : 0.20188776, Epoch 9
# Train_loss 0.16754384, Test loss : 0.20185364, Epoch 10
# Rmse lsoss -> 0.792703067262446
# Mean absolute error -> 0.6526986956596375
# R2 score -> -0.0
# Training...
# Train_loss 0.40766183, Test loss : 0.10883972, Epoch 1
# Train_loss 0.16496189, Test loss : 0.11459359, Epoch 2
# Train_loss 0.14803764, Test loss : 0.10997808, Epoch 3
# Train_loss 0.14689204, Test loss : 0.11085871, Epoch 4
# Train_loss 0.14665898, Test loss : 0.11086546, Epoch 5
# Train_loss 0.14592302, Test loss : 0.11088525, Epoch 6
# Train_loss 0.14603288, Test loss : 0.11076058, Epoch 7
# Train_loss 0.14585397, Test loss : 0.11079772, Epoch 8
# Train_loss 0.14595102, Test loss : 0.11077041, Epoch 9
# Train_loss 0.14615291, Test loss : 0.11070513, Epoch 10
# Rmse lsoss -> 0.43808155916486163
# Mean absolute error -> 0.9793148636817932
# R2 score -> -572.0
# Training...
# Train_loss 0.45053318, Test loss : 0.17469591, Epoch 1
# Train_loss 0.15111361, Test loss : 0.17351041, Epoch 2
# Train_loss 0.13217107, Test loss : 0.17398860, Epoch 3
# Train_loss 0.13093590, Test loss : 0.17491740, Epoch 4
# Train_loss 0.13093749, Test loss : 0.17479817, Epoch 5
# Train_loss 0.13012272, Test loss : 0.17482482, Epoch 6
# Train_loss 0.13017719, Test loss : 0.17517203, Epoch 7
# Train_loss 0.13011034, Test loss : 0.17499486, Epoch 8
# Train_loss 0.13001554, Test loss : 0.17490790, Epoch 9
# Train_loss 0.13005240, Test loss : 0.17492121, Epoch 10
# Rmse lsoss -> 0.6896301344887296
# Mean absolute error -> 1.3152236938476562
# R2 score -> -347.0
# Training...
# Train_loss 0.36120235, Test loss : 0.22266971, Epoch 1
# Train_loss 0.17943770, Test loss : 0.18816944, Epoch 2
# Train_loss 0.16454602, Test loss : 0.18875418, Epoch 3
# Train_loss 0.16555465, Test loss : 0.18949725, Epoch 4
# Train_loss 0.16553082, Test loss : 0.18898603, Epoch 5
# Train_loss 0.16385711, Test loss : 0.18893563, Epoch 6
# Train_loss 0.16383083, Test loss : 0.18927362, Epoch 7
# Train_loss 0.16383362, Test loss : 0.18912592, Epoch 8
# Train_loss 0.16371087, Test loss : 0.18909421, Epoch 9
# Train_loss 0.16371677, Test loss : 0.18907587, Epoch 10
# Rmse lsoss -> 0.7441537210108085
# Mean absolute error -> 0.9635218977928162
# R2 score -> -142.0
# Training...
# Train_loss 0.36825640, Test loss : 0.11665062, Epoch 1
# Train_loss 0.17608539, Test loss : 0.11988161, Epoch 2
# Train_loss 0.16782579, Test loss : 0.11596331, Epoch 3
# Train_loss 0.16711267, Test loss : 0.11257444, Epoch 4
# Train_loss 0.16670363, Test loss : 0.11172098, Epoch 5
# Train_loss 0.16652470, Test loss : 0.10857097, Epoch 6
# Train_loss 0.16578357, Test loss : 0.10717169, Epoch 7
# Train_loss 0.16581645, Test loss : 0.10737547, Epoch 8
# Train_loss 0.16588706, Test loss : 0.10759164, Epoch 9
# Train_loss 0.16592095, Test loss : 0.10737919, Epoch 10
# Rmse lsoss -> 0.4233706418002595
# Mean absolute error -> 0.518142580986023
# R2 score -> -124.0
# Training...
# Train_loss 0.31922567, Test loss : 0.19566144, Epoch 1
# Train_loss 0.16506690, Test loss : 0.15972419, Epoch 2
# Train_loss 0.15603713, Test loss : 0.15923218, Epoch 3
# Train_loss 0.15694304, Test loss : 0.15771363, Epoch 4
# Train_loss 0.15680698, Test loss : 0.15664140, Epoch 5
# Train_loss 0.15454127, Test loss : 0.15654312, Epoch 6
# Train_loss 0.15378629, Test loss : 0.15674845, Epoch 7
# Train_loss 0.15374163, Test loss : 0.15666522, Epoch 8
# Train_loss 0.15390396, Test loss : 0.15654940, Epoch 9
# Train_loss 0.15366541, Test loss : 0.15647689, Epoch 10
# Rmse lsoss -> 0.6143445073551963
# Mean absolute error -> 0.5485825538635254
# R2 score -> -22.0
# Training...
# Train_loss 0.33640895, Test loss : 0.11552240, Epoch 1
# Train_loss 0.16957080, Test loss : 0.10497436, Epoch 2
# Train_loss 0.15482818, Test loss : 0.09531457, Epoch 3
# Train_loss 0.15410074, Test loss : 0.09276872, Epoch 4
# Train_loss 0.15489598, Test loss : 0.09270781, Epoch 5
# Train_loss 0.15215073, Test loss : 0.09307619, Epoch 6
# Train_loss 0.15198033, Test loss : 0.09393304, Epoch 7
# Train_loss 0.15208431, Test loss : 0.09411339, Epoch 8
# Train_loss 0.15210238, Test loss : 0.09396284, Epoch 9
# Train_loss 0.15211118, Test loss : 0.09398403, Epoch 10
# Rmse lsoss -> 0.3726778851832505
# Mean absolute error -> 1.0535342693328857
# R2 score -> -976.0
# Training...
# Train_loss 0.34800529, Test loss : 0.24111448, Epoch 1
# Train_loss 0.16390449, Test loss : 0.18561806, Epoch 2
# Train_loss 0.15193271, Test loss : 0.18534089, Epoch 3
# Train_loss 0.15445742, Test loss : 0.18678359, Epoch 4
# Train_loss 0.15437038, Test loss : 0.18675926, Epoch 5
# Train_loss 0.15004156, Test loss : 0.18634915, Epoch 6
# Train_loss 0.15001270, Test loss : 0.18726142, Epoch 7
# Train_loss 0.15019484, Test loss : 0.18733567, Epoch 8
# Train_loss 0.15014996, Test loss : 0.18702758, Epoch 9
# Train_loss 0.15006202, Test loss : 0.18706071, Epoch 10
# Rmse lsoss -> 0.7396794153762024
# Mean absolute error -> 0.9068407416343689
# R2 score -> -158.0
# Training...
# Train_loss 0.44697092, Test loss : 0.13359254, Epoch 1
# Train_loss 0.17795091, Test loss : 0.13401124, Epoch 2
# Train_loss 0.15441750, Test loss : 0.13394222, Epoch 3
# Train_loss 0.15315714, Test loss : 0.13464895, Epoch 4
# Train_loss 0.15524932, Test loss : 0.13388689, Epoch 5
# Train_loss 0.15100975, Test loss : 0.13385413, Epoch 6
# Train_loss 0.15072220, Test loss : 0.13288253, Epoch 7
# Train_loss 0.15070323, Test loss : 0.13273966, Epoch 8
# Train_loss 0.15065569, Test loss : 0.13270586, Epoch 9
# Train_loss 0.15059982, Test loss : 0.13265534, Epoch 10
# Rmse lsoss -> 0.5254343007592555
# Mean absolute error -> 1.1346815824508667
# R2 score -> -599.0
# Training...
# Train_loss 0.29216486, Test loss : 0.12294194, Epoch 1
# Train_loss 0.14626392, Test loss : 0.09899012, Epoch 2
# Train_loss 0.14232580, Test loss : 0.09749423, Epoch 3
# Train_loss 0.14208707, Test loss : 0.09739100, Epoch 4
# Train_loss 0.14235730, Test loss : 0.09707071, Epoch 5
# Train_loss 0.14127492, Test loss : 0.09650330, Epoch 6
# Train_loss 0.14100553, Test loss : 0.09650087, Epoch 7
# Train_loss 0.14093355, Test loss : 0.09638596, Epoch 8
# Train_loss 0.14105324, Test loss : 0.09637001, Epoch 9
# Train_loss 0.14078795, Test loss : 0.09630523, Epoch 10
# Rmse lsoss -> 0.3794728398360656
# Mean absolute error -> 0.6879374980926514
# R2 score -> -391.0
# Training...
# Train_loss 0.34167636, Test loss : 0.22060052, Epoch 1
# Train_loss 0.18799128, Test loss : 0.20016408, Epoch 2
# Train_loss 0.16943872, Test loss : 0.20157295, Epoch 3
# Train_loss 0.17084237, Test loss : 0.20004603, Epoch 4
# Train_loss 0.17156062, Test loss : 0.19882384, Epoch 5
# Train_loss 0.16740256, Test loss : 0.19856096, Epoch 6
# Train_loss 0.16732187, Test loss : 0.19803365, Epoch 7
# Train_loss 0.16712859, Test loss : 0.19791676, Epoch 8
# Train_loss 0.16714922, Test loss : 0.19793158, Epoch 9
# Train_loss 0.16713497, Test loss : 0.19792419, Epoch 10
# Rmse lsoss -> 0.7864575586041472
# Mean absolute error -> 1.026593804359436
# R2 score -> -172.0
# Training...
# Train_loss 0.37670113, Test loss : 0.11452931, Epoch 1
# Train_loss 0.16439006, Test loss : 0.11240805, Epoch 2
# Train_loss 0.14728075, Test loss : 0.10669412, Epoch 3
# Train_loss 0.14610542, Test loss : 0.10764097, Epoch 4
# Train_loss 0.14614375, Test loss : 0.10815722, Epoch 5
# Train_loss 0.14567921, Test loss : 0.10782193, Epoch 6
# Train_loss 0.14555511, Test loss : 0.10760094, Epoch 7
# Train_loss 0.14558170, Test loss : 0.10767096, Epoch 8
# Train_loss 0.14558197, Test loss : 0.10776645, Epoch 9
# Train_loss 0.14536858, Test loss : 0.10774829, Epoch 10
# Rmse lsoss -> 0.4327688016074195
# Mean absolute error -> 0.8772883415222168
# R2 score -> -574.0
# Training...
# Train_loss 0.34491081, Test loss : 0.17601371, Epoch 1
# Train_loss 0.14166637, Test loss : 0.17152014, Epoch 2
# Train_loss 0.13099443, Test loss : 0.17316388, Epoch 3
# Train_loss 0.13051689, Test loss : 0.17420447, Epoch 4
# Train_loss 0.13030753, Test loss : 0.17391320, Epoch 5
# Train_loss 0.12969113, Test loss : 0.17315683, Epoch 6
# Train_loss 0.12972829, Test loss : 0.17314356, Epoch 7
# Train_loss 0.12963023, Test loss : 0.17320996, Epoch 8
# Train_loss 0.12968257, Test loss : 0.17319920, Epoch 9
# Train_loss 0.12966278, Test loss : 0.17315420, Epoch 10
# Rmse lsoss -> 0.6874009191035213
# Mean absolute error -> 1.1434345245361328
# R2 score -> -443.0
# Training...
# Train_loss 0.31428075, Test loss : 0.21707361, Epoch 1
# Train_loss 0.17552888, Test loss : 0.18848232, Epoch 2
# Train_loss 0.16467003, Test loss : 0.18926622, Epoch 3
# Train_loss 0.16521068, Test loss : 0.18948857, Epoch 4
# Train_loss 0.16478605, Test loss : 0.18815411, Epoch 5
# Train_loss 0.16364542, Test loss : 0.18774943, Epoch 6
# Train_loss 0.16352255, Test loss : 0.18778088, Epoch 7
# Train_loss 0.16358776, Test loss : 0.18784780, Epoch 8
# Train_loss 0.16357271, Test loss : 0.18784089, Epoch 9
# Train_loss 0.16356251, Test loss : 0.18774861, Epoch 10
# Rmse lsoss -> 0.7509860470970268
# Mean absolute error -> 1.3183343410491943
# R2 score -> -445.0
# Training...
# Train_loss 0.38544718, Test loss : 0.10824058, Epoch 1
# Train_loss 0.17776811, Test loss : 0.12968164, Epoch 2
# Train_loss 0.16899011, Test loss : 0.11098436, Epoch 3
# Train_loss 0.16686819, Test loss : 0.10783844, Epoch 4
# Train_loss 0.16621322, Test loss : 0.10863388, Epoch 5
# Train_loss 0.16584860, Test loss : 0.10687940, Epoch 6
# Train_loss 0.16567029, Test loss : 0.10598647, Epoch 7
# Train_loss 0.16563440, Test loss : 0.10601410, Epoch 8
# Train_loss 0.16560164, Test loss : 0.10609455, Epoch 9
# Train_loss 0.16563347, Test loss : 0.10602018, Epoch 10
# Rmse lsoss -> 0.4157881495416881
# Mean absolute error -> 0.6697829961776733
# R2 score -> -473.00000000000006
# Training...
# Train_loss 0.38678193, Test loss : 0.16024753, Epoch 1
# Train_loss 0.16320992, Test loss : 0.16209102, Epoch 2
# Train_loss 0.15827025, Test loss : 0.15754449, Epoch 3
# Train_loss 0.15584903, Test loss : 0.15658062, Epoch 4
# Train_loss 0.15493290, Test loss : 0.15575677, Epoch 5
# Train_loss 0.15388254, Test loss : 0.15579457, Epoch 6
# Train_loss 0.15359292, Test loss : 0.15594745, Epoch 7
# Train_loss 0.15369458, Test loss : 0.15594884, Epoch 8
# Train_loss 0.15361694, Test loss : 0.15587145, Epoch 9
# Train_loss 0.15358662, Test loss : 0.15581880, Epoch 10
# Rmse lsoss -> 0.619843670455816
# Mean absolute error -> 1.5560438632965088
# R2 score -> -797.0
# Training...
# Train_loss 0.40567121, Test loss : 0.12420705, Epoch 1
# Train_loss 0.16637475, Test loss : 0.10690927, Epoch 2
# Train_loss 0.15297359, Test loss : 0.09006919, Epoch 3
# Train_loss 0.15396979, Test loss : 0.09084735, Epoch 4
# Train_loss 0.15450590, Test loss : 0.09145374, Epoch 5
# Train_loss 0.15172754, Test loss : 0.09089568, Epoch 6
# Train_loss 0.15157692, Test loss : 0.09104201, Epoch 7
# Train_loss 0.15172524, Test loss : 0.09119530, Epoch 8
# Train_loss 0.15170001, Test loss : 0.09112685, Epoch 9
# Train_loss 0.15176444, Test loss : 0.09122109, Epoch 10
# Rmse lsoss -> 0.34945241505452457
# Mean absolute error -> 0.8449977040290833
# R2 score -> -867.0
# Training...
# Train_loss 0.37889899, Test loss : 0.19093101, Epoch 1
# Train_loss 0.15738145, Test loss : 0.18403019, Epoch 2
# Train_loss 0.15493110, Test loss : 0.18693260, Epoch 3
# Train_loss 0.15435690, Test loss : 0.18907568, Epoch 4
# Train_loss 0.15321462, Test loss : 0.18720333, Epoch 5
# Train_loss 0.14977546, Test loss : 0.18666356, Epoch 6
# Train_loss 0.14972213, Test loss : 0.18704488, Epoch 7
# Train_loss 0.14980138, Test loss : 0.18712787, Epoch 8
# Train_loss 0.14973576, Test loss : 0.18699431, Epoch 9
# Train_loss 0.14969773, Test loss : 0.18696927, Epoch 10
# Rmse lsoss -> 0.747809310121982
# Mean absolute error -> 0.8475242257118225
# R2 score -> -202.0
# Training...
# Train_loss 0.42632273, Test loss : 0.13135480, Epoch 1
# Train_loss 0.17523469, Test loss : 0.13022663, Epoch 2
# Train_loss 0.15253663, Test loss : 0.13065402, Epoch 3
# Train_loss 0.15212583, Test loss : 0.13019769, Epoch 4
# Train_loss 0.15424775, Test loss : 0.12862460, Epoch 5
# Train_loss 0.15026878, Test loss : 0.12903910, Epoch 6
# Train_loss 0.15020173, Test loss : 0.12827080, Epoch 7
# Train_loss 0.15021331, Test loss : 0.12818961, Epoch 8
# Train_loss 0.15016662, Test loss : 0.12826341, Epoch 9
# Train_loss 0.15008987, Test loss : 0.12820338, Epoch 10
# Rmse lsoss -> 0.5048225706304313
# Mean absolute error -> 2.0103189945220947
# R2 score -> -1736.0
# Training...
# Train_loss 0.32216665, Test loss : 0.11444049, Epoch 1
# Train_loss 0.15321352, Test loss : 0.10204640, Epoch 2
# Train_loss 0.14312819, Test loss : 0.09722875, Epoch 3
# Train_loss 0.14163449, Test loss : 0.09570753, Epoch 4
# Train_loss 0.14133880, Test loss : 0.09506717, Epoch 5
# Train_loss 0.14089801, Test loss : 0.09506922, Epoch 6
# Train_loss 0.14070945, Test loss : 0.09524479, Epoch 7
# Train_loss 0.14058206, Test loss : 0.09521954, Epoch 8
# Train_loss 0.14057072, Test loss : 0.09518834, Epoch 9
# Train_loss 0.14070108, Test loss : 0.09518986, Epoch 10
# Rmse lsoss -> 0.38487155056529204
# Mean absolute error -> 0.9136717319488525
# R2 score -> -796.0

# %%
print([item[-1] for item in matrix_cv_base])
print([item[-3] for item in matrix_cv_base])

print([item[-1] for item in matrix_cv_noise])
print([item[-3] for item in matrix_cv_noise])

print([item[-1] for item in matrix_cv_low_demand])
print([item[-3] for item in matrix_cv_low_demand])
# Out:
# [1.8415178, 2.19711, 4.3393803, 3.802082, 3.592763, 2.544934, 3.1379733, 3.5888197, 2.834596, 2.8587863]
# [0.792949244066683, 0.4344989160759052, 0.6895985652551307, 0.7333248015109733, 0.43586898661831186, 0.6097122872855549, 0.36783581172864077, 0.7317843905422778, 0.5121320846026617, 0.3859515623858907]
# [0.6526987, 0.97931486, 1.3152237, 0.9635219, 0.5181426, 0.54858255, 1.0535343, 0.90684074, 1.1346816, 0.6879375]
# [0.792703067262446, 0.43808155916486163, 0.6896301344887296, 0.7441537210108085, 0.4233706418002595, 0.6143445073551963, 0.3726778851832505, 0.7396794153762024, 0.5254343007592555, 0.3794728398360656]
# [1.0265938, 0.87728834, 1.1434345, 1.3183343, 0.669783, 1.5560439, 0.8449977, 0.8475242, 2.010319, 0.91367173]
# [0.7864575586041472, 0.4327688016074195, 0.6874009191035213, 0.7509860470970268, 0.4157881495416881, 0.619843670455816, 0.34945241505452457, 0.747809310121982, 0.5048225706304313, 0.38487155056529204]

# %%
print(np.average([item[-2] for item in matrix_cv_base]))
print(np.average([item[-2] for item in matrix_cv_noise]))
print(np.average([item[-2] for item in matrix_cv_low_demand]))
# Out:
# -4228.6
# -333.1
# -650.5

# %%
matrix_cv_base_MAE = [item[-1] for item in matrix_cv_base]
matrix_cv_noise_MAE = [item[-1] for item in matrix_cv_noise]
matrix_cv_low_demand_MAE = [item[-1] for item in matrix_cv_low_demand]

# %%
print([item[-2] for item in matrix_cv_base])
print([item[-2] for item in matrix_cv_noise])
print([item[-2] for item in matrix_cv_low_demand])
# Out:
# [-810.0, -3144.0, -4312.0, -2728.0, -8386.0, -1973.0, -8092.0, -2724.0, -3892.0, -6225.0]
# [-0.0, -572.0, -347.0, -142.0, -124.0, -22.0, -976.0, -158.0, -599.0, -391.0]
# [-172.0, -574.0, -443.0, -445.0, -473.00000000000006, -797.0, -867.0, -202.0, -1736.0, -796.0]

# %%
print(stats.ttest_ind([item[-2] for item in matrix_cv_base], [item[-2] for item in matrix_cv_noise]))
print(stats.ttest_ind([item[-2] for item in matrix_cv_base], [item[-2] for item in matrix_cv_low_demand]))
print(stats.ttest_ind([item[-2] for item in matrix_cv_noise], [item[-2] for item in matrix_cv_low_demand]))
# Out:
# Ttest_indResult(statistic=-4.7851498670085, pvalue=0.00014812325288086938)
# Ttest_indResult(statistic=-4.360410104884567, pvalue=0.0003770937905093948)
# Ttest_indResult(statistic=1.838012491681219, pvalue=0.08262328246737763)

# %% [markdown]
#  * Summery

# %%
summery.update({ city_name: {
    "base_model": {
        "skill_score": base_model_skill,
        "MAE_score": base_model_MAE_score,
        "RMSE_score": base_model_RSME_score,
        "R2_score": base_model_R2_score
    },
    "noise_model": {
        "skill_score": noise_model_skill,
        "MAE_score": noise_model_MAE_score,
        "RMSE_score": noise_model_RSME_score,
        "R2_score": noise_model_R2_score
    },
    "low_demand_model": {
        "skill_score": low_demand_model_skill,
        "MAE_score": low_demand_model_MAE_score,
        "RMSE_score": low_demand_model_RSME_score,
        "R2_score": low_demand_model_R2_score
    }
}})
localStorage.save_to_pkl(summery)

# %% [markdown]
# - KNN, hypothesis

# %% [markdown]
# - Write about the hypothesis

# %% [markdown]
# ## Hypothesis -
#
#     * Apply KNN on the data, and see different ponts in a graph, Find similar ponts(similarity methos) and compare their evaluation and fix the data.
#     * For example, if some points falls within the same cluster and differ by their demand then their might be somw issue, in the training data
#     * Also, write about how difficlut it would be to find the similar points, as time series data works differently compare to the normal data set

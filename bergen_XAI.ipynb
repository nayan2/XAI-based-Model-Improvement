# %% [markdown]
# ## Findings
#     -> We can see different heat map for differnt test data, while most of them have different error rate.
#     -> We can see that the heat map would be different consideing the fact that, error rate is different.
#     -> We would probbaly generate different heat map, for different range of errors.

# %% [markdown]
# ## Research path -
#     -> Ways to improve the model performace using/through/by XAI
# ## Tasks -
#     -> Generate Attention Map
#     -> Do perturbation analysis/ add or remove data points/ Use any classification technique to improve model performance
#     -> Use some other technique using XAI and compare the results
#     -> Propose some novel technique
#     -> Create seperate model for different cities

# %% [markdown]
# ## Writing suggession
#     -> Have to write why, demand forecasting is important
#     -> The money issue, And what we are tring to achieve from the thesis

# %% [markdown]
# # Improvements suggested -
#     -> Add window feature
#     -> Add lag feature from previous week same day
#     -> Add skill score
#     -> Use absolute error for test data
#     -> Use baseline forescast to evaluate the model

# %%
# %reload_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '../helper/')

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from scipy import stats
import data as data_helper
import model as model_helper
import config
import localStorage
# Out:
# Choosen device cuda

# %% [markdown]
# ## Global Variables

# %%
city_name = "bergen"
summery = { city_name: {} }

# %% [markdown]
# ## Load the data

# %%
train = data_helper.load_train_data(city_name)

# %%
train = data_helper.filter_train_data(train)

# %%
train.head()
# Out:
#                       place  temperature    demand
# time
# 2022-04-08 00:00:00  bergen         -1.1  0.984202
# 2022-04-08 01:00:00  bergen         -0.7  0.950335
# 2022-04-08 02:00:00  bergen         -0.9  0.977533
# 2022-04-08 03:00:00  bergen         -0.9  0.965054
# 2022-04-08 04:00:00  bergen         -1.6  1.024541

# %% [markdown]
# # Data analysis

# %%
data_helper.show_density_plot(train)

# %%
train.isna().sum()
# Out:
# place          0
# temperature    0
# demand         0
# dtype: int64

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# - Time Feature Extraction\
#   -> Year\
#   -> month_cos\
#   -> month_sin\
#   -> day_cos\
#   -> day_sin\
#   -> hour_cos\
#   -> hour_sin\
#   -> Public holiday or not\
#   -> Daylight savings or not\
#   -> Weekend or not\
#   -> Business hour or not\
#   -> Season of the year

# %%
train_1 = data_helper.add_feature(train)

# %%
train_1.head()
# Out:
#                       place  temperature    demand  month_sin  month_cos  \
# time
# 2022-04-08 00:00:00  bergen         -1.1  0.984202   0.866025       -0.5
# 2022-04-08 01:00:00  bergen         -0.7  0.950335   0.866025       -0.5
# 2022-04-08 02:00:00  bergen         -0.9  0.977533   0.866025       -0.5
# 2022-04-08 03:00:00  bergen         -0.9  0.965054   0.866025       -0.5
# 2022-04-08 04:00:00  bergen         -1.6  1.024541   0.866025       -0.5
#
#                       day_sin   day_cos  hour_sin  hour_cos  business_hour  \
# time
# 2022-04-08 00:00:00  0.993257 -0.115935  0.000000  1.000000              0
# 2022-04-08 01:00:00  0.993257 -0.115935  0.269797  0.962917              0
# 2022-04-08 02:00:00  0.993257 -0.115935  0.519584  0.854419              0
# 2022-04-08 03:00:00  0.993257 -0.115935  0.730836  0.682553              0
# 2022-04-08 04:00:00  0.993257 -0.115935  0.887885  0.460065              0
#
#                      season  weekend  daylight  holiday
# time
# 2022-04-08 00:00:00  spring        0         1        0
# 2022-04-08 01:00:00  spring        0         1        0
# 2022-04-08 02:00:00  spring        0         1        0
# 2022-04-08 03:00:00  spring        0         1        0
# 2022-04-08 04:00:00  spring        0         1        0

# %% [markdown]
# - One hot encode

# %%
train_2 = data_helper.one_hot_encoding(train_1, ['season'])

# %%
train_2.head()
# Out:
#                       place  temperature    demand  month_sin  month_cos  \
# time
# 2022-04-08 00:00:00  bergen         -1.1  0.984202   0.866025       -0.5
# 2022-04-08 01:00:00  bergen         -0.7  0.950335   0.866025       -0.5
# 2022-04-08 02:00:00  bergen         -0.9  0.977533   0.866025       -0.5
# 2022-04-08 03:00:00  bergen         -0.9  0.965054   0.866025       -0.5
# 2022-04-08 04:00:00  bergen         -1.6  1.024541   0.866025       -0.5
#
#                       day_sin   day_cos  hour_sin  hour_cos  business_hour  \
# time
# 2022-04-08 00:00:00  0.993257 -0.115935  0.000000  1.000000              0
# 2022-04-08 01:00:00  0.993257 -0.115935  0.269797  0.962917              0
# 2022-04-08 02:00:00  0.993257 -0.115935  0.519584  0.854419              0
# 2022-04-08 03:00:00  0.993257 -0.115935  0.730836  0.682553              0
# 2022-04-08 04:00:00  0.993257 -0.115935  0.887885  0.460065              0
#
#                      weekend  daylight  holiday  autumn  spring  summer
# time
# 2022-04-08 00:00:00        0         1        0       0       1       0
# 2022-04-08 01:00:00        0         1        0       0       1       0
# 2022-04-08 02:00:00        0         1        0       0       1       0
# 2022-04-08 03:00:00        0         1        0       0       1       0
# 2022-04-08 04:00:00        0         1        0       0       1       0

# %% [markdown]
# - Scale the data

# %%
x_scaler, y_scaler, train_3 = data_helper.scale(train_2)

# %%
train_3.head()
# Out:
#                      autumn  business_hour   day_cos   day_sin  daylight  \
# time
# 2022-04-08 00:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 01:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 02:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 03:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 04:00:00       0              0 -0.115935  0.993257         1
#
#                      holiday  hour_cos  hour_sin  month_cos  month_sin  \
# time
# 2022-04-08 00:00:00        0  1.000000  0.000000       -0.5   0.866025
# 2022-04-08 01:00:00        0  0.962917  0.269797       -0.5   0.866025
# 2022-04-08 02:00:00        0  0.854419  0.519584       -0.5   0.866025
# 2022-04-08 03:00:00        0  0.682553  0.730836       -0.5   0.866025
# 2022-04-08 04:00:00        0  0.460065  0.887885       -0.5   0.866025
#
#                       place  spring  summer  weekend  temperature    demand
# time
# 2022-04-08 00:00:00  bergen       1       0        0    -0.354120 -0.742843
# 2022-04-08 01:00:00  bergen       1       0        0    -0.336303 -0.758941
# 2022-04-08 02:00:00  bergen       1       0        0    -0.345212 -0.746013
# 2022-04-08 03:00:00  bergen       1       0        0    -0.345212 -0.751945
# 2022-04-08 04:00:00  bergen       1       0        0    -0.376392 -0.723669

# %% [markdown]
# - Rearrange the columns

# %%
train_4 = train_3[config.COLUMN_NAMES]

# %%
train_4.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-04-08 00:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 01:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 02:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 03:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 04:00:00       1       0       0   0.866025       -0.5  0.993257
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-04-08 00:00:00 -0.115935  0.000000  1.000000              0        0
# 2022-04-08 01:00:00 -0.115935  0.269797  0.962917              0        0
# 2022-04-08 02:00:00 -0.115935  0.519584  0.854419              0        0
# 2022-04-08 03:00:00 -0.115935  0.730836  0.682553              0        0
# 2022-04-08 04:00:00 -0.115935  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature    demand
# time
# 2022-04-08 00:00:00         1        0    -0.354120 -0.742843
# 2022-04-08 01:00:00         1        0    -0.336303 -0.758941
# 2022-04-08 02:00:00         1        0    -0.345212 -0.746013
# 2022-04-08 03:00:00         1        0    -0.345212 -0.751945
# 2022-04-08 04:00:00         1        0    -0.376392 -0.723669

# %% [markdown]
# - Lag feature

# %%
train_5 = data_helper.add_lag(train_4, 1)

# %%
train_5.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-04-08 00:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 01:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 02:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 03:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 04:00:00       1       0       0   0.866025       -0.5  0.993257
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-04-08 00:00:00 -0.115935  0.000000  1.000000              0        0
# 2022-04-08 01:00:00 -0.115935  0.269797  0.962917              0        0
# 2022-04-08 02:00:00 -0.115935  0.519584  0.854419              0        0
# 2022-04-08 03:00:00 -0.115935  0.730836  0.682553              0        0
# 2022-04-08 04:00:00 -0.115935  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature  demand-1    demand
# time
# 2022-04-08 00:00:00         1        0    -0.354120  0.000000 -0.742843
# 2022-04-08 01:00:00         1        0    -0.336303 -0.742843 -0.758941
# 2022-04-08 02:00:00         1        0    -0.345212 -0.758941 -0.746013
# 2022-04-08 03:00:00         1        0    -0.345212 -0.746013 -0.751945
# 2022-04-08 04:00:00         1        0    -0.376392 -0.751945 -0.723669

# %% [markdown]
# - Baseline feature

# %%
train_6 = data_helper.add_baseline_feature(train_5)

# %%
train_6.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-04-08 00:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 01:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 02:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 03:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 04:00:00       1       0       0   0.866025       -0.5  0.993257
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-04-08 00:00:00 -0.115935  0.000000  1.000000              0        0
# 2022-04-08 01:00:00 -0.115935  0.269797  0.962917              0        0
# 2022-04-08 02:00:00 -0.115935  0.519584  0.854419              0        0
# 2022-04-08 03:00:00 -0.115935  0.730836  0.682553              0        0
# 2022-04-08 04:00:00 -0.115935  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature  base_line_demand  \
# time
# 2022-04-08 00:00:00         1        0    -0.354120         -0.742843
# 2022-04-08 01:00:00         1        0    -0.336303         -0.758941
# 2022-04-08 02:00:00         1        0    -0.345212         -0.746013
# 2022-04-08 03:00:00         1        0    -0.345212         -0.751945
# 2022-04-08 04:00:00         1        0    -0.376392         -0.723669
#
#                      demand-1    demand
# time
# 2022-04-08 00:00:00  0.000000 -0.742843
# 2022-04-08 01:00:00 -0.742843 -0.758941
# 2022-04-08 02:00:00 -0.758941 -0.746013
# 2022-04-08 03:00:00 -0.746013 -0.751945
# 2022-04-08 04:00:00 -0.751945 -0.723669

# %% [markdown]
# - Split the final data for Base-line model

# %%
train_split_base_X = train_6.iloc[:, :-1]
train_split_base_Y = train_6.iloc[:, -1]

# %%
X_train_base, X_test_base, Y_train_base, Y_test_base = train_test_split(train_split_base_X, train_split_base_Y, test_size=0.2, random_state=0)

# %% [markdown]
# - Create sequence

# %%
train_split_X, train_split_Y = data_helper.split_sequences(train_6, config.WINDOW_SIZE)

# %% [markdown]
# - Train test split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train_split_X, train_split_Y, test_size=0.2, random_state=0)

# %% [markdown]
# - Model preparation

# %%
model_helper.show_me()

# %%
PATH = f"./data/{city_name}_model_XAI"
model = model_helper.train_model(np.shape(X_train[0])[-1], X_train, Y_train, X_test, Y_test, False, config.BATCH_SIZE, config.NUM_EPOCHS, config.PRC_EPOCH, PATH, True)
# Out:
# the model  ./data/bergen_model_XAI has beed loaded !

# %% [markdown]
# - Test the performance

# %%
base_model_actual_value, base_model_predicted_value, base_model_RSME_score, base_model_R2_score, base_model_MAE_score, _, _ = model_helper.display_results(model, X_test, Y_test, y_scaler, (-0.4, 4), (200, 400))
# print(actual), print(predicted)
# Comment about the result:: Capture variation but missing trend
# Out:
#   0%|          | 0/1690 [00:00<?, ?it/s]
# d:\Semester 4\XAI\../helper\model.py:316: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
#   seq = torch.FloatTensor([X[index]]).to(device=config.DEVICE)
# Rmse lsoss -> 1.0972499434809433
# Mean absolute error -> 0.28478267788887024
# R2 score -> 89.0

# %% [markdown]
# - Generate the explaination (global)

# %%
# compute global attention
meanAttn, meanScores = model_helper.generate_global_heatmap(model, X_test, "Global Heat Map")
# Out:
#   0%|          | 0/85 [00:00<?, ?it/s]

# %% [markdown]
# - How's the heatmap looks like, for good and bad predictions

# %%
good_pred, bad_pred = model_helper.split_good_bad_data(X_train, Y_train, model, y_scaler)
# Out:
#   0%|          | 0/6758 [00:00<?, ?it/s]

# %%
model_helper.generate_global_heatmap(model, good_pred, "Good Prediction Heat Map")
model_helper.generate_global_heatmap(model, bad_pred, "Bad Predictin Heat Map")
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/324 [00:00<?, ?it/s]
# (array([[ 4.3078052e-09, -4.5804587e-09, -6.1596461e-09, ...,
#           8.6079153e-09, -2.1034248e-09, -5.1716436e-09],
#         [ 5.7496496e-09, -5.0284341e-09, -6.7000081e-09, ...,
#           7.9996729e-09, -1.6991629e-09, -4.3928998e-09],
#         [ 6.8987407e-09, -5.2821623e-09, -7.2005113e-09, ...,
#           6.9830270e-09, -1.0476822e-09, -3.2167851e-09],
#         ...,
#         [ 3.9899306e-09, -2.6648335e-09, -3.4491010e-09, ...,
#           1.7972187e-09,  7.4808953e-10,  7.5680795e-10],
#         [ 2.3593776e-09, -1.5868387e-09, -1.9727224e-09, ...,
#           1.2386084e-09,  3.6090508e-10,  4.0334505e-10],
#         [ 8.9528407e-10, -5.8882160e-10, -7.0321088e-10, ...,
#           5.6927613e-10,  9.7411308e-11,  1.2539887e-10]], dtype=float32),
#  array([[0.00608007],
#         [0.00603771],
#         [0.00600996],
#         [0.0059912 ],
#         [0.00597822],
#         [0.00596922],
#         [0.00596297],
#         [0.00595864],
#         [0.00595563],
#         [0.00595364],
#         [0.00595229],
#         [0.00595146],
#         [0.00595097],
#         [0.00595073],
#         [0.00595064],
#         [0.00595067],
#         [0.0059508 ],
#         [0.00595092],
#         [0.00595107],
#         [0.00595118],
#         [0.00595128],
#         [0.00595131],
#         [0.00595131],
#         [0.00595125],
#         [0.00595114],
#         [0.00595098],
#         [0.0059508 ],
#         [0.00595057],
#         [0.00595036],
#         [0.00595016],
#         [0.00594997],
#         [0.00594981],
#         [0.00594968],
#         [0.00594962],
#         [0.0059496 ],
#         [0.00594964],
#         [0.00594973],
#         [0.00594986],
#         [0.00595004],
#         [0.00595023],
#         [0.00595043],
#         [0.00595063],
#         [0.00595082],
#         [0.00595096],
#         [0.00595107],
#         [0.00595111],
#         [0.00595112],
#         [0.00595106],
#         [0.00595095],
#         [0.00595079],
#         [0.0059506 ],
#         [0.00595038],
#         [0.00595016],
#         [0.00594995],
#         [0.00594974],
#         [0.00594959],
#         [0.00594946],
#         [0.00594939],
#         [0.00594938],
#         [0.00594942],
#         [0.00594953],
#         [0.00594967],
#         [0.00594982],
#         [0.00595002],
#         [0.00595023],
#         [0.00595045],
#         [0.00595063],
#         [0.0059508 ],
#         [0.00595088],
#         [0.00595094],
#         [0.00595095],
#         [0.0059509 ],
#         [0.0059508 ],
#         [0.00595064],
#         [0.00595046],
#         [0.00595025],
#         [0.00595003],
#         [0.0059498 ],
#         [0.00594961],
#         [0.00594943],
#         [0.00594932],
#         [0.00594924],
#         [0.00594925],
#         [0.00594927],
#         [0.00594935],
#         [0.0059495 ],
#         [0.00594969],
#         [0.00594989],
#         [0.00595009],
#         [0.00595029],
#         [0.00595048],
#         [0.00595061],
#         [0.00595071],
#         [0.00595077],
#         [0.00595075],
#         [0.00595071],
#         [0.00595061],
#         [0.00595044],
#         [0.00595028],
#         [0.00595004],
#         [0.00594984],
#         [0.00594961],
#         [0.00594942],
#         [0.00594928],
#         [0.00594914],
#         [0.00594907],
#         [0.00594905],
#         [0.0059491 ],
#         [0.00594916],
#         [0.00594929],
#         [0.00594947],
#         [0.00594965],
#         [0.00594985],
#         [0.00595005],
#         [0.00595023],
#         [0.00595038],
#         [0.00595049],
#         [0.00595055],
#         [0.00595054],
#         [0.00595048],
#         [0.00595035],
#         [0.0059502 ],
#         [0.00595001],
#         [0.00594979],
#         [0.00594959],
#         [0.00594936],
#         [0.00594917],
#         [0.00594901],
#         [0.00594889],
#         [0.00594882],
#         [0.0059488 ],
#         [0.00594884],
#         [0.00594892],
#         [0.00594906],
#         [0.00594922],
#         [0.00594944],
#         [0.00594965],
#         [0.00594985],
#         [0.00595004],
#         [0.00595018],
#         [0.00595027],
#         [0.00595035],
#         [0.00595032],
#         [0.00595026],
#         [0.00595015],
#         [0.00594997],
#         [0.00594978],
#         [0.00594956],
#         [0.00594934],
#         [0.00594914],
#         [0.00594896],
#         [0.0059488 ],
#         [0.00594869],
#         [0.00594863],
#         [0.00594862],
#         [0.00594867],
#         [0.00594875],
#         [0.00594889],
#         [0.00594905],
#         [0.00594925],
#         [0.00594947],
#         [0.00594967],
#         [0.00594983],
#         [0.00594998],
#         [0.00595007],
#         [0.00595011],
#         [0.00595011],
#         [0.00595005]], dtype=float32))

# %% [markdown]
# - Generate the explaination (Local)

# %%
heat_index = 1
res = model_helper.disp_grads_rk(model_helper.compute_grads(None, model, X_test[heat_index]))
print(f"Actual result -> {Y_test[heat_index]} && Predicted result -> {res}")
print(f"Error - {np.mean(np.abs(Y_test[heat_index] - res))}")
# Out:
# Actual result -> 0.014661932036836856 && Predicted result -> -0.29228031635284424
# Error - 0.3069422483896811

# %% [markdown]
# - Partial dependency plt, to manipulate the data

# %%
X, y = train_6.iloc[:, :-1], np.reshape(y_scaler.inverse_transform(np.reshape(train_6.iloc[:, -1].to_numpy(), (-1, 1))), (-1))

# %%
# polyreg = model_helper.train_plyrg_model(4, X, y)

# %%
# model_helper.generate_feature_graph(polyreg, X, 3, int(len(X.columns)/3), X.columns[:-1])

# %% [markdown]
# - Perturbation analysis or replace less important data with random noise, K-nearest neighbor, Augmented data

# %% [markdown]
# - Random noise

# %%
# Add random noise based on the heatmap
light_blue = (0.00594, 0.00596)
dark_red = (0.00597, )
X_train_with_noise = data_helper.add_random_noise(X_train, light_blue, dark_red, model)

# %%
# Retrain the model with the new data
PATH_NOISE = f"./data/{city_name}_model_XAI_Noise"
model_noise = model_helper.train_model(np.shape(X_train[0])[-1], X_train_with_noise, Y_train, X_test, Y_test, False, config.BATCH_SIZE, 6, config.PRC_EPOCH, PATH_NOISE, True)
# Out:
# the model  ./data/bergen_model_XAI_Noise has beed loaded !

# %%
# Check the performance
noise_model_actual_value, noise_model_predicted_value, noise_model_RSME_score, noise_model_R2_score, noise_model_MAE_score, _, _ = model_helper.display_results(model_noise, X_test, Y_test, y_scaler, (0.4, 4.0), [200, 400])
print(noise_model_actual_value), print(noise_model_predicted_value)
# Out:
#   0%|          | 0/1690 [00:00<?, ?it/s]
# Rmse lsoss -> 1.1075773045962698
# Mean absolute error -> 0.2962590754032135
# R2 score -> 89.0
# [3.9656365, 2.5778499, 0.704031, 1.017308, 3.3493536, 0.80324394, 1.078285, 2.8752277, 2.1822588, 2.173894, 0.87349397, 3.0633526, 0.697515, 1.610121, 2.3743, 1.32268, 0.61985004, 2.6451066, 0.8653911, 0.56633097, 0.96797997, 3.4271908, 3.7947927, 1.862814, 0.62902206, 0.860125, 3.8195274, 1.889356, 1.1177831, 3.4852526, 1.7511259, 0.817458, 2.4671886, 0.6858451, 3.4166038, 0.949669, 0.72375005, 1.378052, 0.9486661, 3.3294308, 3.3590581, 1.280324, 0.65703094, 0.99554294, 3.027563, 1.729473, 0.7124231, 2.314578, 1.599119, 0.73733205, 3.4737542, 0.817989, 3.3455665, 0.800265, 0.927436, 0.70009404, 0.91826797, 1.6009649, 0.99781704, 3.3950377, 3.4136016, 1.390356, 3.9710715, 0.67657006, 0.83094203, 1.068116, 2.9661076, 0.979498, 0.76639503, 0.90525603, 1.628331, 0.79521406, 0.626634, 0.834003, 1.0049809, 3.3294137, 3.0786195, 2.6575036, 0.92111, 3.4549506, 2.9958467, 3.0888057, 2.785022, 0.701103, 0.93579596, 1.9800259, 2.8852887, 3.1441696, 0.713994, 1.4942771, 3.1590838, 0.6824941, 0.692109, 2.5462875, 2.94786, 0.755005, 0.585936, 1.2119911, 1.0280349, 0.758554, 3.682253, 0.753415, 4.263267, 0.817504, 0.682107, 3.5385802, 0.74375, 0.56759197, 0.844125, 0.842517, 1.2148839, 3.2663414, 3.0903058, 2.9522517, 3.1660736, 0.96936595, 0.903344, 0.89005303, 1.009733, 1.1070011, 0.96517396, 2.9308116, 3.0184247, 0.55027604, 0.818567, 2.4461267, 3.2179782, 4.188716, 3.309701, 0.930122, 3.3901846, 0.80728, 0.796634, 1.019524, 1.037998, 1.6551889, 0.76551104, 2.838388, 2.7495458, 0.71486205, 1.02601, 0.63098603, 1.29242, 0.99542093, 4.0891047, 0.94733196, 2.4116678, 1.635425, 0.83580005, 0.80599105, 4.08049, 0.993811, 0.59258306, 0.82633704, 0.938891, 2.8244996, 3.2382019, 4.003799, 3.4341795, 3.4439485, 3.666772, 0.548946, 4.3198423, 0.78512394, 1.540746, 3.7320254, 3.3123212, 1.120321, 1.626679, 0.622187, 3.9182062, 0.72422504, 0.896341, 0.820917, 2.6561415, 1.152111, 1.055679, 3.3218336, 2.08273, 1.14781, 0.99367106, 0.727688, 2.8660364, 1.8829709, 1.888022, 0.914457, 0.610492, 1.5232121, 0.79257005, 1.0287371, 0.90015, 0.69912696, 0.55593103, 0.87920606, 1.0395551, 1.292357, 1.2449211, 0.669717, 0.64651805, 2.241412, 2.6615496, 2.7613747, 0.842815, 0.9847541, 3.0847487, 1.8621609, 0.876432, 3.8560145, 0.82205904, 3.2339616, 1.016105, 1.4692919, 0.99589896, 2.465633, 3.2830906, 3.619132, 3.5924146, 0.903863, 1.493256, 3.578264, 2.015457, 2.8485277, 3.111382, 0.85292095, 3.646477, 1.046845, 1.277484, 0.554534, 3.0288005, 0.90490603, 0.921015, 3.5578897, 2.2123332, 0.78546107, 0.715569, 0.93824005, 0.99467295, 3.6552455, 0.8213631, 1.733452, 0.9216921, 1.065691, 2.18743, 0.908601, 3.2198977, 3.7081156, 1.960906, 0.832784, 0.855416, 2.416674, 3.2068236, 0.668843, 0.894002, 1.160891, 0.88418794, 3.488469, 3.1904037, 0.80141604, 0.755872, 1.123053, 1.633276, 0.720107, 1.151555, 3.4503326, 0.617041, 0.851597, 3.311465, 0.720233, 3.2408836, 0.87545305, 0.90775007, 2.509572, 0.562626, 0.86650395, 0.8040271, 0.963364, 0.528684, 0.99503195, 3.7662625, 3.6850257, 1.001606, 0.7139981, 4.122393, 1.701745, 3.560271, 3.9276576, 0.998838, 3.061476, 0.746998, 0.84589094, 2.309214, 0.7193661, 3.8743107, 1.803967, 0.954488, 0.606625, 1.0589919, 0.825987, 1.68639, 3.8063908, 2.0135949, 1.7743869, 0.719241, 2.5303707, 1.111837, 0.67824197, 0.608382, 2.8151786, 0.8309991, 0.700402, 2.9427788, 1.916288, 2.8053885, 0.98357695, 0.960809, 2.0727909, 0.665959, 3.1231186, 0.89392, 1.493945, 2.9798717, 1.680491, 0.93144405, 3.3475633, 3.061061, 0.625492, 2.0062819, 0.912085, 0.84922403, 2.032677, 2.6647837, 2.6843667, 3.5496502, 3.2516859, 0.7810861, 0.781649, 2.9127529, 3.574535, 2.8605855, 0.842729, 3.1535025, 3.1027617, 0.76817507, 2.065398, 0.64963806, 2.8091755, 2.10515, 0.861147, 4.0081344, 0.87898, 2.7346547, 2.316443, 1.133106, 2.0093699, 0.62597203, 0.946564, 1.261854, 1.142085, 3.9425967, 2.952847, 3.1248271, 2.271221, 1.119494, 3.4708366, 1.138131, 0.84457105, 2.8363626, 0.64182407, 3.094734, 1.9187089, 1.9892039, 0.739397, 0.929917, 3.4710286, 0.6732070 ...
# [3.8113213 3.0635605 0.9986839 ... 3.2934608 1.708271  1.2841263]
# (None, None)

# %% [markdown]
# ## Analysis from the PDP -
#     -> OSLO is the only city that consume a tons of electricy compare to the other ctities
#     -> All the other cities might have a normal electricity demand
#     -> It, would be a good experiment, to see, if the deduct Bergen data from the training data set, it might overall improve the model performance
#     -> From the month graph - it seems like, at the end of the year (11, 12), consumption really spikes
#     -> From the day graph - it seems like, on the day (3,4) the consumption spikes
#     -> From the daylight graph - it seems like, if the daylight increase, consumption decrease
#     -> From the holiday graph - it seems like, during the hoiliday consumption increase
#     -> And, all the other feature, doesnt have that much deviative impact

# %% [markdown]
# ## The whole hypothesis, is based on our specific model perforrmance, we we can call it model(technique) dependent
#     -> As we can see from the model performace that, its under performing for some prediction, that is preety low compare to the average demand

# %% [markdown]
# - Try to adjust the training data with all the others finding and see if that improves the performance
# - The hypothesis is that, from the prediction graph, we can see that, mostly our model is not performing well when the consumption is going down
# - For all the spikes, the model is performing well, to solve the problem we could use different hypothesis, we could add some penalize terms to the model for lower consumption mitchmatch
# - Or we could modify some traing data and convert some somple to more lower degree and see how the model perform, Or add some bias(lower consumption example) to the trainign data and see how the model perform.

# %% [markdown]
# # Lets try the data modification

# %%
train_low_demand = data_helper.adjust_train_data(train_6)

# %%
train_low_demand_split_X, train_low_demand_split_Y = data_helper.split_sequences(train_low_demand, config.WINDOW_SIZE)
X_train_low_demand, X_test_low_demand, Y_train_low_demand, Y_test_low_demand = train_test_split(train_low_demand_split_X, train_low_demand_split_Y, test_size=0.2, random_state=0)

# %%
# Retrain the model with the new data
PATH_LOW_DEMAND = f"./data/{city_name}_model_XAI_low_demand"
model_low_demand = model_helper.train_model(np.shape(X_train[0])[-1], X_train_low_demand, Y_train_low_demand, X_test_low_demand,
                               Y_test_low_demand, False, config.BATCH_SIZE, 10, config.PRC_EPOCH, PATH_LOW_DEMAND, True)
# Out:
# the model  ./data/bergen_model_XAI_low_demand has beed loaded !

# %%
# Check the performance
low_demand_model_actual_value, low_demand_model_predicted_value, low_demand_model_RSME_score, low_demand_model_R2_score, low_demand_model_MAE_score, _, _ = model_helper.display_results(
    model_low_demand, X_test_low_demand, Y_test_low_demand, y_scaler, (0, 4), (400, 700))
print(low_demand_model_actual_value), print(low_demand_model_predicted_value)
# Out:
#   0%|          | 0/1690 [00:00<?, ?it/s]
# Rmse lsoss -> 1.1000165981427623
# Mean absolute error -> 0.40757542848587036
# R2 score -> 80.0
# [3.9656365, 2.5778499, 0.704031, 1.017308, 3.3493536, 0.80324394, 1.078285, 2.8752277, 2.1822588, 2.173894, 0.87349397, 3.0633526, 0.697515, 1.610121, 2.3743, 1.32268, 0.61985004, 2.6451066, 0.8653911, 0.56633097, 0.96797997, 3.4271908, 3.7947927, 1.862814, 0.62902206, 0.860125, 3.8195274, 1.889356, 1.1177831, 3.4852526, 1.7511259, 0.817458, 2.4671886, 0.6858451, 3.4166038, 0.949669, 0.72375005, 1.378052, 0.9486661, 3.3294308, 3.3590581, 1.280324, 0.65703094, 0.99554294, 3.027563, 1.729473, 0.7124231, 2.314578, 1.599119, 0.73733205, 3.4737542, 0.817989, 3.3455665, 0.800265, 0.927436, 0.70009404, 0.91826797, 1.6009649, 0.99781704, 3.3950377, 3.4136016, 1.390356, 3.9710715, 0.67657006, 0.83094203, 1.068116, 2.9661076, 0.979498, 0.76639503, 0.90525603, 1.628331, 0.79521406, 0.626634, 0.834003, 1.0049809, 3.3294137, 3.0786195, 2.6575036, 0.92111, 3.4549506, 2.9958467, 3.0888057, 2.785022, 0.701103, 0.93579596, 1.9800259, 2.8852887, 3.1441696, 0.713994, 1.4942771, 3.1590838, 0.6824941, 0.692109, 2.5462875, 2.94786, 0.755005, 0.585936, 1.2119911, 1.0280349, 0.758554, 3.682253, 0.753415, 4.263267, 0.817504, 0.682107, 3.5385802, 0.74375, 0.56759197, 0.844125, 0.842517, 1.2148839, 3.2663414, 3.0903058, 2.9522517, 3.1660736, 0.96936595, 0.903344, 0.89005303, 1.009733, 1.1070011, 0.96517396, 2.9308116, 3.0184247, 0.55027604, 0.818567, 2.4461267, 3.2179782, 4.188716, 3.309701, 0.930122, 3.3901846, 0.80728, 0.796634, 1.019524, 1.037998, 1.6551889, 0.76551104, 2.838388, 2.7495458, 0.71486205, 1.02601, 0.63098603, 1.29242, 0.99542093, 4.0891047, 0.94733196, 2.4116678, 1.635425, 0.83580005, 0.80599105, 4.08049, 0.993811, 0.59258306, 0.82633704, 0.938891, 2.8244996, 3.2382019, 4.003799, 3.4341795, 3.4439485, 3.666772, 0.548946, 4.3198423, 0.78512394, 1.540746, 3.7320254, 3.3123212, 1.120321, 1.626679, 0.622187, 3.9182062, 0.72422504, 0.896341, 0.820917, 2.6561415, 1.152111, 1.055679, 3.3218336, 2.08273, 1.14781, 0.99367106, 0.727688, 2.8660364, 1.8829709, 1.888022, 0.914457, 0.610492, 1.5232121, 0.79257005, 1.0287371, 0.90015, 0.69912696, 0.55593103, 0.87920606, 1.0395551, 1.292357, 1.2449211, 0.669717, 0.64651805, 2.241412, 2.6615496, 2.7613747, 0.842815, 0.9847541, 3.0847487, 1.8621609, 0.876432, 3.8560145, 0.82205904, 3.2339616, 1.016105, 1.4692919, 0.99589896, 2.465633, 3.2830906, 3.619132, 3.5924146, 0.903863, 1.493256, 3.578264, 2.015457, 2.8485277, 3.111382, 0.85292095, 3.646477, 1.046845, 1.277484, 0.554534, 3.0288005, 0.90490603, 0.921015, 3.5578897, 2.2123332, 0.78546107, 0.715569, 0.93824005, 0.99467295, 3.6552455, 0.8213631, 1.733452, 0.9216921, 1.065691, 2.18743, 0.908601, 3.2198977, 3.7081156, 1.960906, 0.832784, 0.855416, 2.416674, 3.2068236, 0.668843, 0.894002, 1.160891, 0.88418794, 3.488469, 3.1904037, 0.80141604, 0.755872, 1.123053, 1.633276, 0.720107, 1.151555, 3.4503326, 0.617041, 0.851597, 3.311465, 0.720233, 3.2408836, 0.87545305, 0.90775007, 2.509572, 0.562626, 0.86650395, 0.8040271, 0.963364, 0.528684, 0.99503195, 3.7662625, 3.6850257, 1.001606, 0.7139981, 4.122393, 1.701745, 3.560271, 3.9276576, 0.998838, 3.061476, 0.746998, 0.84589094, 2.309214, 0.7193661, 3.8743107, 1.803967, 0.954488, 0.606625, 1.0589919, 0.825987, 1.68639, 3.8063908, 2.0135949, 1.7743869, 0.719241, 2.5303707, 1.111837, 0.67824197, 0.608382, 2.8151786, 0.8309991, 0.700402, 2.9427788, 1.916288, 2.8053885, 0.98357695, 0.960809, 2.0727909, 0.665959, 3.1231186, 0.89392, 1.493945, 2.9798717, 1.680491, 0.93144405, 3.3475633, 3.061061, 0.625492, 2.0062819, 0.912085, 0.84922403, 2.032677, 2.6647837, 2.6843667, 3.5496502, 3.2516859, 0.7810861, 0.781649, 2.9127529, 3.574535, 2.8605855, 0.842729, 3.1535025, 3.1027617, 0.76817507, 2.065398, 0.64963806, 2.8091755, 2.10515, 0.861147, 4.0081344, 0.87898, 2.7346547, 2.316443, 1.133106, 2.0093699, 0.62597203, 0.946564, 1.261854, 1.142085, 3.9425967, 2.952847, 3.1248271, 2.271221, 1.119494, 3.4708366, 1.138131, 0.84457105, 2.8363626, 0.64182407, 3.094734, 1.9187089, 1.9892039, 0.739397, 0.929917, 3.4710286, 0.6732070 ...
# [3.0296822  1.9553261  0.10209274 ... 3.3276596  1.8777237  1.5274429 ]
# (None, None)

# %% [markdown]
# ## Base-line model
#
#     -> https://machinelearningmastery.com/persistence-time-series-forecasting-with-python/
#
# ## Skill score
#
# You are told that your skill score for temperature forecasts last month was +0.25 (25%). The standard forecast used for comparison was in error by 2 degrees on average. This means:
#
#     -> Your error is 0.25 degrees smaller than the standard score.
#     -> The error of your forecasts is 2.5 degrees.
#     -> The error of your forecasts is 1.5 degrees.

# %%
base_line_model_predicted_value, base_line_model_actual_value = model_helper.model_base_line(X_test_base, Y_test_base, y_scaler)
base_line_model_MAE_score = np.mean(np.abs(np.subtract(base_line_model_actual_value, base_line_model_predicted_value)))
print(f"Base model MAE - {base_line_model_MAE_score}")
# Out:
# Base model MAE - 1.1846717214391582

# %% [markdown]
#  * Base model skill

# %%
base_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, base_model_predicted_value, base_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.8296418407186851

# %% [markdown]
#  * Noise model skill

# %%
noise_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, noise_model_predicted_value, noise_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.8190613145673107

# %% [markdown]
#  * Low-demnad model skill

# %%
low_demand_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, low_demand_model_predicted_value, low_demand_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.7164345465946372

# %% [markdown]
# ## Cross validation

# %%
matrix_cv_base = model_helper.cross_validation(X_train, Y_train, 10, y_scaler, (-0.4, 4))
matrix_cv_noise = model_helper.cross_validation(X_train_with_noise, Y_train, 10, y_scaler, (0.4, 4.0))
matrix_cv_low_demand = model_helper.cross_validation(X_train_low_demand, Y_train_low_demand, 10, y_scaler, (0, 4))
# Out:
# Training...
# Train_loss 0.58464400, Test loss : 0.55346394, Epoch 1
# Train_loss 0.57155728, Test loss : 0.53796953, Epoch 2
# Train_loss 0.56956403, Test loss : 0.53467600, Epoch 3
# Train_loss 0.56925362, Test loss : 0.53051070, Epoch 4
# Train_loss 0.56910721, Test loss : 0.52669774, Epoch 5
# Train_loss 0.56683524, Test loss : 0.52638488, Epoch 6
# Train_loss 0.56694524, Test loss : 0.52597425, Epoch 7
# Train_loss 0.56682038, Test loss : 0.52552374, Epoch 8
# Train_loss 0.56689839, Test loss : 0.52509572, Epoch 9
# Train_loss 0.56685049, Test loss : 0.52466286, Epoch 10
# Rmse lsoss -> 1.1028093356451663
# Mean absolute error -> 0.6039097905158997
# R2 score -> 61.0
# Training...
# Train_loss 0.58966878, Test loss : 0.53938347, Epoch 1
# Train_loss 0.58388222, Test loss : 0.53266986, Epoch 2
# Train_loss 0.58187427, Test loss : 0.52866359, Epoch 3
# Train_loss 0.58191067, Test loss : 0.52547369, Epoch 4
# Train_loss 0.58176510, Test loss : 0.52284024, Epoch 5
# Train_loss 0.57997402, Test loss : 0.52184338, Epoch 6
# Train_loss 0.57970470, Test loss : 0.52108744, Epoch 7
# Train_loss 0.57959159, Test loss : 0.52052908, Epoch 8
# Train_loss 0.57961092, Test loss : 0.52010002, Epoch 9
# Train_loss 0.57960768, Test loss : 0.51971573, Epoch 10
# Rmse lsoss -> 1.0937004623094013
# Mean absolute error -> 0.624615490436554
# R2 score -> 59.0
# Training...
# Train_loss 0.60223339, Test loss : 0.54091194, Epoch 1
# Train_loss 0.57282625, Test loss : 0.53769768, Epoch 2
# Train_loss 0.57217270, Test loss : 0.53484241, Epoch 3
# Train_loss 0.57238457, Test loss : 0.53214189, Epoch 4
# Train_loss 0.57219610, Test loss : 0.52983004, Epoch 5
# Train_loss 0.57110428, Test loss : 0.52973163, Epoch 6
# Train_loss 0.57107573, Test loss : 0.52952447, Epoch 7
# Train_loss 0.57112488, Test loss : 0.52930591, Epoch 8
# Train_loss 0.57109827, Test loss : 0.52909202, Epoch 9
# Train_loss 0.57108415, Test loss : 0.52886376, Epoch 10
# Rmse lsoss -> 1.1132341341455345
# Mean absolute error -> 0.5939998626708984
# R2 score -> 59.0
# Training...
# Train_loss 0.58842577, Test loss : 0.56174185, Epoch 1
# Train_loss 0.56305531, Test loss : 0.55271041, Epoch 2
# Train_loss 0.56377424, Test loss : 0.54825127, Epoch 3
# Train_loss 0.56350248, Test loss : 0.54428942, Epoch 4
# Train_loss 0.56336856, Test loss : 0.54115635, Epoch 5
# Train_loss 0.56270546, Test loss : 0.54095886, Epoch 6
# Train_loss 0.56252420, Test loss : 0.54077193, Epoch 7
# Train_loss 0.56254245, Test loss : 0.54057396, Epoch 8
# Train_loss 0.56246840, Test loss : 0.54029961, Epoch 9
# Train_loss 0.56243316, Test loss : 0.54004301, Epoch 10
# Rmse lsoss -> 1.1359755455897445
# Mean absolute error -> 0.5629345178604126
# R2 score -> 70.0
# Training...
# Train_loss 0.58386963, Test loss : 0.55768594, Epoch 1
# Train_loss 0.57297878, Test loss : 0.55461851, Epoch 2
# Train_loss 0.57217986, Test loss : 0.55217750, Epoch 3
# Train_loss 0.57226595, Test loss : 0.54941438, Epoch 4
# Train_loss 0.57209581, Test loss : 0.54718412, Epoch 5
# Train_loss 0.57085496, Test loss : 0.54708360, Epoch 6
# Train_loss 0.57087571, Test loss : 0.54687301, Epoch 7
# Train_loss 0.57089071, Test loss : 0.54663901, Epoch 8
# Train_loss 0.57086331, Test loss : 0.54638105, Epoch 9
# Train_loss 0.57086340, Test loss : 0.54613578, Epoch 10
# Rmse lsoss -> 1.1489502676815873
# Mean absolute error -> 0.6212981343269348
# R2 score -> 61.0
# Training...
# Train_loss 0.57444568, Test loss : 0.58714067, Epoch 1
# Train_loss 0.56761809, Test loss : 0.58229179, Epoch 2
# Train_loss 0.56771397, Test loss : 0.57729365, Epoch 3
# Train_loss 0.56744340, Test loss : 0.57353647, Epoch 4
# Train_loss 0.56743409, Test loss : 0.57060840, Epoch 5
# Train_loss 0.56675841, Test loss : 0.57038354, Epoch 6
# Train_loss 0.56678734, Test loss : 0.57006541, Epoch 7
# Train_loss 0.56675546, Test loss : 0.56980971, Epoch 8
# Train_loss 0.56680307, Test loss : 0.56960880, Epoch 9
# Train_loss 0.56678390, Test loss : 0.56943112, Epoch 10
# Rmse lsoss -> 1.1959353550756402
# Mean absolute error -> 0.6720729470252991
# R2 score -> 55.00000000000001
# Training...
# Train_loss 0.60040690, Test loss : 0.55535829, Epoch 1
# Train_loss 0.57271803, Test loss : 0.54376919, Epoch 2
# Train_loss 0.57216574, Test loss : 0.54033296, Epoch 3
# Train_loss 0.57184644, Test loss : 0.53750887, Epoch 4
# Train_loss 0.57178232, Test loss : 0.53527204, Epoch 5
# Train_loss 0.57085168, Test loss : 0.53485383, Epoch 6
# Train_loss 0.57075104, Test loss : 0.53448503, Epoch 7
# Train_loss 0.57071329, Test loss : 0.53419436, Epoch 8
# Train_loss 0.57068848, Test loss : 0.53391484, Epoch 9
# Train_loss 0.57072362, Test loss : 0.53366058, Epoch 10
# Rmse lsoss -> 1.1225012473798248
# Mean absolute error -> 0.5303259491920471
# R2 score -> 68.0
# Training...
# Train_loss 0.59605971, Test loss : 0.54900908, Epoch 1
# Train_loss 0.57760949, Test loss : 0.54252258, Epoch 2
# Train_loss 0.57752684, Test loss : 0.53924933, Epoch 3
# Train_loss 0.57722840, Test loss : 0.53618203, Epoch 4
# Train_loss 0.57724931, Test loss : 0.53335184, Epoch 5
# Train_loss 0.57625162, Test loss : 0.53317859, Epoch 6
# Train_loss 0.57622708, Test loss : 0.53299952, Epoch 7
# Train_loss 0.57627681, Test loss : 0.53279238, Epoch 8
# Train_loss 0.57634808, Test loss : 0.53254528, Epoch 9
# Train_loss 0.57633889, Test loss : 0.53230098, Epoch 10
# Rmse lsoss -> 1.1196231035031432
# Mean absolute error -> 0.5205854773521423
# R2 score -> 70.0
# Training...
# Train_loss 0.58150644, Test loss : 0.56798465, Epoch 1
# Train_loss 0.57771886, Test loss : 0.54697346, Epoch 2
# Train_loss 0.57202754, Test loss : 0.54692524, Epoch 3
# Train_loss 0.57281364, Test loss : 0.54390756, Epoch 4
# Train_loss 0.57249589, Test loss : 0.54187646, Epoch 5
# Train_loss 0.57027400, Test loss : 0.53900815, Epoch 6
# Train_loss 0.56965632, Test loss : 0.53658124, Epoch 7
# Train_loss 0.56925623, Test loss : 0.53516182, Epoch 8
# Train_loss 0.56908547, Test loss : 0.53426231, Epoch 9
# Train_loss 0.56897014, Test loss : 0.53359060, Epoch 10
# Rmse lsoss -> 1.11977987357147
# Mean absolute error -> 0.4665103554725647
# R2 score -> 77.0
# Training...
# Train_loss 0.58841847, Test loss : 0.58667612, Epoch 1
# Train_loss 0.57023899, Test loss : 0.57827373, Epoch 2
# Train_loss 0.57088326, Test loss : 0.57626937, Epoch 3
# Train_loss 0.57071687, Test loss : 0.57433972, Epoch 4
# Train_loss 0.57062916, Test loss : 0.57256408, Epoch 5
# Train_loss 0.56989345, Test loss : 0.57373179, Epoch 6
# Train_loss 0.56958220, Test loss : 0.57474571, Epoch 7
# Train_loss 0.56950703, Test loss : 0.57519425, Epoch 8
# Train_loss 0.56939032, Test loss : 0.57528914, Epoch 9
# Train_loss 0.56940699, Test loss : 0.57520878, Epoch 10
# Rmse lsoss -> 1.2085038864963396
# Mean absolute error -> 0.8071509599685669
# R2 score -> 40.0
# Training...
# Train_loss 0.57821053, Test loss : 0.54896848, Epoch 1
# Train_loss 0.57091488, Test loss : 0.53718727, Epoch 2
# Train_loss 0.56937167, Test loss : 0.53386477, Epoch 3
# Train_loss 0.56917895, Test loss : 0.52972519, Epoch 4
# Train_loss 0.56901859, Test loss : 0.52588406, Epoch 5
# Train_loss 0.56691313, Test loss : 0.52554373, Epoch 6
# Train_loss 0.56689696, Test loss : 0.52504288, Epoch 7
# Train_loss 0.56686303, Test loss : 0.52457015, Epoch 8
# Train_loss 0.56682486, Test loss : 0.52408247, Epoch 9
# Train_loss 0.56679103, Test loss : 0.52360797, Epoch 10
# Rmse lsoss -> 1.1031342784286062
# Mean absolute error -> 0.4478585720062256
# R2 score -> 75.0
# Training...
# Train_loss 0.58803920, Test loss : 0.53510646, Epoch 1
# Train_loss 0.58387834, Test loss : 0.53121488, Epoch 2
# Train_loss 0.58201980, Test loss : 0.52778183, Epoch 3
# Train_loss 0.58189183, Test loss : 0.52510917, Epoch 4
# Train_loss 0.58179996, Test loss : 0.52259928, Epoch 5
# Train_loss 0.57989619, Test loss : 0.52165816, Epoch 6
# Train_loss 0.57966978, Test loss : 0.52095765, Epoch 7
# Train_loss 0.57953152, Test loss : 0.52044795, Epoch 8
# Train_loss 0.57953155, Test loss : 0.52003721, Epoch 9
# Train_loss 0.57955409, Test loss : 0.51966770, Epoch 10
# Rmse lsoss -> 1.091978873436262
# Mean absolute error -> 0.5491839647293091
# R2 score -> 63.0
# Training...
# Train_loss 0.60302993, Test loss : 0.54015789, Epoch 1
# Train_loss 0.57237280, Test loss : 0.53580063, Epoch 2
# Train_loss 0.57204945, Test loss : 0.53196732, Epoch 3
# Train_loss 0.57207612, Test loss : 0.52891634, Epoch 4
# Train_loss 0.57198272, Test loss : 0.52630887, Epoch 5
# Train_loss 0.57099680, Test loss : 0.52621486, Epoch 6
# Train_loss 0.57105173, Test loss : 0.52602462, Epoch 7
# Train_loss 0.57098643, Test loss : 0.52581240, Epoch 8
# Train_loss 0.57097341, Test loss : 0.52559116, Epoch 9
# Train_loss 0.57100391, Test loss : 0.52538941, Epoch 10
# Rmse lsoss -> 1.1053553007433166
# Mean absolute error -> 0.3621864318847656
# R2 score -> 84.0
# Training...
# Train_loss 0.58074863, Test loss : 0.55782695, Epoch 1
# Train_loss 0.56307201, Test loss : 0.55005885, Epoch 2
# Train_loss 0.56358123, Test loss : 0.54546313, Epoch 3
# Train_loss 0.56355432, Test loss : 0.54234555, Epoch 4
# Train_loss 0.56344234, Test loss : 0.54057109, Epoch 5
# Train_loss 0.56282852, Test loss : 0.54045401, Epoch 6
# Train_loss 0.56268057, Test loss : 0.54036023, Epoch 7
# Train_loss 0.56257772, Test loss : 0.54021292, Epoch 8
# Train_loss 0.56251026, Test loss : 0.54001895, Epoch 9
# Train_loss 0.56247626, Test loss : 0.53984883, Epoch 10
# Rmse lsoss -> 1.1339799324392772
# Mean absolute error -> 0.565922200679779
# R2 score -> 63.0
# Training...
# Train_loss 0.59874907, Test loss : 0.55633196, Epoch 1
# Train_loss 0.57270379, Test loss : 0.55336006, Epoch 2
# Train_loss 0.57193429, Test loss : 0.54994539, Epoch 3
# Train_loss 0.57212598, Test loss : 0.54731245, Epoch 4
# Train_loss 0.57196038, Test loss : 0.54529843, Epoch 5
# Train_loss 0.57086416, Test loss : 0.54525009, Epoch 6
# Train_loss 0.57077707, Test loss : 0.54503846, Epoch 7
# Train_loss 0.57081304, Test loss : 0.54484470, Epoch 8
# Train_loss 0.57076504, Test loss : 0.54461957, Epoch 9
# Train_loss 0.57078658, Test loss : 0.54443025, Epoch 10
# Rmse lsoss -> 1.146559080845041
# Mean absolute error -> 0.5165717601776123
# R2 score -> 68.0
# Training...
# Train_loss 0.57730570, Test loss : 0.59276363, Epoch 1
# Train_loss 0.56799101, Test loss : 0.58586659, Epoch 2
# Train_loss 0.56779684, Test loss : 0.58153403, Epoch 3
# Train_loss 0.56748099, Test loss : 0.57773381, Epoch 4
# Train_loss 0.56738294, Test loss : 0.57435119, Epoch 5
# Train_loss 0.56690742, Test loss : 0.57404506, Epoch 6
# Train_loss 0.56690047, Test loss : 0.57367192, Epoch 7
# Train_loss 0.56686370, Test loss : 0.57338002, Epoch 8
# Train_loss 0.56685720, Test loss : 0.57309925, Epoch 9
# Train_loss 0.56687481, Test loss : 0.57283723, Epoch 10
# Rmse lsoss -> 1.2058994950125541
# Mean absolute error -> 0.57328200340271
# R2 score -> 57.99999999999999
# Training...
# Train_loss 0.59885005, Test loss : 0.55057543, Epoch 1
# Train_loss 0.57254401, Test loss : 0.54217282, Epoch 2
# Train_loss 0.57217487, Test loss : 0.53905274, Epoch 3
# Train_loss 0.57191867, Test loss : 0.53672658, Epoch 4
# Train_loss 0.57178011, Test loss : 0.53480131, Epoch 5
# Train_loss 0.57086439, Test loss : 0.53442132, Epoch 6
# Train_loss 0.57070961, Test loss : 0.53410813, Epoch 7
# Train_loss 0.57076266, Test loss : 0.53388305, Epoch 8
# Train_loss 0.57076792, Test loss : 0.53368021, Epoch 9
# Train_loss 0.57079376, Test loss : 0.53351176, Epoch 10
# Rmse lsoss -> 1.122960785592985
# Mean absolute error -> 0.5780066251754761
# R2 score -> 56.99999999999999
# Training...
# Train_loss 0.58519354, Test loss : 0.54499589, Epoch 1
# Train_loss 0.57732748, Test loss : 0.54189623, Epoch 2
# Train_loss 0.57734964, Test loss : 0.53964434, Epoch 3
# Train_loss 0.57718608, Test loss : 0.53743897, Epoch 4
# Train_loss 0.57713512, Test loss : 0.53519487, Epoch 5
# Train_loss 0.57638859, Test loss : 0.53507627, Epoch 6
# Train_loss 0.57635581, Test loss : 0.53492827, Epoch 7
# Train_loss 0.57628052, Test loss : 0.53471373, Epoch 8
# Train_loss 0.57630158, Test loss : 0.53449727, Epoch 9
# Train_loss 0.57634567, Test loss : 0.53427784, Epoch 10
# Rmse lsoss -> 1.123141183625103
# Mean absolute error -> 0.586307942867279
# R2 score -> 61.0
# Training...
# Train_loss 0.57685380, Test loss : 0.57013553, Epoch 1
# Train_loss 0.57752870, Test loss : 0.54986838, Epoch 2
# Train_loss 0.57228393, Test loss : 0.54957202, Epoch 3
# Train_loss 0.57292353, Test loss : 0.54659632, Epoch 4
# Train_loss 0.57249454, Test loss : 0.54429218, Epoch 5
# Train_loss 0.57033924, Test loss : 0.54133040, Epoch 6
# Train_loss 0.56973690, Test loss : 0.53886078, Epoch 7
# Train_loss 0.56934904, Test loss : 0.53729375, Epoch 8
# Train_loss 0.56920149, Test loss : 0.53626220, Epoch 9
# Train_loss 0.56913651, Test loss : 0.53549487, Epoch 10
# Rmse lsoss -> 1.1268006854696089
# Mean absolute error -> 0.3177616596221924
# R2 score -> 87.0
# Training...
# Train_loss 0.59719811, Test loss : 0.58829031, Epoch 1
# Train_loss 0.57007743, Test loss : 0.57400589, Epoch 2
# Train_loss 0.57079997, Test loss : 0.57051289, Epoch 3
# Train_loss 0.57063108, Test loss : 0.56773038, Epoch 4
# Train_loss 0.57058613, Test loss : 0.56541517, Epoch 5
# Train_loss 0.56975588, Test loss : 0.56660347, Epoch 6
# Train_loss 0.56934855, Test loss : 0.56764100, Epoch 7
# Train_loss 0.56921076, Test loss : 0.56807279, Epoch 8
# Train_loss 0.56919117, Test loss : 0.56810847, Epoch 9
# Train_loss 0.56920551, Test loss : 0.56800412, Epoch 10
# Rmse lsoss -> 1.1932905960865858
# Mean absolute error -> 0.5145046710968018
# R2 score -> 73.0
# Training...
# Train_loss 0.57877146, Test loss : 0.53827934, Epoch 1
# Train_loss 0.57077864, Test loss : 0.52827798, Epoch 2
# Train_loss 0.56899895, Test loss : 0.52398758, Epoch 3
# Train_loss 0.56904056, Test loss : 0.52016004, Epoch 4
# Train_loss 0.56885770, Test loss : 0.51721132, Epoch 5
# Train_loss 0.56695628, Test loss : 0.51696018, Epoch 6
# Train_loss 0.56682377, Test loss : 0.51668486, Epoch 7
# Train_loss 0.56679277, Test loss : 0.51637225, Epoch 8
# Train_loss 0.56687430, Test loss : 0.51613730, Epoch 9
# Train_loss 0.56681995, Test loss : 0.51588670, Epoch 10
# Rmse lsoss -> 1.0941941585607273
# Mean absolute error -> 0.5003209114074707
# R2 score -> 72.0
# Training...
# Train_loss 0.59029634, Test loss : 0.53674859, Epoch 1
# Train_loss 0.58336885, Test loss : 0.53061032, Epoch 2
# Train_loss 0.58169125, Test loss : 0.52749245, Epoch 3
# Train_loss 0.58181643, Test loss : 0.52390900, Epoch 4
# Train_loss 0.58160930, Test loss : 0.52034524, Epoch 5
# Train_loss 0.57999174, Test loss : 0.51976980, Epoch 6
# Train_loss 0.57976951, Test loss : 0.51928019, Epoch 7
# Train_loss 0.57966348, Test loss : 0.51884119, Epoch 8
# Train_loss 0.57961459, Test loss : 0.51844163, Epoch 9
# Train_loss 0.57964930, Test loss : 0.51805090, Epoch 10
# Rmse lsoss -> 1.0926053188023437
# Mean absolute error -> 0.3626932203769684
# R2 score -> 83.0
# Training...
# Train_loss 0.59371178, Test loss : 0.54224336, Epoch 1
# Train_loss 0.57368616, Test loss : 0.53825564, Epoch 2
# Train_loss 0.57323516, Test loss : 0.53337863, Epoch 3
# Train_loss 0.57332824, Test loss : 0.53005704, Epoch 4
# Train_loss 0.57330408, Test loss : 0.52790921, Epoch 5
# Train_loss 0.57223432, Test loss : 0.52792806, Epoch 6
# Train_loss 0.57220493, Test loss : 0.52780882, Epoch 7
# Train_loss 0.57225879, Test loss : 0.52767375, Epoch 8
# Train_loss 0.57222924, Test loss : 0.52750634, Epoch 9
# Train_loss 0.57220762, Test loss : 0.52735138, Epoch 10
# Rmse lsoss -> 1.1175470907201681
# Mean absolute error -> 0.41367238759994507
# R2 score -> 81.0
# Training...
# Train_loss 0.58728546, Test loss : 0.55278764, Epoch 1
# Train_loss 0.56333936, Test loss : 0.54749056, Epoch 2
# Train_loss 0.56407252, Test loss : 0.54370029, Epoch 3
# Train_loss 0.56374720, Test loss : 0.54058496, Epoch 4
# Train_loss 0.56374149, Test loss : 0.53849016, Epoch 5
# Train_loss 0.56314414, Test loss : 0.53808713, Epoch 6
# Train_loss 0.56299683, Test loss : 0.53775396, Epoch 7
# Train_loss 0.56295615, Test loss : 0.53751585, Epoch 8
# Train_loss 0.56297061, Test loss : 0.53732027, Epoch 9
# Train_loss 0.56297037, Test loss : 0.53716963, Epoch 10
# Rmse lsoss -> 1.1333373859744449
# Mean absolute error -> 0.4096103012561798
# R2 score -> 79.0
# Training...
# Train_loss 0.58462187, Test loss : 0.55073442, Epoch 1
# Train_loss 0.57272801, Test loss : 0.54985499, Epoch 2
# Train_loss 0.57227766, Test loss : 0.54644434, Epoch 3
# Train_loss 0.57233473, Test loss : 0.54361264, Epoch 4
# Train_loss 0.57228147, Test loss : 0.54158794, Epoch 5
# Train_loss 0.57120273, Test loss : 0.54158513, Epoch 6
# Train_loss 0.57119727, Test loss : 0.54143736, Epoch 7
# Train_loss 0.57121535, Test loss : 0.54127645, Epoch 8
# Train_loss 0.57121629, Test loss : 0.54110819, Epoch 9
# Train_loss 0.57121590, Test loss : 0.54093387, Epoch 10
# Rmse lsoss -> 1.1470214001921584
# Mean absolute error -> 0.3829958140850067
# R2 score -> 83.0
# Training...
# Train_loss 0.58054672, Test loss : 0.59140921, Epoch 1
# Train_loss 0.56858085, Test loss : 0.58141184, Epoch 2
# Train_loss 0.56769375, Test loss : 0.57652257, Epoch 3
# Train_loss 0.56755054, Test loss : 0.57176611, Epoch 4
# Train_loss 0.56753335, Test loss : 0.56858376, Epoch 5
# Train_loss 0.56698032, Test loss : 0.56836575, Epoch 6
# Train_loss 0.56694272, Test loss : 0.56809100, Epoch 7
# Train_loss 0.56699664, Test loss : 0.56786351, Epoch 8
# Train_loss 0.56699786, Test loss : 0.56765404, Epoch 9
# Train_loss 0.56699655, Test loss : 0.56744849, Epoch 10
# Rmse lsoss -> 1.1987536395100227
# Mean absolute error -> 0.45451393723487854
# R2 score -> 75.0
# Training...
# Train_loss 0.59327767, Test loss : 0.54127204, Epoch 1
# Train_loss 0.57274765, Test loss : 0.53628052, Epoch 2
# Train_loss 0.57247357, Test loss : 0.53334977, Epoch 3
# Train_loss 0.57238081, Test loss : 0.53124038, Epoch 4
# Train_loss 0.57240450, Test loss : 0.52969284, Epoch 5
# Train_loss 0.57136722, Test loss : 0.52948952, Epoch 6
# Train_loss 0.57136455, Test loss : 0.52934701, Epoch 7
# Train_loss 0.57129687, Test loss : 0.52921278, Epoch 8
# Train_loss 0.57135225, Test loss : 0.52909186, Epoch 9
# Train_loss 0.57133373, Test loss : 0.52895138, Epoch 10
# Rmse lsoss -> 1.1227437812804535
# Mean absolute error -> 0.8788511753082275
# R2 score -> 27.0
# Training...
# Train_loss 0.60008897, Test loss : 0.53932449, Epoch 1
# Train_loss 0.57833369, Test loss : 0.53378387, Epoch 2
# Train_loss 0.57790053, Test loss : 0.53027917, Epoch 3
# Train_loss 0.57782508, Test loss : 0.52774578, Epoch 4
# Train_loss 0.57781288, Test loss : 0.52575648, Epoch 5
# Train_loss 0.57713513, Test loss : 0.52556190, Epoch 6
# Train_loss 0.57713176, Test loss : 0.52539599, Epoch 7
# Train_loss 0.57708197, Test loss : 0.52524925, Epoch 8
# Train_loss 0.57707655, Test loss : 0.52510622, Epoch 9
# Train_loss 0.57709817, Test loss : 0.52499221, Epoch 10
# Rmse lsoss -> 1.1132886919810199
# Mean absolute error -> 0.6018333435058594
# R2 score -> 56.99999999999999
# Training...
# Train_loss 0.57962180, Test loss : 0.56636029, Epoch 1
# Train_loss 0.57753473, Test loss : 0.54167380, Epoch 2
# Train_loss 0.57192308, Test loss : 0.53965111, Epoch 3
# Train_loss 0.57273702, Test loss : 0.53430007, Epoch 4
# Train_loss 0.57234229, Test loss : 0.53085731, Epoch 5
# Train_loss 0.57027209, Test loss : 0.52870883, Epoch 6
# Train_loss 0.56971253, Test loss : 0.52689181, Epoch 7
# Train_loss 0.56937114, Test loss : 0.52570940, Epoch 8
# Train_loss 0.56922826, Test loss : 0.52488085, Epoch 9
# Train_loss 0.56913782, Test loss : 0.52427740, Epoch 10
# Rmse lsoss -> 1.1076556031425266
# Mean absolute error -> 0.5417327284812927
# R2 score -> 65.0
# Training...
# Train_loss 0.59266693, Test loss : 0.58630482, Epoch 1
# Train_loss 0.57029177, Test loss : 0.57396332, Epoch 2
# Train_loss 0.57092472, Test loss : 0.57095090, Epoch 3
# Train_loss 0.57062116, Test loss : 0.56732114, Epoch 4
# Train_loss 0.57052030, Test loss : 0.56415666, Epoch 5
# Train_loss 0.56984676, Test loss : 0.56480146, Epoch 6
# Train_loss 0.56950888, Test loss : 0.56539595, Epoch 7
# Train_loss 0.56940874, Test loss : 0.56559303, Epoch 8
# Train_loss 0.56932001, Test loss : 0.56553931, Epoch 9
# Train_loss 0.56931470, Test loss : 0.56538046, Epoch 10
# Rmse lsoss -> 1.1910994838319873
# Mean absolute error -> 0.5718967318534851
# R2 score -> 67.0

# %%
print([item[-1] for item in matrix_cv_base])
print([item[-3] for item in matrix_cv_base])

print([item[-1] for item in matrix_cv_noise])
print([item[-3] for item in matrix_cv_noise])

print([item[-1] for item in matrix_cv_low_demand])
print([item[-3] for item in matrix_cv_low_demand])
# Out:
# [0.6039098, 0.6246155, 0.59399986, 0.5629345, 0.62129813, 0.67207295, 0.53032595, 0.5205855, 0.46651036, 0.80715096]
# [1.1028093356451663, 1.0937004623094013, 1.1132341341455345, 1.1359755455897445, 1.1489502676815873, 1.1959353550756402, 1.1225012473798248, 1.1196231035031432, 1.11977987357147, 1.2085038864963396]
# [0.44785857, 0.54918396, 0.36218643, 0.5659222, 0.51657176, 0.573282, 0.5780066, 0.58630794, 0.31776166, 0.5145047]
# [1.1031342784286062, 1.091978873436262, 1.1053553007433166, 1.1339799324392772, 1.146559080845041, 1.2058994950125541, 1.122960785592985, 1.123141183625103, 1.1268006854696089, 1.1932905960865858]
# [0.5003209, 0.36269322, 0.4136724, 0.4096103, 0.3829958, 0.45451394, 0.8788512, 0.60183334, 0.5417327, 0.57189673]
# [1.0941941585607273, 1.0926053188023437, 1.1175470907201681, 1.1333373859744449, 1.1470214001921584, 1.1987536395100227, 1.1227437812804535, 1.1132886919810199, 1.1076556031425266, 1.1910994838319873]

# %%
print(np.average([item[-2] for item in matrix_cv_base]))
print(np.average([item[-2] for item in matrix_cv_noise]))
print(np.average([item[-2] for item in matrix_cv_low_demand]))
# Out:
# 62.0
# 68.9
# 68.9

# %%
matrix_cv_base_MAE = [item[-1] for item in matrix_cv_base]
matrix_cv_noise_MAE = [item[-1] for item in matrix_cv_noise]
matrix_cv_low_demand_MAE = [item[-1] for item in matrix_cv_low_demand]

# %%
print([item[-2] for item in matrix_cv_base])
print([item[-2] for item in matrix_cv_noise])
print([item[-2] for item in matrix_cv_low_demand])
# Out:
# [61.0, 59.0, 59.0, 70.0, 61.0, 55.00000000000001, 68.0, 70.0, 77.0, 40.0]
# [75.0, 63.0, 84.0, 63.0, 68.0, 57.99999999999999, 56.99999999999999, 61.0, 87.0, 73.0]
# [72.0, 83.0, 81.0, 79.0, 83.0, 75.0, 27.0, 56.99999999999999, 65.0, 67.0]

# %%
print(stats.ttest_ind([item[-2] for item in matrix_cv_base], [item[-2] for item in matrix_cv_noise]))
print(stats.ttest_ind([item[-2] for item in matrix_cv_base], [item[-2] for item in matrix_cv_low_demand]))
print(stats.ttest_ind([item[-2] for item in matrix_cv_noise], [item[-2] for item in matrix_cv_low_demand]))
# Out:
# Ttest_indResult(statistic=-1.4843000678254388, pvalue=0.15503039377060426)
# Ttest_indResult(statistic=-1.0985026893435588, pvalue=0.286462013934937)
# Ttest_indResult(statistic=0.0, pvalue=1.0)

# %% [markdown]
#  * Summery

# %%
summery.update({ city_name: {
    "base_model": {
        "skill_score": base_model_skill,
        "MAE_score": base_model_MAE_score,
        "RMSE_score": base_model_RSME_score,
        "R2_score": base_model_R2_score
    },
    "noise_model": {
        "skill_score": noise_model_skill,
        "MAE_score": noise_model_MAE_score,
        "RMSE_score": noise_model_RSME_score,
        "R2_score": noise_model_R2_score
    },
    "low_demand_model": {
        "skill_score": low_demand_model_skill,
        "MAE_score": low_demand_model_MAE_score,
        "RMSE_score": low_demand_model_RSME_score,
        "R2_score": low_demand_model_R2_score
    }
}})
localStorage.save_to_pkl(summery)

# %% [markdown]
# - KNN, hypothesis

# %% [markdown]
# - Write about the hypothesis

# %% [markdown]
# ## Hypothesis -
#
#     * Apply KNN on the data, and see different ponts in a graph, Find similar ponts(similarity methos) and compare their evaluation and fix the data.
#     * For example, if some points falls within the same cluster and differ by their demand then their might be somw issue, in the training data
#     * Also, write about how difficlut it would be to find the similar points, as time series data works differently compare to the normal data set

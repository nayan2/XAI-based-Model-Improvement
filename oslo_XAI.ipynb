# %% [markdown]
# ## Findings
#     -> We can see different heat map for differnt test data, while most of them have different error rate.
#     -> We can see that the heat map would be different consideing the fact that, error rate is different.
#     -> We would probbaly generate different heat map, for different range of errors.

# %% [markdown]
# ## Research path -
#     -> Ways to improve the model performace using/through/by XAI
# ## Tasks -
#     -> Generate Attention Map
#     -> Do perturbation analysis/ add or remove data points/ Use any classification technique to improve model performance
#     -> Use some other technique using XAI and compare the results
#     -> Propose some novel technique
#     -> Create seperate model for different cities

# %% [markdown]
# ## Writing suggession
#     -> Have to write why, demand forecasting is important
#     -> The money issue, And what we are tring to achieve from the thesis

# %% [markdown]
# # Improvements suggested -
#     -> Add window feature
#     -> Add lag feature from previous week same day
#     -> Add skill score
#     -> Use absolute error for test data
#     -> Use baseline forescast to evaluate the model

# %%
# %reload_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '../helper/')

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from scipy import stats
import data as data_helper
import model as model_helper
import config
import localStorage
# Out:
# Choosen device cuda

# %% [markdown]
# ## Global Variables

# %%
city_name = "oslo"
summery = { city_name: {} }

# %% [markdown]
# ## Load the data

# %%
train = data_helper.load_train_data(city_name)

# %%
train = data_helper.filter_train_data(train)

# %%
train.head()
# Out:
#                     place  temperature    demand
# time
# 2022-04-08 00:00:00  oslo          0.2  3.584066
# 2022-04-08 01:00:00  oslo          0.4  3.549536
# 2022-04-08 02:00:00  oslo          0.0  3.552738
# 2022-04-08 03:00:00  oslo         -0.4  3.638570
# 2022-04-08 04:00:00  oslo         -0.5  3.929940

# %% [markdown]
# # Data analysis

# %%
data_helper.show_density_plot(train)

# %%
train.isna().sum()
# Out:
# place          0
# temperature    0
# demand         0
# dtype: int64

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# - Time Feature Extraction\
#   -> Year\
#   -> month_cos\
#   -> month_sin\
#   -> day_cos\
#   -> day_sin\
#   -> hour_cos\
#   -> hour_sin\
#   -> Public holiday or not\
#   -> Daylight savings or not\
#   -> Weekend or not\
#   -> Business hour or not\
#   -> Season of the year

# %%
train_1 = data_helper.add_feature(train)

# %%
train_1.head()
# Out:
#                     place  temperature    demand  month_sin  month_cos  \
# time
# 2022-04-08 00:00:00  oslo          0.2  3.584066   0.866025       -0.5
# 2022-04-08 01:00:00  oslo          0.4  3.549536   0.866025       -0.5
# 2022-04-08 02:00:00  oslo          0.0  3.552738   0.866025       -0.5
# 2022-04-08 03:00:00  oslo         -0.4  3.638570   0.866025       -0.5
# 2022-04-08 04:00:00  oslo         -0.5  3.929940   0.866025       -0.5
#
#                       day_sin   day_cos  hour_sin  hour_cos  business_hour  \
# time
# 2022-04-08 00:00:00  0.993257 -0.115935  0.000000  1.000000              0
# 2022-04-08 01:00:00  0.993257 -0.115935  0.269797  0.962917              0
# 2022-04-08 02:00:00  0.993257 -0.115935  0.519584  0.854419              0
# 2022-04-08 03:00:00  0.993257 -0.115935  0.730836  0.682553              0
# 2022-04-08 04:00:00  0.993257 -0.115935  0.887885  0.460065              0
#
#                      season  weekend  daylight  holiday
# time
# 2022-04-08 00:00:00  spring        0         1        0
# 2022-04-08 01:00:00  spring        0         1        0
# 2022-04-08 02:00:00  spring        0         1        0
# 2022-04-08 03:00:00  spring        0         1        0
# 2022-04-08 04:00:00  spring        0         1        0

# %% [markdown]
# - One hot encode

# %%
train_2 = data_helper.one_hot_encoding(train_1, ['season'])

# %%
train_2.head()
# Out:
#                     place  temperature    demand  month_sin  month_cos  \
# time
# 2022-04-08 00:00:00  oslo          0.2  3.584066   0.866025       -0.5
# 2022-04-08 01:00:00  oslo          0.4  3.549536   0.866025       -0.5
# 2022-04-08 02:00:00  oslo          0.0  3.552738   0.866025       -0.5
# 2022-04-08 03:00:00  oslo         -0.4  3.638570   0.866025       -0.5
# 2022-04-08 04:00:00  oslo         -0.5  3.929940   0.866025       -0.5
#
#                       day_sin   day_cos  hour_sin  hour_cos  business_hour  \
# time
# 2022-04-08 00:00:00  0.993257 -0.115935  0.000000  1.000000              0
# 2022-04-08 01:00:00  0.993257 -0.115935  0.269797  0.962917              0
# 2022-04-08 02:00:00  0.993257 -0.115935  0.519584  0.854419              0
# 2022-04-08 03:00:00  0.993257 -0.115935  0.730836  0.682553              0
# 2022-04-08 04:00:00  0.993257 -0.115935  0.887885  0.460065              0
#
#                      weekend  daylight  holiday  autumn  spring  summer
# time
# 2022-04-08 00:00:00        0         1        0       0       1       0
# 2022-04-08 01:00:00        0         1        0       0       1       0
# 2022-04-08 02:00:00        0         1        0       0       1       0
# 2022-04-08 03:00:00        0         1        0       0       1       0
# 2022-04-08 04:00:00        0         1        0       0       1       0

# %% [markdown]
# - Scale the data

# %%
x_scaler, y_scaler, train_3 = data_helper.scale(train_2)

# %%
train_3.head()
# Out:
#                      autumn  business_hour   day_cos   day_sin  daylight  \
# time
# 2022-04-08 00:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 01:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 02:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 03:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 04:00:00       0              0 -0.115935  0.993257         1
#
#                      holiday  hour_cos  hour_sin  month_cos  month_sin place  \
# time
# 2022-04-08 00:00:00        0  1.000000  0.000000       -0.5   0.866025  oslo
# 2022-04-08 01:00:00        0  0.962917  0.269797       -0.5   0.866025  oslo
# 2022-04-08 02:00:00        0  0.854419  0.519584       -0.5   0.866025  oslo
# 2022-04-08 03:00:00        0  0.682553  0.730836       -0.5   0.866025  oslo
# 2022-04-08 04:00:00        0  0.460065  0.887885       -0.5   0.866025  oslo
#
#                      spring  summer  weekend  temperature    demand
# time
# 2022-04-08 00:00:00       1       0        0    -0.309735 -0.750248
# 2022-04-08 01:00:00       1       0        0    -0.300885 -0.754427
# 2022-04-08 02:00:00       1       0        0    -0.318584 -0.754040
# 2022-04-08 03:00:00       1       0        0    -0.336283 -0.743651
# 2022-04-08 04:00:00       1       0        0    -0.340708 -0.708386

# %% [markdown]
# - Rearrange the columns

# %%
train_4 = train_3[config.COLUMN_NAMES]

# %%
train_4.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-04-08 00:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 01:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 02:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 03:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 04:00:00       1       0       0   0.866025       -0.5  0.993257
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-04-08 00:00:00 -0.115935  0.000000  1.000000              0        0
# 2022-04-08 01:00:00 -0.115935  0.269797  0.962917              0        0
# 2022-04-08 02:00:00 -0.115935  0.519584  0.854419              0        0
# 2022-04-08 03:00:00 -0.115935  0.730836  0.682553              0        0
# 2022-04-08 04:00:00 -0.115935  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature    demand
# time
# 2022-04-08 00:00:00         1        0    -0.309735 -0.750248
# 2022-04-08 01:00:00         1        0    -0.300885 -0.754427
# 2022-04-08 02:00:00         1        0    -0.318584 -0.754040
# 2022-04-08 03:00:00         1        0    -0.336283 -0.743651
# 2022-04-08 04:00:00         1        0    -0.340708 -0.708386

# %% [markdown]
# - Lag feature

# %%
train_5 = data_helper.add_lag(train_4, 1)

# %%
train_5.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-04-08 00:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 01:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 02:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 03:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 04:00:00       1       0       0   0.866025       -0.5  0.993257
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-04-08 00:00:00 -0.115935  0.000000  1.000000              0        0
# 2022-04-08 01:00:00 -0.115935  0.269797  0.962917              0        0
# 2022-04-08 02:00:00 -0.115935  0.519584  0.854419              0        0
# 2022-04-08 03:00:00 -0.115935  0.730836  0.682553              0        0
# 2022-04-08 04:00:00 -0.115935  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature  demand-1    demand
# time
# 2022-04-08 00:00:00         1        0    -0.309735  0.000000 -0.750248
# 2022-04-08 01:00:00         1        0    -0.300885 -0.750248 -0.754427
# 2022-04-08 02:00:00         1        0    -0.318584 -0.754427 -0.754040
# 2022-04-08 03:00:00         1        0    -0.336283 -0.754040 -0.743651
# 2022-04-08 04:00:00         1        0    -0.340708 -0.743651 -0.708386

# %% [markdown]
# - Baseline feature

# %%
train_6 = data_helper.add_baseline_feature(train_5)

# %%
train_6.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-04-08 00:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 01:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 02:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 03:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 04:00:00       1       0       0   0.866025       -0.5  0.993257
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-04-08 00:00:00 -0.115935  0.000000  1.000000              0        0
# 2022-04-08 01:00:00 -0.115935  0.269797  0.962917              0        0
# 2022-04-08 02:00:00 -0.115935  0.519584  0.854419              0        0
# 2022-04-08 03:00:00 -0.115935  0.730836  0.682553              0        0
# 2022-04-08 04:00:00 -0.115935  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature  base_line_demand  \
# time
# 2022-04-08 00:00:00         1        0    -0.309735         -0.750248
# 2022-04-08 01:00:00         1        0    -0.300885         -0.754427
# 2022-04-08 02:00:00         1        0    -0.318584         -0.754040
# 2022-04-08 03:00:00         1        0    -0.336283         -0.743651
# 2022-04-08 04:00:00         1        0    -0.340708         -0.708386
#
#                      demand-1    demand
# time
# 2022-04-08 00:00:00  0.000000 -0.750248
# 2022-04-08 01:00:00 -0.750248 -0.754427
# 2022-04-08 02:00:00 -0.754427 -0.754040
# 2022-04-08 03:00:00 -0.754040 -0.743651
# 2022-04-08 04:00:00 -0.743651 -0.708386

# %% [markdown]
# - Split the final data for Base-line model

# %%
train_split_base_X = train_6.iloc[:, :-1]
train_split_base_Y = train_6.iloc[:, -1]

# %%
X_train_base, X_test_base, Y_train_base, Y_test_base = train_test_split(train_split_base_X, train_split_base_Y, test_size=0.2, random_state=0)

# %% [markdown]
# - Create sequence

# %%
train_split_X, train_split_Y = data_helper.split_sequences(train_6, config.WINDOW_SIZE)

# %% [markdown]
# - Train test split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train_split_X, train_split_Y, test_size=0.2, random_state=0)

# %% [markdown]
# - Model preparation

# %%
model_helper.show_me()

# %%
PATH = f"./data/{city_name}_model_XAI"
model = model_helper.train_model(np.shape(X_train[0])[-1], X_train, Y_train, X_test, Y_test, False, config.BATCH_SIZE, config.NUM_EPOCHS, config.PRC_EPOCH, PATH, True)
# Out:
# the model  ./data/oslo_model_XAI has beed loaded !

# %% [markdown]
# - Test the performance

# %%
base_model_actual_value, base_model_predicted_value, base_model_RSME_score, base_model_R2_score, base_model_MAE_score, _, _ = model_helper.display_results(model, X_test, Y_test, y_scaler, (-8, 16), (200, 400))
# print(actual), print(predicted)
# Comment about the result:: Capture variation but missing trend
# Out:
#   0%|          | 0/1690 [00:00<?, ?it/s]
# d:\Semester 4\XAI\../helper\model.py:316: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
#   seq = torch.FloatTensor([X[index]]).to(device=config.DEVICE)
# Rmse lsoss -> 4.513649901233834
# Mean absolute error -> 1.5561777353286743
# R2 score -> 81.0

# %% [markdown]
# - Generate the explaination (global)

# %%
# compute global attention
meanAttn, meanScores = model_helper.generate_global_heatmap(model, X_test, "Global Heat Map")
# Out:
#   0%|          | 0/85 [00:00<?, ?it/s]

# %% [markdown]
# - How's the heatmap looks like, for good and bad predictions

# %%
good_pred, bad_pred = model_helper.split_good_bad_data(X_train, Y_train, model, y_scaler)
# Out:
#   0%|          | 0/6758 [00:00<?, ?it/s]

# %%
model_helper.generate_global_heatmap(model, good_pred, "Good Prediction Heat Map")
model_helper.generate_global_heatmap(model, bad_pred, "Bad Predictin Heat Map")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/336 [00:00<?, ?it/s]
# (array([[-1.9681250e-09,  2.6883247e-09,  7.1540511e-09, ...,
#           8.8425542e-09, -4.3678967e-09,  8.1930942e-09],
#         [-1.2378558e-09,  3.1635050e-09,  6.9459110e-09, ...,
#           7.0140032e-09, -3.4134091e-09,  1.0350341e-08],
#         [-6.4725292e-10,  3.1121699e-09,  6.3004602e-09, ...,
#           4.6954067e-09, -2.1516240e-09,  1.1862699e-08],
#         ...,
#         [ 1.7311558e-10,  1.2742241e-09,  1.8854101e-09, ...,
#          -2.2662148e-09,  4.7898713e-10,  5.9002159e-09],
#         [ 1.8120518e-10,  8.3886192e-10,  1.0790697e-09, ...,
#          -1.5368115e-09,  2.4209654e-10,  3.5075138e-09],
#         [ 1.3052184e-10,  3.6162515e-10,  3.7880207e-10, ...,
#          -6.9987355e-10,  9.7334231e-11,  1.3337131e-09]], dtype=float32),
#  array([[0.00613497],
#         [0.00605621],
#         [0.00600501],
#         [0.00597383],
#         [0.005956  ],
#         [0.00594665],
#         [0.00594233],
#         [0.00594091],
#         [0.00594101],
#         [0.00594182],
#         [0.0059429 ],
#         [0.00594404],
#         [0.00594508],
#         [0.00594598],
#         [0.00594673],
#         [0.00594734],
#         [0.00594783],
#         [0.00594819],
#         [0.0059485 ],
#         [0.0059487 ],
#         [0.00594887],
#         [0.00594897],
#         [0.00594907],
#         [0.00594913],
#         [0.00594917],
#         [0.00594918],
#         [0.00594919],
#         [0.00594921],
#         [0.00594923],
#         [0.00594926],
#         [0.00594929],
#         [0.00594932],
#         [0.00594935],
#         [0.0059494 ],
#         [0.00594947],
#         [0.00594952],
#         [0.00594958],
#         [0.00594966],
#         [0.00594972],
#         [0.00594978],
#         [0.00594983],
#         [0.00594987],
#         [0.0059499 ],
#         [0.00594992],
#         [0.00594994],
#         [0.00594993],
#         [0.00594992],
#         [0.00594988],
#         [0.00594987],
#         [0.00594983],
#         [0.0059498 ],
#         [0.00594976],
#         [0.00594976],
#         [0.00594976],
#         [0.00594978],
#         [0.00594982],
#         [0.00594984],
#         [0.00594991],
#         [0.00594998],
#         [0.00595006],
#         [0.00595012],
#         [0.00595018],
#         [0.00595026],
#         [0.00595029],
#         [0.00595033],
#         [0.00595037],
#         [0.00595038],
#         [0.0059504 ],
#         [0.00595037],
#         [0.00595036],
#         [0.00595035],
#         [0.00595031],
#         [0.00595029],
#         [0.00595027],
#         [0.00595023],
#         [0.00595023],
#         [0.00595022],
#         [0.00595023],
#         [0.00595025],
#         [0.00595026],
#         [0.00595031],
#         [0.00595036],
#         [0.00595044],
#         [0.00595052],
#         [0.00595061],
#         [0.00595069],
#         [0.00595074],
#         [0.00595079],
#         [0.00595086],
#         [0.0059509 ],
#         [0.00595093],
#         [0.00595092],
#         [0.00595092],
#         [0.00595089],
#         [0.00595087],
#         [0.00595082],
#         [0.00595079],
#         [0.00595074],
#         [0.00595071],
#         [0.00595068],
#         [0.00595067],
#         [0.00595068],
#         [0.00595068],
#         [0.0059507 ],
#         [0.00595071],
#         [0.00595076],
#         [0.00595082],
#         [0.00595089],
#         [0.00595096],
#         [0.00595102],
#         [0.00595106],
#         [0.00595114],
#         [0.00595118],
#         [0.00595123],
#         [0.00595125],
#         [0.00595128],
#         [0.00595125],
#         [0.00595125],
#         [0.00595124],
#         [0.00595121],
#         [0.00595119],
#         [0.00595117],
#         [0.00595115],
#         [0.00595113],
#         [0.0059511 ],
#         [0.0059511 ],
#         [0.00595108],
#         [0.0059511 ],
#         [0.00595113],
#         [0.00595118],
#         [0.00595123],
#         [0.0059513 ],
#         [0.00595135],
#         [0.00595142],
#         [0.00595147],
#         [0.00595154],
#         [0.00595156],
#         [0.00595159],
#         [0.00595161],
#         [0.00595165],
#         [0.00595162],
#         [0.00595162],
#         [0.00595161],
#         [0.00595157],
#         [0.00595156],
#         [0.00595152],
#         [0.00595149],
#         [0.00595147],
#         [0.00595145],
#         [0.00595145],
#         [0.00595145],
#         [0.00595146],
#         [0.00595148],
#         [0.00595149],
#         [0.00595152],
#         [0.00595157],
#         [0.00595163],
#         [0.00595168],
#         [0.00595174],
#         [0.00595177],
#         [0.00595182],
#         [0.00595186],
#         [0.00595188],
#         [0.00595188],
#         [0.00595192],
#         [0.00595191],
#         [0.0059519 ],
#         [0.0059519 ]], dtype=float32))

# %% [markdown]
# - Generate the explaination (Local)

# %%
heat_index = 1
res = model_helper.disp_grads_rk(model_helper.compute_grads(None, model, X_test[heat_index]))
print(f"Actual result -> {Y_test[heat_index]} && Predicted result -> {res}")
print(f"Error - {np.mean(np.abs(Y_test[heat_index] - res))}")
# Out:
# Actual result -> 0.06954657676675668 && Predicted result -> -0.3178671896457672
# Error - 0.3874137664125239

# %% [markdown]
# - Partial dependency plt, to manipulate the data

# %%
X, y = train_6.iloc[:, :-1], np.reshape(y_scaler.inverse_transform(np.reshape(train_6.iloc[:, -1].to_numpy(), (-1, 1))), (-1))

# %%
# polyreg = model_helper.train_plyrg_model(4, X, y)

# %%
# model_helper.generate_feature_graph(polyreg, X, 3, int(len(X.columns)/3), X.columns[:-1])

# %% [markdown]
# - Perturbation analysis or replace less important data with random noise, K-nearest neighbor, Augmented data

# %% [markdown]
# - Random noise

# %%
# Add random noise based on the heatmap
light_blue = (0.00594, 0.00596)
dark_red = (0.00597, )
X_train_with_noise = data_helper.add_random_noise(X_train, light_blue, dark_red, model)

# %%
# Retrain the model with the new data
PATH_NOISE = f"./data/{city_name}_model_XAI_Noise"
model_noise = model_helper.train_model(np.shape(X_train[0])[-1], X_train_with_noise, Y_train, X_test, Y_test, False, config.BATCH_SIZE, 6, config.PRC_EPOCH, PATH_NOISE, True)
# Out:
# the model  ./data/oslo_model_XAI_Noise has beed loaded !

# %%
# Check the performance
noise_model_actual_value, noise_model_predicted_value, noise_model_RSME_score, noise_model_R2_score, noise_model_MAE_score, _, _ = model_helper.display_results(model_noise, X_test, Y_test, y_scaler, (1.2, 14), [200, 400])
print(noise_model_actual_value), print(noise_model_predicted_value)
# Out:
#   0%|          | 0/1690 [00:00<?, ?it/s]
# Rmse lsoss -> 4.465468902742724
# Mean absolute error -> 1.0340732336044312
# R2 score -> 92.0
# [14.1198845, 10.357395, 2.056274, 2.878534, 11.953338, 2.7030492, 4.091568, 10.627337, 7.7302012, 8.581529, 3.107967, 11.799909, 2.157768, 5.978673, 9.377978, 4.81447, 1.8214889, 11.727384, 2.5070193, 2.0010388, 2.647439, 15.19258, 14.878264, 7.722882, 2.0407248, 2.73834, 14.185392, 6.297783, 3.936551, 12.632282, 6.64471, 2.792539, 9.599034, 1.8504981, 13.019548, 2.8672752, 2.0965161, 5.471177, 2.908808, 11.661177, 13.657745, 4.241251, 2.3537464, 3.8468482, 9.917503, 5.997414, 2.0588782, 8.2262, 5.135551, 2.39064, 13.593565, 2.550195, 14.257194, 2.5618649, 2.557026, 2.3661025, 2.3063242, 5.4439588, 2.8857102, 13.815495, 12.043078, 5.410595, 13.118354, 1.8105068, 2.8162282, 3.5521023, 11.499548, 3.1058419, 2.1230562, 2.914716, 5.4046593, 2.0556598, 1.9920449, 2.6379013, 3.5163, 11.766029, 10.25503, 11.993025, 3.1564271, 13.318704, 12.2348175, 11.639528, 9.294962, 2.0457199, 3.371649, 8.263307, 10.705524, 13.595726, 2.1205602, 6.028779, 11.625614, 1.8539292, 2.3284292, 9.14973, 11.004282, 2.506326, 1.8962507, 3.9056523, 3.1633203, 2.8973851, 13.874965, 2.0212493, 16.781595, 2.344187, 2.2053282, 13.379176, 2.094888, 1.9920578, 2.2693532, 2.4693663, 3.1418562, 14.914534, 11.26863, 11.194965, 12.539651, 2.4650242, 3.7039258, 2.6899142, 3.038636, 3.5260541, 2.7306664, 10.741455, 11.451906, 1.8267701, 3.0233672, 9.54592, 11.955164, 15.602383, 12.805732, 2.5223892, 12.751982, 2.131491, 2.3557851, 2.837209, 2.6495364, 6.148872, 2.1847072, 11.6452, 10.785285, 2.028527, 3.1647213, 2.3044584, 3.5928614, 2.784743, 16.27849, 3.002316, 9.500768, 5.687082, 2.611085, 2.534125, 16.34692, 2.898274, 1.8103571, 2.924784, 2.7335832, 10.912621, 13.012667, 15.866157, 11.387399, 13.340423, 13.597456, 1.8936082, 16.46515, 2.7720153, 6.4699683, 13.243752, 12.52486, 4.012444, 6.1925774, 2.2566578, 15.959253, 2.831436, 2.9372652, 2.1925313, 11.396781, 4.0475135, 3.7699382, 13.165175, 8.445422, 3.5531132, 2.4974065, 2.2492833, 12.4543, 7.471004, 6.8885922, 2.747914, 2.115846, 5.199104, 2.35096, 3.015591, 2.5732832, 2.5420878, 1.905941, 2.729145, 2.6856651, 4.397047, 4.140163, 2.513054, 2.4837902, 8.3153, 11.732683, 11.010466, 2.3844123, 3.4312952, 11.04817, 5.618434, 2.6481032, 12.297435, 2.3477201, 14.915565, 4.140026, 5.203261, 2.815406, 9.904715, 12.84014, 13.586111, 12.08319, 2.2806373, 4.904744, 15.425821, 8.598013, 10.854571, 11.889939, 2.5743923, 14.590658, 2.9346132, 5.356125, 2.137482, 10.609559, 3.014709, 2.8394551, 12.706135, 9.3519745, 2.4619803, 2.1121242, 2.5497103, 3.247991, 15.6011, 2.611769, 6.2265677, 2.8234303, 2.54068, 8.076098, 2.790594, 12.437959, 11.156155, 6.9042087, 2.430815, 3.0145593, 9.877685, 10.30765, 1.7684783, 3.430429, 3.7268133, 2.8244882, 12.710477, 11.624087, 2.7575383, 2.2712433, 3.89788, 5.917806, 2.8613322, 4.6126986, 12.133716, 2.0093222, 2.9278939, 13.334232, 1.9777417, 12.410043, 2.668455, 3.034351, 9.752564, 1.7194852, 2.2709138, 2.5124192, 3.160076, 1.610973, 3.355675, 13.158274, 12.823914, 3.3084261, 1.9832042, 16.983007, 6.241251, 14.383575, 13.203209, 3.4258351, 11.545635, 2.232264, 2.3529441, 9.449879, 2.444121, 13.841893, 7.2983584, 2.6927571, 1.8066292, 3.336482, 2.7720814, 6.721272, 12.884629, 8.427567, 6.265408, 2.215948, 9.634454, 3.058184, 1.902746, 1.8654952, 10.962014, 2.586017, 2.459602, 11.811839, 6.814073, 12.017241, 3.246002, 2.7956119, 8.164574, 1.8357271, 11.024067, 2.7023683, 5.4459286, 12.773389, 6.1474986, 2.5716782, 14.353345, 12.423812, 2.1159194, 7.9518085, 2.8115373, 2.8412454, 8.537582, 10.917601, 10.617408, 14.546807, 12.377777, 2.3251631, 2.3161602, 11.634076, 12.581172, 12.113849, 2.290941, 12.530758, 11.354337, 2.584318, 7.502148, 2.2580483, 12.110842, 8.485554, 2.5824578, 13.859221, 2.500107, 11.101416, 9.421192, 3.0899851, 8.721334, 2.3264499, 2.9800122, 3.5579119, 3.9689324, 12.553304, 12.771707, 12.1755295, 8.154327, 4.340839, 14.469548, 3.163629, 2.6261692, 10.618823, 2.1085432, 11.306322, 6.8110456, 6.786868, 2.475297, 2.550189, 11.340572, 2.037482, 11.996138, 4.9098, 10.911604 ...
# [10.4785     9.068787   3.9392548 ... 12.872009   5.2099915  3.3065033]
# (None, None)

# %% [markdown]
# ## Analysis from the PDP -
#     -> OSLO is the only city that consume a tons of electricy compare to the other ctities
#     -> All the other cities might have a normal electricity demand
#     -> It, would be a good experiment, to see, if the deduct Bergen data from the training data set, it might overall improve the model performance
#     -> From the month graph - it seems like, at the end of the year (11, 12), consumption really spikes
#     -> From the day graph - it seems like, on the day (3,4) the consumption spikes
#     -> From the daylight graph - it seems like, if the daylight increase, consumption decrease
#     -> From the holiday graph - it seems like, during the hoiliday consumption increase
#     -> And, all the other feature, doesnt have that much deviative impact

# %% [markdown]
# ## The whole hypothesis, is based on our specific model perforrmance, we we can call it model(technique) dependent
#     -> As we can see from the model performace that, its under performing for some prediction, that is preety low compare to the average demand

# %% [markdown]
# - Try to adjust the training data with all the others finding and see if that improves the performance
# - The hypothesis is that, from the prediction graph, we can see that, mostly our model is not performing well when the consumption is going down
# - For all the spikes, the model is performing well, to solve the problem we could use different hypothesis, we could add some penalize terms to the model for lower consumption mitchmatch
# - Or we could modify some traing data and convert some somple to more lower degree and see how the model perform, Or add some bias(lower consumption example) to the trainign data and see how the model perform.

# %% [markdown]
# # Lets try the data modification

# %%
train_low_demand = data_helper.adjust_train_data(train_6)

# %%
train_low_demand_split_X, train_low_demand_split_Y = data_helper.split_sequences(train_low_demand, config.WINDOW_SIZE)
X_train_low_demand, X_test_low_demand, Y_train_low_demand, Y_test_low_demand = train_test_split(train_low_demand_split_X, train_low_demand_split_Y, test_size=0.2, random_state=0)

# %%
# Retrain the model with the new data
PATH_LOW_DEMAND = f"./data/{city_name}_model_XAI_low_demand"
model_low_demand = model_helper.train_model(np.shape(X_train[0])[-1], X_train_low_demand, Y_train_low_demand, X_test_low_demand,
                               Y_test_low_demand, False, config.BATCH_SIZE, 10, config.PRC_EPOCH, PATH_LOW_DEMAND, True)
# Out:
# the model  ./data/oslo_model_XAI_low_demand has beed loaded !

# %%
# Check the performance
low_demand_model_actual_value, low_demand_model_predicted_value, low_demand_model_RSME_score, low_demand_model_R2_score, low_demand_model_MAE_score, _, _ = model_helper.display_results(
    model_low_demand, X_test_low_demand, Y_test_low_demand, y_scaler, (-8, 14), (400, 700))
print(low_demand_model_actual_value), print(low_demand_model_predicted_value)
# Out:
#   0%|          | 0/1690 [00:00<?, ?it/s]
# Rmse lsoss -> 4.520949659594205
# Mean absolute error -> 1.1857187747955322
# R2 score -> 87.0
# [14.1198845, 10.357395, 2.056274, 2.878534, 11.953338, 2.7030492, 4.091568, 10.627337, 7.7302012, 8.581529, 3.107967, 11.799909, 2.157768, 5.978673, 9.377978, 4.81447, 1.8214889, 11.727384, 2.5070193, 2.0010388, 2.647439, 15.19258, 14.878264, 7.722882, 2.0407248, 2.73834, 14.185392, 6.297783, 3.936551, 12.632282, 6.64471, 2.792539, 9.599034, 1.8504981, 13.019548, 2.8672752, 2.0965161, 5.471177, 2.908808, 11.661177, 13.657745, 4.241251, 2.3537464, 3.8468482, 9.917503, 5.997414, 2.0588782, 8.2262, 5.135551, 2.39064, 13.593565, 2.550195, 14.257194, 2.5618649, 2.557026, 2.3661025, 2.3063242, 5.4439588, 2.8857102, 13.815495, 12.043078, 5.410595, 13.118354, 1.8105068, 2.8162282, 3.5521023, 11.499548, 3.1058419, 2.1230562, 2.914716, 5.4046593, 2.0556598, 1.9920449, 2.6379013, 3.5163, 11.766029, 10.25503, 11.993025, 3.1564271, 13.318704, 12.2348175, 11.639528, 9.294962, 2.0457199, 3.371649, 8.263307, 10.705524, 13.595726, 2.1205602, 6.028779, 11.625614, 1.8539292, 2.3284292, 9.14973, 11.004282, 2.506326, 1.8962507, 3.9056523, 3.1633203, 2.8973851, 13.874965, 2.0212493, 16.781595, 2.344187, 2.2053282, 13.379176, 2.094888, 1.9920578, 2.2693532, 2.4693663, 3.1418562, 14.914534, 11.26863, 11.194965, 12.539651, 2.4650242, 3.7039258, 2.6899142, 3.038636, 3.5260541, 2.7306664, 10.741455, 11.451906, 1.8267701, 3.0233672, 9.54592, 11.955164, 15.602383, 12.805732, 2.5223892, 12.751982, 2.131491, 2.3557851, 2.837209, 2.6495364, 6.148872, 2.1847072, 11.6452, 10.785285, 2.028527, 3.1647213, 2.3044584, 3.5928614, 2.784743, 16.27849, 3.002316, 9.500768, 5.687082, 2.611085, 2.534125, 16.34692, 2.898274, 1.8103571, 2.924784, 2.7335832, 10.912621, 13.012667, 15.866157, 11.387399, 13.340423, 13.597456, 1.8936082, 16.46515, 2.7720153, 6.4699683, 13.243752, 12.52486, 4.012444, 6.1925774, 2.2566578, 15.959253, 2.831436, 2.9372652, 2.1925313, 11.396781, 4.0475135, 3.7699382, 13.165175, 8.445422, 3.5531132, 2.4974065, 2.2492833, 12.4543, 7.471004, 6.8885922, 2.747914, 2.115846, 5.199104, 2.35096, 3.015591, 2.5732832, 2.5420878, 1.905941, 2.729145, 2.6856651, 4.397047, 4.140163, 2.513054, 2.4837902, 8.3153, 11.732683, 11.010466, 2.3844123, 3.4312952, 11.04817, 5.618434, 2.6481032, 12.297435, 2.3477201, 14.915565, 4.140026, 5.203261, 2.815406, 9.904715, 12.84014, 13.586111, 12.08319, 2.2806373, 4.904744, 15.425821, 8.598013, 10.854571, 11.889939, 2.5743923, 14.590658, 2.9346132, 5.356125, 2.137482, 10.609559, 3.014709, 2.8394551, 12.706135, 9.3519745, 2.4619803, 2.1121242, 2.5497103, 3.247991, 15.6011, 2.611769, 6.2265677, 2.8234303, 2.54068, 8.076098, 2.790594, 12.437959, 11.156155, 6.9042087, 2.430815, 3.0145593, 9.877685, 10.30765, 1.7684783, 3.430429, 3.7268133, 2.8244882, 12.710477, 11.624087, 2.7575383, 2.2712433, 3.89788, 5.917806, 2.8613322, 4.6126986, 12.133716, 2.0093222, 2.9278939, 13.334232, 1.9777417, 12.410043, 2.668455, 3.034351, 9.752564, 1.7194852, 2.2709138, 2.5124192, 3.160076, 1.610973, 3.355675, 13.158274, 12.823914, 3.3084261, 1.9832042, 16.983007, 6.241251, 14.383575, 13.203209, 3.4258351, 11.545635, 2.232264, 2.3529441, 9.449879, 2.444121, 13.841893, 7.2983584, 2.6927571, 1.8066292, 3.336482, 2.7720814, 6.721272, 12.884629, 8.427567, 6.265408, 2.215948, 9.634454, 3.058184, 1.902746, 1.8654952, 10.962014, 2.586017, 2.459602, 11.811839, 6.814073, 12.017241, 3.246002, 2.7956119, 8.164574, 1.8357271, 11.024067, 2.7023683, 5.4459286, 12.773389, 6.1474986, 2.5716782, 14.353345, 12.423812, 2.1159194, 7.9518085, 2.8115373, 2.8412454, 8.537582, 10.917601, 10.617408, 14.546807, 12.377777, 2.3251631, 2.3161602, 11.634076, 12.581172, 12.113849, 2.290941, 12.530758, 11.354337, 2.584318, 7.502148, 2.2580483, 12.110842, 8.485554, 2.5824578, 13.859221, 2.500107, 11.101416, 9.421192, 3.0899851, 8.721334, 2.3264499, 2.9800122, 3.5579119, 3.9689324, 12.553304, 12.771707, 12.1755295, 8.154327, 4.340839, 14.469548, 3.163629, 2.6261692, 10.618823, 2.1085432, 11.306322, 6.8110456, 6.786868, 2.475297, 2.550189, 11.340572, 2.037482, 11.996138, 4.9098, 10.911604 ...
# [ 2.3066711 -0.299057  -8.        ... 11.853302   5.7938995  4.6081543]
# (None, None)

# %% [markdown]
# ## Base-line model
#
#     -> https://machinelearningmastery.com/persistence-time-series-forecasting-with-python/
#
# ## Skill score
#
# You are told that your skill score for temperature forecasts last month was +0.25 (25%). The standard forecast used for comparison was in error by 2 degrees on average. This means:
#
#     -> Your error is 0.25 degrees smaller than the standard score.
#     -> The error of your forecasts is 2.5 degrees.
#     -> The error of your forecasts is 1.5 degrees.

# %%
base_line_model_predicted_value, base_line_model_actual_value = model_helper.model_base_line(X_test_base, Y_test_base, y_scaler)
base_line_model_MAE_score = np.mean(np.abs(np.subtract(base_line_model_actual_value, base_line_model_predicted_value)))
print(f"Base model MAE - {base_line_model_MAE_score}")
# Out:
# Base model MAE - 4.735937748259851

# %% [markdown]
#  * Base model skill

# %%
base_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, base_model_predicted_value, base_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.6858935959881544

# %% [markdown]
#  * Noise model skill

# %%
noise_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, noise_model_predicted_value, noise_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.7985147160453037

# %% [markdown]
#  * Low-demnad model skill

# %%
low_demand_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, low_demand_model_predicted_value, low_demand_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.765803849457843

# %% [markdown]
# ## Cross validation

# %%
matrix_cv_base = model_helper.cross_validation(X_train, Y_train, 10, y_scaler, (-8, 16))
matrix_cv_noise = model_helper.cross_validation(X_train_with_noise, Y_train, 10, y_scaler, (1.2, 14))
matrix_cv_low_demand = model_helper.cross_validation(X_train_low_demand, Y_train_low_demand, 10, y_scaler, (-8, 14))
# Out:
# Training...
# Train_loss 0.60449565, Test loss : 0.55950027, Epoch 1
# Train_loss 0.58982283, Test loss : 0.54697894, Epoch 2
# Train_loss 0.58717207, Test loss : 0.54387614, Epoch 3
# Train_loss 0.58713124, Test loss : 0.54011527, Epoch 4
# Train_loss 0.58698858, Test loss : 0.53673007, Epoch 5
# Train_loss 0.58471180, Test loss : 0.53636423, Epoch 6
# Train_loss 0.58458371, Test loss : 0.53590402, Epoch 7
# Train_loss 0.58465160, Test loss : 0.53542569, Epoch 8
# Train_loss 0.58468592, Test loss : 0.53495643, Epoch 9
# Train_loss 0.58463544, Test loss : 0.53450407, Epoch 10
# Rmse lsoss -> 4.4122628383282185
# Mean absolute error -> 4.708398342132568
# R2 score -> -54.0
# Training...
# Train_loss 0.60545134, Test loss : 0.54938210, Epoch 1
# Train_loss 0.59890660, Test loss : 0.54461426, Epoch 2
# Train_loss 0.59678500, Test loss : 0.54123981, Epoch 3
# Train_loss 0.59668025, Test loss : 0.53904636, Epoch 4
# Train_loss 0.59649234, Test loss : 0.53671616, Epoch 5
# Train_loss 0.59453601, Test loss : 0.53566637, Epoch 6
# Train_loss 0.59423985, Test loss : 0.53489929, Epoch 7
# Train_loss 0.59416965, Test loss : 0.53438621, Epoch 8
# Train_loss 0.59419232, Test loss : 0.53400169, Epoch 9
# Train_loss 0.59405263, Test loss : 0.53364120, Epoch 10
# Rmse lsoss -> 4.403941313945917
# Mean absolute error -> 3.986159324645996
# R2 score -> -16.0
# Training...
# Train_loss 0.61835968, Test loss : 0.56369213, Epoch 1
# Train_loss 0.59224165, Test loss : 0.56210072, Epoch 2
# Train_loss 0.59155725, Test loss : 0.56033063, Epoch 3
# Train_loss 0.59163433, Test loss : 0.55838622, Epoch 4
# Train_loss 0.59156263, Test loss : 0.55647144, Epoch 5
# Train_loss 0.59038982, Test loss : 0.55637351, Epoch 6
# Train_loss 0.59029337, Test loss : 0.55616199, Epoch 7
# Train_loss 0.59035443, Test loss : 0.55594117, Epoch 8
# Train_loss 0.59030636, Test loss : 0.55569994, Epoch 9
# Train_loss 0.59038861, Test loss : 0.55547130, Epoch 10
# Rmse lsoss -> 4.58584828590554
# Mean absolute error -> 4.8843302726745605
# R2 score -> -60.0
# Training...
# Train_loss 0.61199064, Test loss : 0.58836761, Epoch 1
# Train_loss 0.57145566, Test loss : 0.58053093, Epoch 2
# Train_loss 0.57249136, Test loss : 0.57779339, Epoch 3
# Train_loss 0.57250767, Test loss : 0.57576251, Epoch 4
# Train_loss 0.57248862, Test loss : 0.57388649, Epoch 5
# Train_loss 0.57154471, Test loss : 0.57388270, Epoch 6
# Train_loss 0.57132468, Test loss : 0.57391035, Epoch 7
# Train_loss 0.57113715, Test loss : 0.57381425, Epoch 8
# Train_loss 0.57109737, Test loss : 0.57359968, Epoch 9
# Train_loss 0.57114094, Test loss : 0.57336061, Epoch 10
# Rmse lsoss -> 4.730907215112438
# Mean absolute error -> 4.435146808624268
# R2 score -> -18.0
# Training...
# Train_loss 0.60547365, Test loss : 0.57626691, Epoch 1
# Train_loss 0.58367522, Test loss : 0.57421141, Epoch 2
# Train_loss 0.58256535, Test loss : 0.57317039, Epoch 3
# Train_loss 0.58268765, Test loss : 0.57170432, Epoch 4
# Train_loss 0.58268441, Test loss : 0.57064222, Epoch 5
# Train_loss 0.58112584, Test loss : 0.57078867, Epoch 6
# Train_loss 0.58113525, Test loss : 0.57079339, Epoch 7
# Train_loss 0.58114137, Test loss : 0.57070337, Epoch 8
# Train_loss 0.58111513, Test loss : 0.57059127, Epoch 9
# Train_loss 0.58119156, Test loss : 0.57046525, Epoch 10
# Rmse lsoss -> 4.7085580462729855
# Mean absolute error -> 5.3251118659973145
# R2 score -> -81.0
# Training...
# Train_loss 0.60871621, Test loss : 0.59992918, Epoch 1
# Train_loss 0.58643470, Test loss : 0.59203299, Epoch 2
# Train_loss 0.58591108, Test loss : 0.58811749, Epoch 3
# Train_loss 0.58557997, Test loss : 0.58510839, Epoch 4
# Train_loss 0.58554143, Test loss : 0.58214860, Epoch 5
# Train_loss 0.58474717, Test loss : 0.58171452, Epoch 6
# Train_loss 0.58488193, Test loss : 0.58123061, Epoch 7
# Train_loss 0.58490803, Test loss : 0.58087337, Epoch 8
# Train_loss 0.58489999, Test loss : 0.58058902, Epoch 9
# Train_loss 0.58468561, Test loss : 0.58030219, Epoch 10
# Rmse lsoss -> 4.787389266922212
# Mean absolute error -> 4.059162139892578
# R2 score -> -12.0
# Training...
# Train_loss 0.60252224, Test loss : 0.55106674, Epoch 1
# Train_loss 0.58954033, Test loss : 0.54784460, Epoch 2
# Train_loss 0.58950763, Test loss : 0.54559837, Epoch 3
# Train_loss 0.58944172, Test loss : 0.54388899, Epoch 4
# Train_loss 0.58937332, Test loss : 0.54237715, Epoch 5
# Train_loss 0.58855059, Test loss : 0.54227637, Epoch 6
# Train_loss 0.58841395, Test loss : 0.54215380, Epoch 7
# Train_loss 0.58836540, Test loss : 0.54199813, Epoch 8
# Train_loss 0.58844996, Test loss : 0.54180589, Epoch 9
# Train_loss 0.58843357, Test loss : 0.54160791, Epoch 10
# Rmse lsoss -> 4.4693871957481575
# Mean absolute error -> 4.197971343994141
# R2 score -> -34.0
# Training...
# Train_loss 0.61260433, Test loss : 0.57674700, Epoch 1
# Train_loss 0.59841709, Test loss : 0.57281093, Epoch 2
# Train_loss 0.59845248, Test loss : 0.57073275, Epoch 3
# Train_loss 0.59827042, Test loss : 0.56874632, Epoch 4
# Train_loss 0.59832108, Test loss : 0.56648701, Epoch 5
# Train_loss 0.59750947, Test loss : 0.56641149, Epoch 6
# Train_loss 0.59751468, Test loss : 0.56631080, Epoch 7
# Train_loss 0.59746332, Test loss : 0.56613818, Epoch 8
# Train_loss 0.59736790, Test loss : 0.56593795, Epoch 9
# Train_loss 0.59740264, Test loss : 0.56570623, Epoch 10
# Rmse lsoss -> 4.671185394730481
# Mean absolute error -> 3.1427252292633057
# R2 score -> 37.0
# Training...
# Train_loss 0.58962650, Test loss : 0.58853418, Epoch 1
# Train_loss 0.59433484, Test loss : 0.58239699, Epoch 2
# Train_loss 0.59050520, Test loss : 0.57697385, Epoch 3
# Train_loss 0.58973895, Test loss : 0.57489864, Epoch 4
# Train_loss 0.58947774, Test loss : 0.57268121, Epoch 5
# Train_loss 0.58702011, Test loss : 0.56974134, Epoch 6
# Train_loss 0.58640592, Test loss : 0.56735032, Epoch 7
# Train_loss 0.58603341, Test loss : 0.56590320, Epoch 8
# Train_loss 0.58586907, Test loss : 0.56501330, Epoch 9
# Train_loss 0.58576608, Test loss : 0.56441822, Epoch 10
# Rmse lsoss -> 4.65731655936975
# Mean absolute error -> 6.387505531311035
# R2 score -> -167.0
# Training...
# Train_loss 0.59114825, Test loss : 0.60963784, Epoch 1
# Train_loss 0.58290605, Test loss : 0.60476434, Epoch 2
# Train_loss 0.58311951, Test loss : 0.60224143, Epoch 3
# Train_loss 0.58299752, Test loss : 0.59993971, Epoch 4
# Train_loss 0.58296979, Test loss : 0.59790146, Epoch 5
# Train_loss 0.58213364, Test loss : 0.59891910, Epoch 6
# Train_loss 0.58196152, Test loss : 0.59969476, Epoch 7
# Train_loss 0.58184279, Test loss : 0.59997446, Epoch 8
# Train_loss 0.58186605, Test loss : 0.59993263, Epoch 9
# Train_loss 0.58176867, Test loss : 0.59973936, Epoch 10
# Rmse lsoss -> 4.952322235999471
# Mean absolute error -> 5.151871681213379
# R2 score -> -55.00000000000001
# Training...
# Train_loss 0.59668740, Test loss : 0.55534533, Epoch 1
# Train_loss 0.58892209, Test loss : 0.54695298, Epoch 2
# Train_loss 0.58722395, Test loss : 0.54469363, Epoch 3
# Train_loss 0.58702693, Test loss : 0.54184005, Epoch 4
# Train_loss 0.58683752, Test loss : 0.53876802, Epoch 5
# Train_loss 0.58472971, Test loss : 0.53845014, Epoch 6
# Train_loss 0.58467272, Test loss : 0.53799274, Epoch 7
# Train_loss 0.58459733, Test loss : 0.53753548, Epoch 8
# Train_loss 0.58467598, Test loss : 0.53707869, Epoch 9
# Train_loss 0.58467320, Test loss : 0.53665447, Epoch 10
# Rmse lsoss -> 4.428678528857439
# Mean absolute error -> 2.4493870735168457
# R2 score -> 47.0
# Training...
# Train_loss 0.60307323, Test loss : 0.54980049, Epoch 1
# Train_loss 0.59847745, Test loss : 0.54420805, Epoch 2
# Train_loss 0.59641045, Test loss : 0.54136308, Epoch 3
# Train_loss 0.59640466, Test loss : 0.53902502, Epoch 4
# Train_loss 0.59629064, Test loss : 0.53669448, Epoch 5
# Train_loss 0.59450846, Test loss : 0.53565196, Epoch 6
# Train_loss 0.59422406, Test loss : 0.53479886, Epoch 7
# Train_loss 0.59401381, Test loss : 0.53419355, Epoch 8
# Train_loss 0.59395867, Test loss : 0.53368024, Epoch 9
# Train_loss 0.59397671, Test loss : 0.53322020, Epoch 10
# Rmse lsoss -> 4.402150946171753
# Mean absolute error -> 1.573055624961853
# R2 score -> 79.0
# Training...
# Train_loss 0.61497115, Test loss : 0.56186057, Epoch 1
# Train_loss 0.59193195, Test loss : 0.56138078, Epoch 2
# Train_loss 0.59147504, Test loss : 0.55982824, Epoch 3
# Train_loss 0.59163025, Test loss : 0.55840504, Epoch 4
# Train_loss 0.59151335, Test loss : 0.55711815, Epoch 5
# Train_loss 0.59046821, Test loss : 0.55708004, Epoch 6
# Train_loss 0.59041496, Test loss : 0.55692667, Epoch 7
# Train_loss 0.59042065, Test loss : 0.55675034, Epoch 8
# Train_loss 0.59050554, Test loss : 0.55658001, Epoch 9
# Train_loss 0.59045924, Test loss : 0.55641022, Epoch 10
# Rmse lsoss -> 4.594651114384534
# Mean absolute error -> 2.2537786960601807
# R2 score -> 54.0
# Training...
# Train_loss 0.61179697, Test loss : 0.59089516, Epoch 1
# Train_loss 0.57160988, Test loss : 0.58211046, Epoch 2
# Train_loss 0.57268257, Test loss : 0.57947193, Epoch 3
# Train_loss 0.57261396, Test loss : 0.57727313, Epoch 4
# Train_loss 0.57235637, Test loss : 0.57526153, Epoch 5
# Train_loss 0.57143491, Test loss : 0.57528564, Epoch 6
# Train_loss 0.57120435, Test loss : 0.57531317, Epoch 7
# Train_loss 0.57112794, Test loss : 0.57518125, Epoch 8
# Train_loss 0.57109122, Test loss : 0.57496983, Epoch 9
# Train_loss 0.57112742, Test loss : 0.57472067, Epoch 10
# Rmse lsoss -> 4.745545959256534
# Mean absolute error -> 1.977592945098877
# R2 score -> 69.0
# Training...
# Train_loss 0.59199498, Test loss : 0.57474810, Epoch 1
# Train_loss 0.58336328, Test loss : 0.57259487, Epoch 2
# Train_loss 0.58252652, Test loss : 0.57167763, Epoch 3
# Train_loss 0.58245079, Test loss : 0.57004672, Epoch 4
# Train_loss 0.58247235, Test loss : 0.56872481, Epoch 5
# Train_loss 0.58105602, Test loss : 0.56881604, Epoch 6
# Train_loss 0.58099366, Test loss : 0.56876388, Epoch 7
# Train_loss 0.58105572, Test loss : 0.56864434, Epoch 8
# Train_loss 0.58102030, Test loss : 0.56848694, Epoch 9
# Train_loss 0.58103774, Test loss : 0.56832212, Epoch 10
# Rmse lsoss -> 4.689462683182159
# Mean absolute error -> 1.2813935279846191
# R2 score -> 83.0
# Training...
# Train_loss 0.59695605, Test loss : 0.59859933, Epoch 1
# Train_loss 0.58590046, Test loss : 0.59246539, Epoch 2
# Train_loss 0.58570832, Test loss : 0.58847541, Epoch 3
# Train_loss 0.58549587, Test loss : 0.58535519, Epoch 4
# Train_loss 0.58543179, Test loss : 0.58261151, Epoch 5
# Train_loss 0.58491224, Test loss : 0.58220757, Epoch 6
# Train_loss 0.58479884, Test loss : 0.58179356, Epoch 7
# Train_loss 0.58476242, Test loss : 0.58145113, Epoch 8
# Train_loss 0.58480485, Test loss : 0.58117172, Epoch 9
# Train_loss 0.58479627, Test loss : 0.58091457, Epoch 10
# Rmse lsoss -> 4.796721912637602
# Mean absolute error -> 2.3598930835723877
# R2 score -> 57.99999999999999
# Training...
# Train_loss 0.60655258, Test loss : 0.55726080, Epoch 1
# Train_loss 0.58967444, Test loss : 0.55303755, Epoch 2
# Train_loss 0.58961378, Test loss : 0.55127626, Epoch 3
# Train_loss 0.58940312, Test loss : 0.54977184, Epoch 4
# Train_loss 0.58938187, Test loss : 0.54825657, Epoch 5
# Train_loss 0.58856853, Test loss : 0.54808738, Epoch 6
# Train_loss 0.58850412, Test loss : 0.54792097, Epoch 7
# Train_loss 0.58846784, Test loss : 0.54774376, Epoch 8
# Train_loss 0.58854301, Test loss : 0.54757101, Epoch 9
# Train_loss 0.58856795, Test loss : 0.54739712, Epoch 10
# Rmse lsoss -> 4.524080273645429
# Mean absolute error -> 1.285497784614563
# R2 score -> 86.0
# Training...
# Train_loss 0.61638017, Test loss : 0.57566371, Epoch 1
# Train_loss 0.59866589, Test loss : 0.57259167, Epoch 2
# Train_loss 0.59864112, Test loss : 0.57000703, Epoch 3
# Train_loss 0.59850382, Test loss : 0.56790688, Epoch 4
# Train_loss 0.59841827, Test loss : 0.56575056, Epoch 5
# Train_loss 0.59756409, Test loss : 0.56571969, Epoch 6
# Train_loss 0.59748707, Test loss : 0.56564356, Epoch 7
# Train_loss 0.59742277, Test loss : 0.56546337, Epoch 8
# Train_loss 0.59759406, Test loss : 0.56524808, Epoch 9
# Train_loss 0.59745887, Test loss : 0.56500658, Epoch 10
# Rmse lsoss -> 4.660969844632995
# Mean absolute error -> 1.8044716119766235
# R2 score -> 78.0
# Training...
# Train_loss 0.59277074, Test loss : 0.59082024, Epoch 1
# Train_loss 0.59462187, Test loss : 0.57715360, Epoch 2
# Train_loss 0.58958262, Test loss : 0.57413918, Epoch 3
# Train_loss 0.58959574, Test loss : 0.57128703, Epoch 4
# Train_loss 0.58931708, Test loss : 0.56843320, Epoch 5
# Train_loss 0.58694266, Test loss : 0.56550719, Epoch 6
# Train_loss 0.58621730, Test loss : 0.56314217, Epoch 7
# Train_loss 0.58589065, Test loss : 0.56174477, Epoch 8
# Train_loss 0.58563317, Test loss : 0.56082715, Epoch 9
# Train_loss 0.58558676, Test loss : 0.56016876, Epoch 10
# Rmse lsoss -> 4.617044566051138
# Mean absolute error -> 2.4137678146362305
# R2 score -> 52.0
# Training...
# Train_loss 0.60661028, Test loss : 0.61187089, Epoch 1
# Train_loss 0.58296956, Test loss : 0.60486309, Epoch 2
# Train_loss 0.58357537, Test loss : 0.60136985, Epoch 3
# Train_loss 0.58350970, Test loss : 0.59929927, Epoch 4
# Train_loss 0.58343078, Test loss : 0.59739500, Epoch 5
# Train_loss 0.58251241, Test loss : 0.59906316, Epoch 6
# Train_loss 0.58212779, Test loss : 0.60024901, Epoch 7
# Train_loss 0.58184153, Test loss : 0.60062588, Epoch 8
# Train_loss 0.58189829, Test loss : 0.60061864, Epoch 9
# Train_loss 0.58180605, Test loss : 0.60039077, Epoch 10
# Rmse lsoss -> 4.95404737289873
# Mean absolute error -> 2.6437084674835205
# R2 score -> 50.0
# Training...
# Train_loss 0.59522500, Test loss : 0.55025370, Epoch 1
# Train_loss 0.58865541, Test loss : 0.54084888, Epoch 2
# Train_loss 0.58674881, Test loss : 0.53566937, Epoch 3
# Train_loss 0.58668919, Test loss : 0.53067123, Epoch 4
# Train_loss 0.58655546, Test loss : 0.52669315, Epoch 5
# Train_loss 0.58459397, Test loss : 0.52625926, Epoch 6
# Train_loss 0.58456341, Test loss : 0.52580514, Epoch 7
# Train_loss 0.58467738, Test loss : 0.52542367, Epoch 8
# Train_loss 0.58465850, Test loss : 0.52506998, Epoch 9
# Train_loss 0.58463195, Test loss : 0.52473244, Epoch 10
# Rmse lsoss -> 4.400721118095639
# Mean absolute error -> 1.9205772876739502
# R2 score -> 63.0
# Training...
# Train_loss 0.60500743, Test loss : 0.54448633, Epoch 1
# Train_loss 0.59857439, Test loss : 0.53872651, Epoch 2
# Train_loss 0.59629594, Test loss : 0.53495465, Epoch 3
# Train_loss 0.59630962, Test loss : 0.53133619, Epoch 4
# Train_loss 0.59616508, Test loss : 0.52772929, Epoch 5
# Train_loss 0.59416398, Test loss : 0.52681808, Epoch 6
# Train_loss 0.59388458, Test loss : 0.52612809, Epoch 7
# Train_loss 0.59374760, Test loss : 0.52560817, Epoch 8
# Train_loss 0.59366820, Test loss : 0.52516138, Epoch 9
# Train_loss 0.59366362, Test loss : 0.52474440, Epoch 10
# Rmse lsoss -> 4.377167083263408
# Mean absolute error -> 3.9259629249572754
# R2 score -> -3.0
# Training...
# Train_loss 0.61254050, Test loss : 0.55872063, Epoch 1
# Train_loss 0.59216522, Test loss : 0.55777034, Epoch 2
# Train_loss 0.59186522, Test loss : 0.55407189, Epoch 3
# Train_loss 0.59183614, Test loss : 0.55121233, Epoch 4
# Train_loss 0.59181624, Test loss : 0.54910877, Epoch 5
# Train_loss 0.59082960, Test loss : 0.54911620, Epoch 6
# Train_loss 0.59082463, Test loss : 0.54897350, Epoch 7
# Train_loss 0.59084596, Test loss : 0.54882745, Epoch 8
# Train_loss 0.59082508, Test loss : 0.54866186, Epoch 9
# Train_loss 0.59079213, Test loss : 0.54848671, Epoch 10
# Rmse lsoss -> 4.624481584517027
# Mean absolute error -> 2.633607864379883
# R2 score -> 49.0
# Training...
# Train_loss 0.59640332, Test loss : 0.57858042, Epoch 1
# Train_loss 0.57159539, Test loss : 0.57252588, Epoch 2
# Train_loss 0.57249041, Test loss : 0.56918317, Epoch 3
# Train_loss 0.57235867, Test loss : 0.56684548, Epoch 4
# Train_loss 0.57226290, Test loss : 0.56542096, Epoch 5
# Train_loss 0.57155656, Test loss : 0.56509297, Epoch 6
# Train_loss 0.57134545, Test loss : 0.56488926, Epoch 7
# Train_loss 0.57121956, Test loss : 0.56469616, Epoch 8
# Train_loss 0.57125307, Test loss : 0.56457975, Epoch 9
# Train_loss 0.57114270, Test loss : 0.56442348, Epoch 10
# Rmse lsoss -> 4.706970670318156
# Mean absolute error -> 3.3812739849090576
# R2 score -> 28.999999999999996
# Training...
# Train_loss 0.59994826, Test loss : 0.56506288, Epoch 1
# Train_loss 0.58327420, Test loss : 0.56375115, Epoch 2
# Train_loss 0.58234268, Test loss : 0.56058763, Epoch 3
# Train_loss 0.58247077, Test loss : 0.55778175, Epoch 4
# Train_loss 0.58239589, Test loss : 0.55588625, Epoch 5
# Train_loss 0.58112416, Test loss : 0.55608107, Epoch 6
# Train_loss 0.58115342, Test loss : 0.55609265, Epoch 7
# Train_loss 0.58107650, Test loss : 0.55602672, Epoch 8
# Train_loss 0.58113320, Test loss : 0.55589869, Epoch 9
# Train_loss 0.58114624, Test loss : 0.55577440, Epoch 10
# Rmse lsoss -> 4.696327747130909
# Mean absolute error -> 2.2605576515197754
# R2 score -> 46.0
# Training...
# Train_loss 0.60263612, Test loss : 0.59302285, Epoch 1
# Train_loss 0.58639397, Test loss : 0.58417760, Epoch 2
# Train_loss 0.58555395, Test loss : 0.58019374, Epoch 3
# Train_loss 0.58537121, Test loss : 0.57692666, Epoch 4
# Train_loss 0.58537755, Test loss : 0.57443775, Epoch 5
# Train_loss 0.58475114, Test loss : 0.57424304, Epoch 6
# Train_loss 0.58472065, Test loss : 0.57403429, Epoch 7
# Train_loss 0.58470855, Test loss : 0.57383391, Epoch 8
# Train_loss 0.58470921, Test loss : 0.57364751, Epoch 9
# Train_loss 0.58469580, Test loss : 0.57348594, Epoch 10
# Rmse lsoss -> 4.800732977851798
# Mean absolute error -> 2.3554744720458984
# R2 score -> 62.0
# Training...
# Train_loss 0.61721691, Test loss : 0.55556725, Epoch 1
# Train_loss 0.59016710, Test loss : 0.54570946, Epoch 2
# Train_loss 0.58969085, Test loss : 0.54068404, Epoch 3
# Train_loss 0.58952296, Test loss : 0.53732750, Epoch 4
# Train_loss 0.58954108, Test loss : 0.53560887, Epoch 5
# Train_loss 0.58879930, Test loss : 0.53556908, Epoch 6
# Train_loss 0.58869551, Test loss : 0.53552977, Epoch 7
# Train_loss 0.58872385, Test loss : 0.53543162, Epoch 8
# Train_loss 0.58877154, Test loss : 0.53531853, Epoch 9
# Train_loss 0.58875024, Test loss : 0.53519247, Epoch 10
# Rmse lsoss -> 4.4845015345143455
# Mean absolute error -> 1.7422521114349365
# R2 score -> 68.0
# Training...
# Train_loss 0.62840421, Test loss : 0.57530167, Epoch 1
# Train_loss 0.59922470, Test loss : 0.56457645, Epoch 2
# Train_loss 0.59878567, Test loss : 0.56009643, Epoch 3
# Train_loss 0.59863897, Test loss : 0.55653672, Epoch 4
# Train_loss 0.59866062, Test loss : 0.55405105, Epoch 5
# Train_loss 0.59790893, Test loss : 0.55395801, Epoch 6
# Train_loss 0.59786150, Test loss : 0.55389345, Epoch 7
# Train_loss 0.59786839, Test loss : 0.55382484, Epoch 8
# Train_loss 0.59785568, Test loss : 0.55377014, Epoch 9
# Train_loss 0.59792303, Test loss : 0.55371947, Epoch 10
# Rmse lsoss -> 4.66474579832997
# Mean absolute error -> 2.493225336074829
# R2 score -> 56.99999999999999
# Training...
# Train_loss 0.59144400, Test loss : 0.58787184, Epoch 1
# Train_loss 0.59414274, Test loss : 0.56985434, Epoch 2
# Train_loss 0.58902723, Test loss : 0.56795498, Epoch 3
# Train_loss 0.58957751, Test loss : 0.56348153, Epoch 4
# Train_loss 0.58908579, Test loss : 0.55971670, Epoch 5
# Train_loss 0.58691366, Test loss : 0.55738567, Epoch 6
# Train_loss 0.58635207, Test loss : 0.55545558, Epoch 7
# Train_loss 0.58600146, Test loss : 0.55420059, Epoch 8
# Train_loss 0.58589542, Test loss : 0.55333114, Epoch 9
# Train_loss 0.58574640, Test loss : 0.55267959, Epoch 10
# Rmse lsoss -> 4.567350970229232
# Mean absolute error -> 2.1762778759002686
# R2 score -> 61.0
# Training...
# Train_loss 0.62806838, Test loss : 0.61984177, Epoch 1
# Train_loss 0.58339110, Test loss : 0.59881716, Epoch 2
# Train_loss 0.58364299, Test loss : 0.59656772, Epoch 3
# Train_loss 0.58309061, Test loss : 0.59311097, Epoch 4
# Train_loss 0.58318959, Test loss : 0.59036946, Epoch 5
# Train_loss 0.58237759, Test loss : 0.59155762, Epoch 6
# Train_loss 0.58198745, Test loss : 0.59246323, Epoch 7
# Train_loss 0.58191223, Test loss : 0.59279659, Epoch 8
# Train_loss 0.58190825, Test loss : 0.59278289, Epoch 9
# Train_loss 0.58185088, Test loss : 0.59263476, Epoch 10
# Rmse lsoss -> 4.905688988750276
# Mean absolute error -> 2.8118910789489746
# R2 score -> 43.0

# %%
print([item[-1] for item in matrix_cv_base])
print([item[-3] for item in matrix_cv_base])

print([item[-1] for item in matrix_cv_noise])
print([item[-3] for item in matrix_cv_noise])

print([item[-1] for item in matrix_cv_low_demand])
print([item[-3] for item in matrix_cv_low_demand])
# Out:
# [4.7083983, 3.9861593, 4.8843303, 4.435147, 5.325112, 4.059162, 4.1979713, 3.1427252, 6.3875055, 5.1518717]
# [4.4122628383282185, 4.403941313945917, 4.58584828590554, 4.730907215112438, 4.7085580462729855, 4.787389266922212, 4.4693871957481575, 4.671185394730481, 4.65731655936975, 4.952322235999471]
# [2.449387, 1.5730556, 2.2537787, 1.977593, 1.2813935, 2.359893, 1.2854978, 1.8044716, 2.4137678, 2.6437085]
# [4.428678528857439, 4.402150946171753, 4.594651114384534, 4.745545959256534, 4.689462683182159, 4.796721912637602, 4.524080273645429, 4.660969844632995, 4.617044566051138, 4.95404737289873]
# [1.9205773, 3.925963, 2.6336079, 3.381274, 2.2605577, 2.3554745, 1.7422521, 2.4932253, 2.1762779, 2.811891]
# [4.400721118095639, 4.377167083263408, 4.624481584517027, 4.706970670318156, 4.696327747130909, 4.800732977851798, 4.4845015345143455, 4.66474579832997, 4.567350970229232, 4.905688988750276]

# %%
print(np.average([item[-2] for item in matrix_cv_base]))
print(np.average([item[-2] for item in matrix_cv_noise]))
print(np.average([item[-2] for item in matrix_cv_low_demand]))
# Out:
# -46.0
# 65.6
# 47.5

# %%
matrix_cv_base_MAE = [item[-1] for item in matrix_cv_base]
matrix_cv_noise_MAE = [item[-1] for item in matrix_cv_noise]
matrix_cv_low_demand_MAE = [item[-1] for item in matrix_cv_low_demand]

# %%
print([item[-2] for item in matrix_cv_base])
print([item[-2] for item in matrix_cv_noise])
print([item[-2] for item in matrix_cv_low_demand])
# Out:
# [-54.0, -16.0, -60.0, -18.0, -81.0, -12.0, -34.0, 37.0, -167.0, -55.00000000000001]
# [47.0, 79.0, 54.0, 69.0, 83.0, 57.99999999999999, 86.0, 78.0, 52.0, 50.0]
# [63.0, -3.0, 49.0, 28.999999999999996, 46.0, 62.0, 68.0, 56.99999999999999, 61.0, 43.0]

# %%
print(stats.ttest_ind([item[-2] for item in matrix_cv_base], [item[-2] for item in matrix_cv_noise]))
print(stats.ttest_ind([item[-2] for item in matrix_cv_base], [item[-2] for item in matrix_cv_low_demand]))
print(stats.ttest_ind([item[-2] for item in matrix_cv_noise], [item[-2] for item in matrix_cv_low_demand]))
# Out:
# Ttest_indResult(statistic=-6.314688567695471, pvalue=5.954346008667122e-06)
# Ttest_indResult(statistic=-5.109255714222828, pvalue=7.333431761543622e-05)
# Ttest_indResult(statistic=2.200184470153362, pvalue=0.04109347824966965)

# %% [markdown]
#  * Summery

# %%
summery.update({ city_name: {
    "base_model": {
        "skill_score": base_model_skill,
        "MAE_score": base_model_MAE_score,
        "RMSE_score": base_model_RSME_score,
        "R2_score": base_model_R2_score
    },
    "noise_model": {
        "skill_score": noise_model_skill,
        "MAE_score": noise_model_MAE_score,
        "RMSE_score": noise_model_RSME_score,
        "R2_score": noise_model_R2_score
    },
    "low_demand_model": {
        "skill_score": low_demand_model_skill,
        "MAE_score": low_demand_model_MAE_score,
        "RMSE_score": low_demand_model_RSME_score,
        "R2_score": low_demand_model_R2_score
    }
}})
localStorage.save_to_pkl(summery)

# %% [markdown]
# - KNN, hypothesis

# %% [markdown]
# - Write about the hypothesis

# %% [markdown]
# ## Hypothesis -
#
#     * Apply KNN on the data, and see different ponts in a graph, Find similar ponts(similarity methos) and compare their evaluation and fix the data.
#     * For example, if some points falls within the same cluster and differ by their demand then their might be somw issue, in the training data
#     * Also, write about how difficlut it would be to find the similar points, as time series data works differently compare to the normal data set

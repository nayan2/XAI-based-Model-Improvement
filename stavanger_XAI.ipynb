# %% [markdown]
# ## Findings
#     -> We can see different heat map for differnt test data, while most of them have different error rate.
#     -> We can see that the heat map would be different consideing the fact that, error rate is different.
#     -> We would probbaly generate different heat map, for different range of errors.

# %% [markdown]
# ## Research path -
#     -> Ways to improve the model performace using/through/by XAI
# ## Tasks -
#     -> Generate Attention Map
#     -> Do perturbation analysis/ add or remove data points/ Use any classification technique to improve model performance
#     -> Use some other technique using XAI and compare the results
#     -> Propose some novel technique
#     -> Create seperate model for different cities

# %% [markdown]
# ## Writing suggession
#     -> Have to write why, demand forecasting is important
#     -> The money issue, And what we are tring to achieve from the thesis

# %% [markdown]
# # Improvements suggested -
#     -> Add window feature
#     -> Add lag feature from previous week same day
#     -> Add skill score
#     -> Use absolute error for test data
#     -> Use baseline forescast to evaluate the model

# %%
# %reload_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '../helper/')

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from scipy import stats
import data as data_helper
import model as model_helper
import config
import localStorage
# Out:
# Choosen device cuda

# %% [markdown]
# ## Global Variables

# %%
city_name = "stavanger"
summery = { city_name: {} }

# %% [markdown]
# ## Load the data

# %%
train = data_helper.load_train_data(city_name)

# %%
train = data_helper.filter_train_data(train)

# %%
train.head()
# Out:
#                          place  temperature    demand
# time
# 2022-04-08 00:00:00  stavanger          1.1  1.782011
# 2022-04-08 01:00:00  stavanger          1.0  1.744253
# 2022-04-08 02:00:00  stavanger          0.4  1.753405
# 2022-04-08 03:00:00  stavanger          0.4  1.745010
# 2022-04-08 04:00:00  stavanger          1.1  1.895899

# %% [markdown]
# # Data analysis

# %%
data_helper.show_density_plot(train)

# %%
train.isna().sum()
# Out:
# place          0
# temperature    0
# demand         0
# dtype: int64

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# - Time Feature Extraction\
#   -> Year\
#   -> month_cos\
#   -> month_sin\
#   -> day_cos\
#   -> day_sin\
#   -> hour_cos\
#   -> hour_sin\
#   -> Public holiday or not\
#   -> Daylight savings or not\
#   -> Weekend or not\
#   -> Business hour or not\
#   -> Season of the year

# %%
train_1 = data_helper.add_feature(train)

# %%
train_1.head()
# Out:
#                          place  temperature    demand  month_sin  month_cos  \
# time
# 2022-04-08 00:00:00  stavanger          1.1  1.782011   0.866025       -0.5
# 2022-04-08 01:00:00  stavanger          1.0  1.744253   0.866025       -0.5
# 2022-04-08 02:00:00  stavanger          0.4  1.753405   0.866025       -0.5
# 2022-04-08 03:00:00  stavanger          0.4  1.745010   0.866025       -0.5
# 2022-04-08 04:00:00  stavanger          1.1  1.895899   0.866025       -0.5
#
#                       day_sin   day_cos  hour_sin  hour_cos  business_hour  \
# time
# 2022-04-08 00:00:00  0.993257 -0.115935  0.000000  1.000000              0
# 2022-04-08 01:00:00  0.993257 -0.115935  0.269797  0.962917              0
# 2022-04-08 02:00:00  0.993257 -0.115935  0.519584  0.854419              0
# 2022-04-08 03:00:00  0.993257 -0.115935  0.730836  0.682553              0
# 2022-04-08 04:00:00  0.993257 -0.115935  0.887885  0.460065              0
#
#                      season  weekend  daylight  holiday
# time
# 2022-04-08 00:00:00  spring        0         1        0
# 2022-04-08 01:00:00  spring        0         1        0
# 2022-04-08 02:00:00  spring        0         1        0
# 2022-04-08 03:00:00  spring        0         1        0
# 2022-04-08 04:00:00  spring        0         1        0

# %% [markdown]
# - One hot encode

# %%
train_2 = data_helper.one_hot_encoding(train_1, ['season'])

# %%
train_2.head()
# Out:
#                          place  temperature    demand  month_sin  month_cos  \
# time
# 2022-04-08 00:00:00  stavanger          1.1  1.782011   0.866025       -0.5
# 2022-04-08 01:00:00  stavanger          1.0  1.744253   0.866025       -0.5
# 2022-04-08 02:00:00  stavanger          0.4  1.753405   0.866025       -0.5
# 2022-04-08 03:00:00  stavanger          0.4  1.745010   0.866025       -0.5
# 2022-04-08 04:00:00  stavanger          1.1  1.895899   0.866025       -0.5
#
#                       day_sin   day_cos  hour_sin  hour_cos  business_hour  \
# time
# 2022-04-08 00:00:00  0.993257 -0.115935  0.000000  1.000000              0
# 2022-04-08 01:00:00  0.993257 -0.115935  0.269797  0.962917              0
# 2022-04-08 02:00:00  0.993257 -0.115935  0.519584  0.854419              0
# 2022-04-08 03:00:00  0.993257 -0.115935  0.730836  0.682553              0
# 2022-04-08 04:00:00  0.993257 -0.115935  0.887885  0.460065              0
#
#                      weekend  daylight  holiday  autumn  spring  summer
# time
# 2022-04-08 00:00:00        0         1        0       0       1       0
# 2022-04-08 01:00:00        0         1        0       0       1       0
# 2022-04-08 02:00:00        0         1        0       0       1       0
# 2022-04-08 03:00:00        0         1        0       0       1       0
# 2022-04-08 04:00:00        0         1        0       0       1       0

# %% [markdown]
# - Scale the data

# %%
x_scaler, y_scaler, train_3 = data_helper.scale(train_2)

# %%
train_3.head()
# Out:
#                      autumn  business_hour   day_cos   day_sin  daylight  \
# time
# 2022-04-08 00:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 01:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 02:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 03:00:00       0              0 -0.115935  0.993257         1
# 2022-04-08 04:00:00       0              0 -0.115935  0.993257         1
#
#                      holiday  hour_cos  hour_sin  month_cos  month_sin  \
# time
# 2022-04-08 00:00:00        0  1.000000  0.000000       -0.5   0.866025
# 2022-04-08 01:00:00        0  0.962917  0.269797       -0.5   0.866025
# 2022-04-08 02:00:00        0  0.854419  0.519584       -0.5   0.866025
# 2022-04-08 03:00:00        0  0.682553  0.730836       -0.5   0.866025
# 2022-04-08 04:00:00        0  0.460065  0.887885       -0.5   0.866025
#
#                          place  spring  summer  weekend  temperature    demand
# time
# 2022-04-08 00:00:00  stavanger       1       0        0    -0.430939 -0.760518
# 2022-04-08 01:00:00  stavanger       1       0        0    -0.436464 -0.770040
# 2022-04-08 02:00:00  stavanger       1       0        0    -0.469613 -0.767732
# 2022-04-08 03:00:00  stavanger       1       0        0    -0.469613 -0.769849
# 2022-04-08 04:00:00  stavanger       1       0        0    -0.430939 -0.731797

# %% [markdown]
# - Rearrange the columns

# %%
train_4 = train_3[config.COLUMN_NAMES]

# %%
train_4.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-04-08 00:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 01:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 02:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 03:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 04:00:00       1       0       0   0.866025       -0.5  0.993257
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-04-08 00:00:00 -0.115935  0.000000  1.000000              0        0
# 2022-04-08 01:00:00 -0.115935  0.269797  0.962917              0        0
# 2022-04-08 02:00:00 -0.115935  0.519584  0.854419              0        0
# 2022-04-08 03:00:00 -0.115935  0.730836  0.682553              0        0
# 2022-04-08 04:00:00 -0.115935  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature    demand
# time
# 2022-04-08 00:00:00         1        0    -0.430939 -0.760518
# 2022-04-08 01:00:00         1        0    -0.436464 -0.770040
# 2022-04-08 02:00:00         1        0    -0.469613 -0.767732
# 2022-04-08 03:00:00         1        0    -0.469613 -0.769849
# 2022-04-08 04:00:00         1        0    -0.430939 -0.731797

# %% [markdown]
# - Lag feature

# %%
train_5 = data_helper.add_lag(train_4, 1)

# %%
train_5.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-04-08 00:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 01:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 02:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 03:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 04:00:00       1       0       0   0.866025       -0.5  0.993257
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-04-08 00:00:00 -0.115935  0.000000  1.000000              0        0
# 2022-04-08 01:00:00 -0.115935  0.269797  0.962917              0        0
# 2022-04-08 02:00:00 -0.115935  0.519584  0.854419              0        0
# 2022-04-08 03:00:00 -0.115935  0.730836  0.682553              0        0
# 2022-04-08 04:00:00 -0.115935  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature  demand-1    demand
# time
# 2022-04-08 00:00:00         1        0    -0.430939  0.000000 -0.760518
# 2022-04-08 01:00:00         1        0    -0.436464 -0.760518 -0.770040
# 2022-04-08 02:00:00         1        0    -0.469613 -0.770040 -0.767732
# 2022-04-08 03:00:00         1        0    -0.469613 -0.767732 -0.769849
# 2022-04-08 04:00:00         1        0    -0.430939 -0.769849 -0.731797

# %% [markdown]
# - Baseline feature

# %%
train_6 = data_helper.add_baseline_feature(train_5)

# %%
train_6.head()
# Out:
#                      spring  summer  autumn  month_sin  month_cos   day_sin  \
# time
# 2022-04-08 00:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 01:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 02:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 03:00:00       1       0       0   0.866025       -0.5  0.993257
# 2022-04-08 04:00:00       1       0       0   0.866025       -0.5  0.993257
#
#                       day_cos  hour_sin  hour_cos  business_hour  weekend  \
# time
# 2022-04-08 00:00:00 -0.115935  0.000000  1.000000              0        0
# 2022-04-08 01:00:00 -0.115935  0.269797  0.962917              0        0
# 2022-04-08 02:00:00 -0.115935  0.519584  0.854419              0        0
# 2022-04-08 03:00:00 -0.115935  0.730836  0.682553              0        0
# 2022-04-08 04:00:00 -0.115935  0.887885  0.460065              0        0
#
#                      daylight  holiday  temperature  base_line_demand  \
# time
# 2022-04-08 00:00:00         1        0    -0.430939         -0.760518
# 2022-04-08 01:00:00         1        0    -0.436464         -0.770040
# 2022-04-08 02:00:00         1        0    -0.469613         -0.767732
# 2022-04-08 03:00:00         1        0    -0.469613         -0.769849
# 2022-04-08 04:00:00         1        0    -0.430939         -0.731797
#
#                      demand-1    demand
# time
# 2022-04-08 00:00:00  0.000000 -0.760518
# 2022-04-08 01:00:00 -0.760518 -0.770040
# 2022-04-08 02:00:00 -0.770040 -0.767732
# 2022-04-08 03:00:00 -0.767732 -0.769849
# 2022-04-08 04:00:00 -0.769849 -0.731797

# %% [markdown]
# - Split the final data for Base-line model

# %%
train_split_base_X = train_6.iloc[:, :-1]
train_split_base_Y = train_6.iloc[:, -1]

# %%
X_train_base, X_test_base, Y_train_base, Y_test_base = train_test_split(train_split_base_X, train_split_base_Y, test_size=0.2, random_state=0)

# %% [markdown]
# - Create sequence

# %%
train_split_X, train_split_Y = data_helper.split_sequences(train_6, config.WINDOW_SIZE)

# %% [markdown]
# - Train test split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train_split_X, train_split_Y, test_size=0.2, random_state=0)

# %% [markdown]
# - Model preparation

# %%
model_helper.show_me()

# %%
PATH = f"./data/{city_name}_model_XAI"
model = model_helper.train_model(np.shape(X_train[0])[-1], X_train, Y_train, X_test, Y_test, False, config.BATCH_SIZE, config.NUM_EPOCHS, config.PRC_EPOCH, PATH, True)
# Out:
# the model  ./data/stavanger_model_XAI has beed loaded !

# %% [markdown]
# - Test the performance

# %%
base_model_actual_value, base_model_predicted_value, base_model_RSME_score, base_model_R2_score, base_model_MAE_score, _, _ = model_helper.display_results(model, X_test, Y_test, y_scaler, (0, 7), (200, 400))
# print(actual), print(predicted)
# Comment about the result:: Capture variation but missing trend
# Out:
#   0%|          | 0/1690 [00:00<?, ?it/s]
# d:\Semester 4\XAI\../helper\model.py:316: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
#   seq = torch.FloatTensor([X[index]]).to(device=config.DEVICE)
# Rmse lsoss -> 2.008128338029487
# Mean absolute error -> 0.518963634967804
# R2 score -> 91.0

# %% [markdown]
# - Generate the explaination (global)

# %%
# compute global attention
meanAttn, meanScores = model_helper.generate_global_heatmap(model, X_test, "Global Heat Map")
# Out:
#   0%|          | 0/85 [00:00<?, ?it/s]

# %% [markdown]
# - How's the heatmap looks like, for good and bad predictions

# %%
good_pred, bad_pred = model_helper.split_good_bad_data(X_train, Y_train, model, y_scaler)
# Out:
#   0%|          | 0/6758 [00:00<?, ?it/s]

# %%
model_helper.generate_global_heatmap(model, good_pred, "Good Prediction Heat Map")
model_helper.generate_global_heatmap(model, bad_pred, "Bad Predictin Heat Map")
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/331 [00:00<?, ?it/s]
# (array([[-3.4207972e-09, -1.2098798e-10,  1.5266835e-08, ...,
#           3.4495883e-08, -1.9026695e-08, -8.5132461e-09],
#         [-3.5306937e-09, -3.3918120e-12,  1.5075553e-08, ...,
#           3.6163467e-08, -2.0485167e-08, -7.6292883e-09],
#         [-3.3012237e-09, -2.3744600e-11,  1.4442955e-08, ...,
#           3.6553516e-08, -2.1167304e-08, -6.4861672e-09],
#         ...,
#         [-7.1148193e-10,  3.0979352e-10,  3.8661350e-09, ...,
#           1.1023007e-08, -7.9533402e-09,  1.2815997e-09],
#         [-3.3974420e-10,  1.9914644e-10,  2.3111977e-09, ...,
#           6.4582908e-09, -4.6575797e-09,  9.5946595e-10],
#         [-5.8783693e-11,  6.6785709e-11,  8.9267926e-10, ...,
#           2.4539277e-09, -1.7187901e-09,  4.4170112e-10]], dtype=float32),
#  array([[0.00610588],
#         [0.00605589],
#         [0.00601604],
#         [0.00598804],
#         [0.00596987],
#         [0.00595882],
#         [0.00595256],
#         [0.00594932],
#         [0.00594786],
#         [0.00594743],
#         [0.00594754],
#         [0.00594788],
#         [0.0059483 ],
#         [0.0059487 ],
#         [0.00594904],
#         [0.00594932],
#         [0.0059495 ],
#         [0.00594961],
#         [0.00594964],
#         [0.00594962],
#         [0.00594955],
#         [0.00594945],
#         [0.00594934],
#         [0.00594919],
#         [0.00594907],
#         [0.00594895],
#         [0.00594887],
#         [0.00594881],
#         [0.0059488 ],
#         [0.00594886],
#         [0.00594894],
#         [0.00594904],
#         [0.0059492 ],
#         [0.00594938],
#         [0.00594956],
#         [0.00594975],
#         [0.00594991],
#         [0.00595006],
#         [0.00595016],
#         [0.00595023],
#         [0.00595024],
#         [0.00595025],
#         [0.00595019],
#         [0.00595009],
#         [0.00594998],
#         [0.00594982],
#         [0.00594967],
#         [0.00594952],
#         [0.00594937],
#         [0.00594922],
#         [0.00594913],
#         [0.00594905],
#         [0.00594904],
#         [0.00594907],
#         [0.00594914],
#         [0.00594927],
#         [0.00594942],
#         [0.00594959],
#         [0.00594978],
#         [0.00594996],
#         [0.00595013],
#         [0.00595027],
#         [0.00595037],
#         [0.00595044],
#         [0.00595047],
#         [0.00595044],
#         [0.00595037],
#         [0.00595029],
#         [0.00595015],
#         [0.00594999],
#         [0.00594983],
#         [0.00594966],
#         [0.00594953],
#         [0.00594939],
#         [0.00594929],
#         [0.00594921],
#         [0.00594919],
#         [0.00594923],
#         [0.00594932],
#         [0.00594945],
#         [0.00594962],
#         [0.00594979],
#         [0.00594997],
#         [0.00595018],
#         [0.00595034],
#         [0.00595051],
#         [0.00595062],
#         [0.00595071],
#         [0.00595076],
#         [0.00595073],
#         [0.00595069],
#         [0.00595058],
#         [0.00595044],
#         [0.00595031],
#         [0.00595015],
#         [0.00594999],
#         [0.00594984],
#         [0.00594971],
#         [0.00594961],
#         [0.00594954],
#         [0.00594952],
#         [0.00594954],
#         [0.00594962],
#         [0.00594974],
#         [0.00594991],
#         [0.00595007],
#         [0.00595025],
#         [0.00595044],
#         [0.00595062],
#         [0.00595077],
#         [0.0059509 ],
#         [0.00595099],
#         [0.00595103],
#         [0.00595104],
#         [0.00595098],
#         [0.00595088],
#         [0.00595075],
#         [0.00595061],
#         [0.00595046],
#         [0.00595028],
#         [0.00595013],
#         [0.00595001],
#         [0.00594989],
#         [0.00594983],
#         [0.00594981],
#         [0.00594982],
#         [0.00594988],
#         [0.00594998],
#         [0.00595013],
#         [0.00595029],
#         [0.00595048],
#         [0.00595067],
#         [0.00595085],
#         [0.00595101],
#         [0.00595114],
#         [0.00595122],
#         [0.00595125],
#         [0.00595126],
#         [0.0059512 ],
#         [0.0059511 ],
#         [0.00595099],
#         [0.00595083],
#         [0.00595068],
#         [0.00595052],
#         [0.00595036],
#         [0.00595022],
#         [0.00595011],
#         [0.00595004],
#         [0.00595001],
#         [0.00595005],
#         [0.0059501 ],
#         [0.00595022],
#         [0.00595036],
#         [0.00595054],
#         [0.00595071],
#         [0.00595089],
#         [0.00595108],
#         [0.00595121],
#         [0.00595133],
#         [0.0059514 ],
#         [0.00595143],
#         [0.00595139],
#         [0.00595136],
#         [0.00595127],
#         [0.00595115],
#         [0.00595101],
#         [0.00595085],
#         [0.00595071]], dtype=float32))

# %% [markdown]
# - Generate the explaination (Local)

# %%
heat_index = 1
res = model_helper.disp_grads_rk(model_helper.compute_grads(None, model, X_test[heat_index]))
print(f"Actual result -> {Y_test[heat_index]} && Predicted result -> {res}")
print(f"Error - {np.mean(np.abs(Y_test[heat_index] - res))}")
# Out:
# Actual result -> 0.00853371833143668 && Predicted result -> -0.3487960696220398
# Error - 0.3573297879534765

# %% [markdown]
# - Partial dependency plt, to manipulate the data

# %%
X, y = train_6.iloc[:, :-1], np.reshape(y_scaler.inverse_transform(np.reshape(train_6.iloc[:, -1].to_numpy(), (-1, 1))), (-1))

# %%
# polyreg = model_helper.train_plyrg_model(4, X, y)

# %%
# model_helper.generate_feature_graph(polyreg, X, 3, int(len(X.columns)/3), X.columns[:-1])

# %% [markdown]
# - Perturbation analysis or replace less important data with random noise, K-nearest neighbor, Augmented data

# %% [markdown]
# - Random noise

# %%
# Add random noise based on the heatmap
light_blue = (0.00594, 0.00596)
dark_red = (0.00597, )
X_train_with_noise = data_helper.add_random_noise(X_train, light_blue, dark_red, model)

# %%
# Retrain the model with the new data
PATH_NOISE = f"./data/{city_name}_model_XAI_Noise"
model_noise = model_helper.train_model(np.shape(X_train[0])[-1], X_train_with_noise, Y_train, X_test, Y_test, False, config.BATCH_SIZE, 6, config.PRC_EPOCH, PATH_NOISE, True)
# Out:
# the model  ./data/stavanger_model_XAI_Noise has beed loaded !

# %%
# Check the performance
noise_model_actual_value, noise_model_predicted_value, noise_model_RSME_score, noise_model_R2_score, noise_model_MAE_score, _, _ = model_helper.display_results(model_noise, X_test, Y_test, y_scaler, (0.7, 7), [200, 400])
print(noise_model_actual_value), print(noise_model_predicted_value)
# Out:
#   0%|          | 0/1690 [00:00<?, ?it/s]
# Rmse lsoss -> 2.0057916230494173
# Mean absolute error -> 0.514903724193573
# R2 score -> 90.0
# [6.7319546, 4.8315988, 1.0077199, 1.7626721, 5.893128, 1.3743541, 2.212086, 5.061247, 3.8994548, 4.0338907, 1.4814501, 5.672304, 1.266065, 2.968276, 4.551357, 2.2332249, 1.0278331, 5.301267, 1.458379, 1.1099813, 1.4196032, 7.196531, 6.8061557, 3.6135669, 1.021203, 1.4410043, 6.60652, 3.1022818, 1.7585809, 5.919124, 3.196739, 1.4702492, 4.413298, 1.0577942, 6.1438704, 1.4985602, 1.1837261, 2.5702422, 1.6257492, 5.8129272, 6.430493, 2.0547361, 1.2082281, 1.731545, 5.297871, 3.0131829, 1.110929, 3.9221609, 2.5596752, 1.403281, 6.434229, 1.3411292, 6.568349, 1.4130441, 1.4032391, 1.2542411, 1.3642511, 2.865354, 1.801475, 6.235536, 5.687591, 2.698472, 6.522079, 1.0137893, 1.3684762, 1.712868, 5.409825, 1.783326, 1.149625, 1.3849571, 2.931339, 1.2047031, 1.1078912, 1.4468701, 1.6600181, 5.319888, 5.1775813, 5.1253176, 1.530349, 5.974529, 5.462353, 5.4741817, 4.7619133, 1.098159, 1.5193369, 3.9675753, 5.219501, 6.119645, 1.198021, 2.811152, 5.448836, 1.0818722, 1.1996012, 4.4235597, 5.279173, 1.222403, 0.9747462, 1.8632761, 1.763841, 1.4631683, 6.275324, 1.1297512, 7.9511676, 1.240545, 1.1201162, 6.293927, 1.236128, 1.057679, 1.2469373, 1.3567121, 1.824974, 6.153342, 5.563644, 5.108078, 5.7300158, 1.3703389, 1.655199, 1.4953152, 1.682177, 1.7123971, 1.54946, 5.136158, 5.28967, 0.8562931, 1.339898, 4.501198, 5.6836348, 7.333515, 5.780742, 1.521706, 5.758701, 1.2502391, 1.252786, 1.5984529, 1.534992, 2.9733028, 1.2115331, 5.555758, 5.1503987, 1.1165881, 1.531207, 1.1989481, 1.8476139, 1.572032, 7.313476, 1.4781001, 4.5863457, 2.95678, 1.4270021, 1.3232253, 7.645208, 1.482617, 0.9949981, 1.4769121, 1.5883312, 4.969521, 6.37166, 7.40516, 5.193369, 6.213109, 6.731882, 1.0184951, 7.2314568, 1.390319, 2.959527, 6.04147, 5.833767, 1.8790549, 2.9567778, 1.1406671, 7.531233, 1.3985423, 1.6155632, 1.2097292, 5.2342443, 1.930441, 1.6671879, 6.0955815, 3.9220169, 1.7053471, 1.494196, 1.2270921, 5.452168, 3.488983, 3.3347878, 1.4685111, 1.172502, 2.5868561, 1.2412173, 1.561049, 1.5623381, 1.3131591, 0.9625741, 1.5434601, 1.589229, 2.191096, 1.9809511, 1.147512, 1.11099, 3.9783, 5.287841, 5.0357013, 1.3266082, 1.625439, 4.8223467, 3.055979, 1.433014, 5.717093, 1.3266441, 6.772846, 1.9274681, 2.488565, 1.791866, 4.757094, 5.901515, 6.804843, 5.699592, 1.382423, 2.397289, 7.0359817, 3.864006, 4.944286, 5.610179, 1.4188942, 7.016435, 1.733503, 2.5139298, 1.0709802, 4.9111624, 1.530063, 1.5527371, 6.0911818, 4.7370687, 1.4459091, 1.2169591, 1.3495141, 1.515314, 6.793438, 1.311996, 3.036984, 1.6668199, 1.532203, 3.780221, 1.6028041, 5.699384, 5.3865, 3.2634377, 1.2655252, 1.3949133, 4.549374, 4.996902, 0.94422305, 1.5732, 1.7788811, 1.5020783, 5.872624, 5.1784134, 1.4484211, 1.165501, 1.8285899, 2.82451, 1.3071462, 2.316575, 5.434219, 1.0106541, 1.5297612, 6.323901, 1.1157001, 5.5913067, 1.4208821, 1.4526691, 4.9103537, 0.94388103, 1.2971791, 1.164659, 1.4337779, 0.9086111, 1.766193, 6.4039097, 5.8378487, 1.5546341, 1.0989752, 7.8711762, 3.0088668, 6.7680087, 6.616685, 1.637917, 5.4263287, 1.2551349, 1.302135, 4.543608, 1.2943842, 6.8337936, 3.23371, 1.717181, 1.020543, 1.7376169, 1.4844142, 3.139312, 6.4253225, 3.871485, 3.1347928, 1.2270011, 4.46761, 1.6014459, 1.0243381, 1.0809549, 5.737507, 1.442117, 1.095747, 5.1274447, 3.334829, 5.31217, 1.673151, 1.4805349, 3.945517, 1.0015749, 5.318405, 1.3979892, 2.591426, 5.749556, 2.985964, 1.3152399, 6.597202, 5.921216, 1.0396279, 3.937242, 1.3758761, 1.5617812, 4.001125, 5.130373, 5.221111, 6.582969, 5.693139, 1.2978711, 1.354192, 5.511013, 6.169075, 5.678098, 1.2505761, 5.534642, 5.1833467, 1.265075, 3.69782, 1.1770431, 5.49937, 3.880985, 1.495943, 6.533338, 1.3284681, 5.462728, 4.503016, 1.6459761, 4.3379474, 1.1922212, 1.653285, 1.8292371, 1.862052, 5.9120317, 5.803172, 5.918098, 4.020812, 1.978948, 6.458135, 1.678352, 1.4005862, 5.154013, 1.1835141, 5.861707, 3.334754, 3.529983, 1.3717481, 1.4518529, 5.243769, 1.182935, 5.403254, 2.727598, 5.123695, 6.278175, 1.834586, 6.303414, 1.4065942, 1.9121381, 1. ...
# [6.1486664 4.9694977 1.4123764 ... 6.095619  2.8034058 2.234932 ]
# (None, None)

# %% [markdown]
# ## Analysis from the PDP -
#     -> OSLO is the only city that consume a tons of electricy compare to the other ctities
#     -> All the other cities might have a normal electricity demand
#     -> It, would be a good experiment, to see, if the deduct Bergen data from the training data set, it might overall improve the model performance
#     -> From the month graph - it seems like, at the end of the year (11, 12), consumption really spikes
#     -> From the day graph - it seems like, on the day (3,4) the consumption spikes
#     -> From the daylight graph - it seems like, if the daylight increase, consumption decrease
#     -> From the holiday graph - it seems like, during the hoiliday consumption increase
#     -> And, all the other feature, doesnt have that much deviative impact

# %% [markdown]
# ## The whole hypothesis, is based on our specific model perforrmance, we we can call it model(technique) dependent
#     -> As we can see from the model performace that, its under performing for some prediction, that is preety low compare to the average demand

# %% [markdown]
# - Try to adjust the training data with all the others finding and see if that improves the performance
# - The hypothesis is that, from the prediction graph, we can see that, mostly our model is not performing well when the consumption is going down
# - For all the spikes, the model is performing well, to solve the problem we could use different hypothesis, we could add some penalize terms to the model for lower consumption mitchmatch
# - Or we could modify some traing data and convert some somple to more lower degree and see how the model perform, Or add some bias(lower consumption example) to the trainign data and see how the model perform.

# %% [markdown]
# # Lets try the data modification

# %%
train_low_demand = data_helper.adjust_train_data(train_6)

# %%
train_low_demand_split_X, train_low_demand_split_Y = data_helper.split_sequences(train_low_demand, config.WINDOW_SIZE)
X_train_low_demand, X_test_low_demand, Y_train_low_demand, Y_test_low_demand = train_test_split(train_low_demand_split_X, train_low_demand_split_Y, test_size=0.2, random_state=0)

# %%
# Retrain the model with the new data
PATH_LOW_DEMAND = f"./data/{city_name}_model_XAI_low_demand"
model_low_demand = model_helper.train_model(np.shape(X_train[0])[-1], X_train_low_demand, Y_train_low_demand, X_test_low_demand,
                               Y_test_low_demand, False, config.BATCH_SIZE, 10, config.PRC_EPOCH, PATH_LOW_DEMAND, True)
# Out:
# the model  ./data/stavanger_model_XAI_low_demand has beed loaded !

# %%
# Check the performance
low_demand_model_actual_value, low_demand_model_predicted_value, low_demand_model_RSME_score, low_demand_model_R2_score, low_demand_model_MAE_score, _, _ = model_helper.display_results(
    model_low_demand, X_test_low_demand, Y_test_low_demand, y_scaler, (-2, 7), (400, 700))
print(low_demand_model_actual_value), print(low_demand_model_predicted_value)
# Out:
#   0%|          | 0/1690 [00:00<?, ?it/s]
# Rmse lsoss -> 2.0199660049070687
# Mean absolute error -> 0.5001181960105896
# R2 score -> 90.0
# [6.7319546, 4.8315988, 1.0077199, 1.7626721, 5.893128, 1.3743541, 2.212086, 5.061247, 3.8994548, 4.0338907, 1.4814501, 5.672304, 1.266065, 2.968276, 4.551357, 2.2332249, 1.0278331, 5.301267, 1.458379, 1.1099813, 1.4196032, 7.196531, 6.8061557, 3.6135669, 1.021203, 1.4410043, 6.60652, 3.1022818, 1.7585809, 5.919124, 3.196739, 1.4702492, 4.413298, 1.0577942, 6.1438704, 1.4985602, 1.1837261, 2.5702422, 1.6257492, 5.8129272, 6.430493, 2.0547361, 1.2082281, 1.731545, 5.297871, 3.0131829, 1.110929, 3.9221609, 2.5596752, 1.403281, 6.434229, 1.3411292, 6.568349, 1.4130441, 1.4032391, 1.2542411, 1.3642511, 2.865354, 1.801475, 6.235536, 5.687591, 2.698472, 6.522079, 1.0137893, 1.3684762, 1.712868, 5.409825, 1.783326, 1.149625, 1.3849571, 2.931339, 1.2047031, 1.1078912, 1.4468701, 1.6600181, 5.319888, 5.1775813, 5.1253176, 1.530349, 5.974529, 5.462353, 5.4741817, 4.7619133, 1.098159, 1.5193369, 3.9675753, 5.219501, 6.119645, 1.198021, 2.811152, 5.448836, 1.0818722, 1.1996012, 4.4235597, 5.279173, 1.222403, 0.9747462, 1.8632761, 1.763841, 1.4631683, 6.275324, 1.1297512, 7.9511676, 1.240545, 1.1201162, 6.293927, 1.236128, 1.057679, 1.2469373, 1.3567121, 1.824974, 6.153342, 5.563644, 5.108078, 5.7300158, 1.3703389, 1.655199, 1.4953152, 1.682177, 1.7123971, 1.54946, 5.136158, 5.28967, 0.8562931, 1.339898, 4.501198, 5.6836348, 7.333515, 5.780742, 1.521706, 5.758701, 1.2502391, 1.252786, 1.5984529, 1.534992, 2.9733028, 1.2115331, 5.555758, 5.1503987, 1.1165881, 1.531207, 1.1989481, 1.8476139, 1.572032, 7.313476, 1.4781001, 4.5863457, 2.95678, 1.4270021, 1.3232253, 7.645208, 1.482617, 0.9949981, 1.4769121, 1.5883312, 4.969521, 6.37166, 7.40516, 5.193369, 6.213109, 6.731882, 1.0184951, 7.2314568, 1.390319, 2.959527, 6.04147, 5.833767, 1.8790549, 2.9567778, 1.1406671, 7.531233, 1.3985423, 1.6155632, 1.2097292, 5.2342443, 1.930441, 1.6671879, 6.0955815, 3.9220169, 1.7053471, 1.494196, 1.2270921, 5.452168, 3.488983, 3.3347878, 1.4685111, 1.172502, 2.5868561, 1.2412173, 1.561049, 1.5623381, 1.3131591, 0.9625741, 1.5434601, 1.589229, 2.191096, 1.9809511, 1.147512, 1.11099, 3.9783, 5.287841, 5.0357013, 1.3266082, 1.625439, 4.8223467, 3.055979, 1.433014, 5.717093, 1.3266441, 6.772846, 1.9274681, 2.488565, 1.791866, 4.757094, 5.901515, 6.804843, 5.699592, 1.382423, 2.397289, 7.0359817, 3.864006, 4.944286, 5.610179, 1.4188942, 7.016435, 1.733503, 2.5139298, 1.0709802, 4.9111624, 1.530063, 1.5527371, 6.0911818, 4.7370687, 1.4459091, 1.2169591, 1.3495141, 1.515314, 6.793438, 1.311996, 3.036984, 1.6668199, 1.532203, 3.780221, 1.6028041, 5.699384, 5.3865, 3.2634377, 1.2655252, 1.3949133, 4.549374, 4.996902, 0.94422305, 1.5732, 1.7788811, 1.5020783, 5.872624, 5.1784134, 1.4484211, 1.165501, 1.8285899, 2.82451, 1.3071462, 2.316575, 5.434219, 1.0106541, 1.5297612, 6.323901, 1.1157001, 5.5913067, 1.4208821, 1.4526691, 4.9103537, 0.94388103, 1.2971791, 1.164659, 1.4337779, 0.9086111, 1.766193, 6.4039097, 5.8378487, 1.5546341, 1.0989752, 7.8711762, 3.0088668, 6.7680087, 6.616685, 1.637917, 5.4263287, 1.2551349, 1.302135, 4.543608, 1.2943842, 6.8337936, 3.23371, 1.717181, 1.020543, 1.7376169, 1.4844142, 3.139312, 6.4253225, 3.871485, 3.1347928, 1.2270011, 4.46761, 1.6014459, 1.0243381, 1.0809549, 5.737507, 1.442117, 1.095747, 5.1274447, 3.334829, 5.31217, 1.673151, 1.4805349, 3.945517, 1.0015749, 5.318405, 1.3979892, 2.591426, 5.749556, 2.985964, 1.3152399, 6.597202, 5.921216, 1.0396279, 3.937242, 1.3758761, 1.5617812, 4.001125, 5.130373, 5.221111, 6.582969, 5.693139, 1.2978711, 1.354192, 5.511013, 6.169075, 5.678098, 1.2505761, 5.534642, 5.1833467, 1.265075, 3.69782, 1.1770431, 5.49937, 3.880985, 1.495943, 6.533338, 1.3284681, 5.462728, 4.503016, 1.6459761, 4.3379474, 1.1922212, 1.653285, 1.8292371, 1.862052, 5.9120317, 5.803172, 5.918098, 4.020812, 1.978948, 6.458135, 1.678352, 1.4005862, 5.154013, 1.1835141, 5.861707, 3.334754, 3.529983, 1.3717481, 1.4518529, 5.243769, 1.182935, 5.403254, 2.727598, 5.123695, 6.278175, 1.834586, 6.303414, 1.4065942, 1.9121381, 1. ...
# [ 3.373352   1.6101761 -2.        ...  5.8140182  2.8197403  2.0058136]
# (None, None)

# %% [markdown]
# ## Base-line model
#
#     -> https://machinelearningmastery.com/persistence-time-series-forecasting-with-python/
#
# ## Skill score
#
# You are told that your skill score for temperature forecasts last month was +0.25 (25%). The standard forecast used for comparison was in error by 2 degrees on average. This means:
#
#     -> Your error is 0.25 degrees smaller than the standard score.
#     -> The error of your forecasts is 2.5 degrees.
#     -> The error of your forecasts is 1.5 degrees.

# %%
base_line_model_predicted_value, base_line_model_actual_value = model_helper.model_base_line(X_test_base, Y_test_base, y_scaler)
base_line_model_MAE_score = np.mean(np.abs(np.subtract(base_line_model_actual_value, base_line_model_predicted_value)))
print(f"Base model MAE - {base_line_model_MAE_score}")
# Out:
# Base model MAE - 2.145991035759861

# %% [markdown]
#  * Base model skill

# %%
base_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, base_model_predicted_value, base_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.7952270427166339

# %% [markdown]
#  * Noise model skill

# %%
noise_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, noise_model_predicted_value, noise_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.797211367527091

# %% [markdown]
#  * Low-demnad model skill

# %%
low_demand_model_skill = model_helper.diplay_skill_grph(base_line_model_actual_value, 0.10, low_demand_model_predicted_value, low_demand_model_MAE_score, base_line_model_predicted_value, base_line_model_MAE_score, (200, 300))
# Out:
# The skill score -> 0.8044379525533993

# %% [markdown]
# ## Cross validation

# %%
matrix_cv_base = model_helper.cross_validation(X_train, Y_train, 10, y_scaler, (0, 7))
matrix_cv_noise = model_helper.cross_validation(X_train_with_noise, Y_train, 10, y_scaler, (0.7, 7))
matrix_cv_low_demand = model_helper.cross_validation(X_train_low_demand, Y_train_low_demand, 10, y_scaler, (-2, 7))
# Out:
# Training...
# Train_loss 0.57057233, Test loss : 0.53389550, Epoch 1
# Train_loss 0.55594273, Test loss : 0.52072528, Epoch 2
# Train_loss 0.55477467, Test loss : 0.51768706, Epoch 3
# Train_loss 0.55420376, Test loss : 0.51474207, Epoch 4
# Train_loss 0.55396694, Test loss : 0.51136135, Epoch 5
# Train_loss 0.55122165, Test loss : 0.51102981, Epoch 6
# Train_loss 0.55136765, Test loss : 0.51057072, Epoch 7
# Train_loss 0.55140416, Test loss : 0.51012233, Epoch 8
# Train_loss 0.55131753, Test loss : 0.50967553, Epoch 9
# Train_loss 0.55132643, Test loss : 0.50920478, Epoch 10
# Rmse lsoss -> 2.0203492151687317
# Mean absolute error -> 0.604887068271637
# R2 score -> 89.0
# Training...
# Train_loss 0.59379147, Test loss : 0.52299726, Epoch 1
# Train_loss 0.56469206, Test loss : 0.51114276, Epoch 2
# Train_loss 0.56145966, Test loss : 0.50890222, Epoch 3
# Train_loss 0.56179763, Test loss : 0.50650914, Epoch 4
# Train_loss 0.56164552, Test loss : 0.50412462, Epoch 5
# Train_loss 0.55969783, Test loss : 0.50284728, Epoch 6
# Train_loss 0.55927912, Test loss : 0.50199739, Epoch 7
# Train_loss 0.55906652, Test loss : 0.50145914, Epoch 8
# Train_loss 0.55915010, Test loss : 0.50102305, Epoch 9
# Train_loss 0.55908348, Test loss : 0.50062549, Epoch 10
# Rmse lsoss -> 1.985661127411986
# Mean absolute error -> 0.9399760365486145
# R2 score -> 68.0
# Training...
# Train_loss 0.58634183, Test loss : 0.53117381, Epoch 1
# Train_loss 0.55816288, Test loss : 0.52888261, Epoch 2
# Train_loss 0.55738771, Test loss : 0.52704637, Epoch 3
# Train_loss 0.55749045, Test loss : 0.52487878, Epoch 4
# Train_loss 0.55751667, Test loss : 0.52337942, Epoch 5
# Train_loss 0.55617625, Test loss : 0.52329036, Epoch 6
# Train_loss 0.55633231, Test loss : 0.52309053, Epoch 7
# Train_loss 0.55632546, Test loss : 0.52290226, Epoch 8
# Train_loss 0.55628027, Test loss : 0.52275482, Epoch 9
# Train_loss 0.55631376, Test loss : 0.52258319, Epoch 10
# Rmse lsoss -> 2.0717905202820144
# Mean absolute error -> 0.9888380765914917
# R2 score -> 65.0
# Training...
# Train_loss 0.57708813, Test loss : 0.55401716, Epoch 1
# Train_loss 0.54103456, Test loss : 0.54739363, Epoch 2
# Train_loss 0.54173493, Test loss : 0.54518772, Epoch 3
# Train_loss 0.54141381, Test loss : 0.54293626, Epoch 4
# Train_loss 0.54130394, Test loss : 0.54096054, Epoch 5
# Train_loss 0.54064152, Test loss : 0.54080105, Epoch 6
# Train_loss 0.54052653, Test loss : 0.54066180, Epoch 7
# Train_loss 0.54037148, Test loss : 0.54046479, Epoch 8
# Train_loss 0.54042208, Test loss : 0.54027680, Epoch 9
# Train_loss 0.54040832, Test loss : 0.54005504, Epoch 10
# Rmse lsoss -> 2.1419488753086604
# Mean absolute error -> 0.9965335726737976
# R2 score -> 70.0
# Training...
# Train_loss 0.58285985, Test loss : 0.53735737, Epoch 1
# Train_loss 0.55364631, Test loss : 0.53655311, Epoch 2
# Train_loss 0.55269427, Test loss : 0.53445015, Epoch 3
# Train_loss 0.55287995, Test loss : 0.53245324, Epoch 4
# Train_loss 0.55278147, Test loss : 0.53065952, Epoch 5
# Train_loss 0.55152290, Test loss : 0.53074302, Epoch 6
# Train_loss 0.55147477, Test loss : 0.53064017, Epoch 7
# Train_loss 0.55148935, Test loss : 0.53046334, Epoch 8
# Train_loss 0.55154819, Test loss : 0.53027979, Epoch 9
# Train_loss 0.55148616, Test loss : 0.53008518, Epoch 10
# Rmse lsoss -> 2.1013891439303944
# Mean absolute error -> 0.7769980430603027
# R2 score -> 80.0
# Training...
# Train_loss 0.56727976, Test loss : 0.56081291, Epoch 1
# Train_loss 0.55198091, Test loss : 0.55594077, Epoch 2
# Train_loss 0.55132975, Test loss : 0.55390130, Epoch 3
# Train_loss 0.55107697, Test loss : 0.55175041, Epoch 4
# Train_loss 0.55097186, Test loss : 0.54929099, Epoch 5
# Train_loss 0.55027726, Test loss : 0.54898034, Epoch 6
# Train_loss 0.55027488, Test loss : 0.54859572, Epoch 7
# Train_loss 0.55025295, Test loss : 0.54827989, Epoch 8
# Train_loss 0.55020477, Test loss : 0.54799032, Epoch 9
# Train_loss 0.55024856, Test loss : 0.54769933, Epoch 10
# Rmse lsoss -> 2.1729701732022715
# Mean absolute error -> 1.1290065050125122
# R2 score -> 60.0
# Training...
# Train_loss 0.57486161, Test loss : 0.53171653, Epoch 1
# Train_loss 0.55299653, Test loss : 0.52639306, Epoch 2
# Train_loss 0.55270732, Test loss : 0.52408733, Epoch 3
# Train_loss 0.55261629, Test loss : 0.52227512, Epoch 4
# Train_loss 0.55249088, Test loss : 0.52017671, Epoch 5
# Train_loss 0.55176983, Test loss : 0.51979732, Epoch 6
# Train_loss 0.55172540, Test loss : 0.51946608, Epoch 7
# Train_loss 0.55171218, Test loss : 0.51918523, Epoch 8
# Train_loss 0.55166037, Test loss : 0.51892890, Epoch 9
# Train_loss 0.55160425, Test loss : 0.51866991, Epoch 10
# Rmse lsoss -> 2.0558876622751106
# Mean absolute error -> 0.8902955651283264
# R2 score -> 68.0
# Training...
# Train_loss 0.58515951, Test loss : 0.54056249, Epoch 1
# Train_loss 0.56181515, Test loss : 0.53382764, Epoch 2
# Train_loss 0.56169740, Test loss : 0.53070579, Epoch 3
# Train_loss 0.56141724, Test loss : 0.52774550, Epoch 4
# Train_loss 0.56136761, Test loss : 0.52495628, Epoch 5
# Train_loss 0.56056047, Test loss : 0.52482438, Epoch 6
# Train_loss 0.56058269, Test loss : 0.52465667, Epoch 7
# Train_loss 0.56057107, Test loss : 0.52443748, Epoch 8
# Train_loss 0.56056342, Test loss : 0.52418038, Epoch 9
# Train_loss 0.56061613, Test loss : 0.52393286, Epoch 10
# Rmse lsoss -> 2.076490863973763
# Mean absolute error -> 0.9076588749885559
# R2 score -> 75.0
# Training...
# Train_loss 0.55628192, Test loss : 0.55228962, Epoch 1
# Train_loss 0.56053735, Test loss : 0.54626995, Epoch 2
# Train_loss 0.55679849, Test loss : 0.54251299, Epoch 3
# Train_loss 0.55645262, Test loss : 0.54117799, Epoch 4
# Train_loss 0.55632427, Test loss : 0.53980588, Epoch 5
# Train_loss 0.55406346, Test loss : 0.53684991, Epoch 6
# Train_loss 0.55337923, Test loss : 0.53440780, Epoch 7
# Train_loss 0.55302750, Test loss : 0.53298487, Epoch 8
# Train_loss 0.55282148, Test loss : 0.53210313, Epoch 9
# Train_loss 0.55278231, Test loss : 0.53151068, Epoch 10
# Rmse lsoss -> 2.1064530090842237
# Mean absolute error -> 0.7081657648086548
# R2 score -> 82.0
# Training...
# Train_loss 0.58407814, Test loss : 0.57109280, Epoch 1
# Train_loss 0.55286435, Test loss : 0.55886634, Epoch 2
# Train_loss 0.55370258, Test loss : 0.55675246, Epoch 3
# Train_loss 0.55327963, Test loss : 0.55472922, Epoch 4
# Train_loss 0.55329510, Test loss : 0.55257384, Epoch 5
# Train_loss 0.55237532, Test loss : 0.55383523, Epoch 6
# Train_loss 0.55205892, Test loss : 0.55486977, Epoch 7
# Train_loss 0.55187859, Test loss : 0.55523472, Epoch 8
# Train_loss 0.55186169, Test loss : 0.55524264, Epoch 9
# Train_loss 0.55183425, Test loss : 0.55507383, Epoch 10
# Rmse lsoss -> 2.199303525439196
# Mean absolute error -> 0.9490072131156921
# R2 score -> 72.0
# Training...
# Train_loss 0.57842491, Test loss : 0.53081090, Epoch 1
# Train_loss 0.55646241, Test loss : 0.51608886, Epoch 2
# Train_loss 0.55374818, Test loss : 0.51367353, Epoch 3
# Train_loss 0.55361308, Test loss : 0.51093868, Epoch 4
# Train_loss 0.55380048, Test loss : 0.50852186, Epoch 5
# Train_loss 0.55128555, Test loss : 0.50833968, Epoch 6
# Train_loss 0.55127379, Test loss : 0.50807350, Epoch 7
# Train_loss 0.55118710, Test loss : 0.50779331, Epoch 8
# Train_loss 0.55129485, Test loss : 0.50749980, Epoch 9
# Train_loss 0.55112594, Test loss : 0.50718606, Epoch 10
# Rmse lsoss -> 2.0101397493280446
# Mean absolute error -> 0.7392325401306152
# R2 score -> 79.0
# Training...
# Train_loss 0.58286778, Test loss : 0.51699794, Epoch 1
# Train_loss 0.56413497, Test loss : 0.50945120, Epoch 2
# Train_loss 0.56141346, Test loss : 0.50696434, Epoch 3
# Train_loss 0.56169450, Test loss : 0.50476439, Epoch 4
# Train_loss 0.56149090, Test loss : 0.50260224, Epoch 5
# Train_loss 0.55957077, Test loss : 0.50151497, Epoch 6
# Train_loss 0.55917493, Test loss : 0.50074177, Epoch 7
# Train_loss 0.55917973, Test loss : 0.50023184, Epoch 8
# Train_loss 0.55906355, Test loss : 0.49982233, Epoch 9
# Train_loss 0.55901391, Test loss : 0.49944097, Epoch 10
# Rmse lsoss -> 1.9801471757616913
# Mean absolute error -> 0.8559834361076355
# R2 score -> 73.0
# Training...
# Train_loss 0.57141026, Test loss : 0.53277750, Epoch 1
# Train_loss 0.55801144, Test loss : 0.53052117, Epoch 2
# Train_loss 0.55733591, Test loss : 0.52805749, Epoch 3
# Train_loss 0.55741817, Test loss : 0.52542267, Epoch 4
# Train_loss 0.55730432, Test loss : 0.52297050, Epoch 5
# Train_loss 0.55625719, Test loss : 0.52279718, Epoch 6
# Train_loss 0.55628434, Test loss : 0.52253956, Epoch 7
# Train_loss 0.55622675, Test loss : 0.52224182, Epoch 8
# Train_loss 0.55626856, Test loss : 0.52197811, Epoch 9
# Train_loss 0.55623771, Test loss : 0.52167390, Epoch 10
# Rmse lsoss -> 2.0689195085211165
# Mean absolute error -> 0.8261390924453735
# R2 score -> 75.0
# Training...
# Train_loss 0.57621607, Test loss : 0.55995812, Epoch 1
# Train_loss 0.54106424, Test loss : 0.55187928, Epoch 2
# Train_loss 0.54190026, Test loss : 0.54912524, Epoch 3
# Train_loss 0.54170728, Test loss : 0.54662099, Epoch 4
# Train_loss 0.54156672, Test loss : 0.54440745, Epoch 5
# Train_loss 0.54076095, Test loss : 0.54442880, Epoch 6
# Train_loss 0.54053640, Test loss : 0.54441003, Epoch 7
# Train_loss 0.54048268, Test loss : 0.54425276, Epoch 8
# Train_loss 0.54047445, Test loss : 0.54403352, Epoch 9
# Train_loss 0.54046304, Test loss : 0.54379185, Epoch 10
# Rmse lsoss -> 2.1561287002721916
# Mean absolute error -> 1.2961097955703735
# R2 score -> 44.0
# Training...
# Train_loss 0.57647261, Test loss : 0.54169793, Epoch 1
# Train_loss 0.55417443, Test loss : 0.53797560, Epoch 2
# Train_loss 0.55288400, Test loss : 0.53521480, Epoch 3
# Train_loss 0.55291729, Test loss : 0.53246726, Epoch 4
# Train_loss 0.55291263, Test loss : 0.53026085, Epoch 5
# Train_loss 0.55151730, Test loss : 0.53036872, Epoch 6
# Train_loss 0.55154474, Test loss : 0.53029350, Epoch 7
# Train_loss 0.55151423, Test loss : 0.53011889, Epoch 8
# Train_loss 0.55152922, Test loss : 0.52992940, Epoch 9
# Train_loss 0.55152521, Test loss : 0.52971281, Epoch 10
# Rmse lsoss -> 2.099365220179127
# Mean absolute error -> 0.7907118201255798
# R2 score -> 79.0
# Training...
# Train_loss 0.56688591, Test loss : 0.55941214, Epoch 1
# Train_loss 0.55171441, Test loss : 0.55467901, Epoch 2
# Train_loss 0.55123489, Test loss : 0.55181182, Epoch 3
# Train_loss 0.55093999, Test loss : 0.54925813, Epoch 4
# Train_loss 0.55088306, Test loss : 0.54648644, Epoch 5
# Train_loss 0.55024769, Test loss : 0.54620001, Epoch 6
# Train_loss 0.55017687, Test loss : 0.54581594, Epoch 7
# Train_loss 0.55023660, Test loss : 0.54551831, Epoch 8
# Train_loss 0.55023663, Test loss : 0.54527629, Epoch 9
# Train_loss 0.55008885, Test loss : 0.54500549, Epoch 10
# Rmse lsoss -> 2.161639457988262
# Mean absolute error -> 1.0937131643295288
# R2 score -> 61.0
# Training...
# Train_loss 0.57978031, Test loss : 0.53228950, Epoch 1
# Train_loss 0.55310319, Test loss : 0.52530715, Epoch 2
# Train_loss 0.55274010, Test loss : 0.52218903, Epoch 3
# Train_loss 0.55254836, Test loss : 0.51988240, Epoch 4
# Train_loss 0.55260155, Test loss : 0.51800315, Epoch 5
# Train_loss 0.55175998, Test loss : 0.51765433, Epoch 6
# Train_loss 0.55167416, Test loss : 0.51737609, Epoch 7
# Train_loss 0.55164853, Test loss : 0.51713840, Epoch 8
# Train_loss 0.55160942, Test loss : 0.51691887, Epoch 9
# Train_loss 0.55169104, Test loss : 0.51669651, Epoch 10
# Rmse lsoss -> 2.047898131474555
# Mean absolute error -> 1.0125584602355957
# R2 score -> 61.0
# Training...
# Train_loss 0.57862836, Test loss : 0.53901481, Epoch 1
# Train_loss 0.56165374, Test loss : 0.53375489, Epoch 2
# Train_loss 0.56160783, Test loss : 0.53178642, Epoch 3
# Train_loss 0.56145994, Test loss : 0.52971118, Epoch 4
# Train_loss 0.56141835, Test loss : 0.52752148, Epoch 5
# Train_loss 0.56075072, Test loss : 0.52745388, Epoch 6
# Train_loss 0.56064070, Test loss : 0.52733397, Epoch 7
# Train_loss 0.56063058, Test loss : 0.52715541, Epoch 8
# Train_loss 0.56060766, Test loss : 0.52694814, Epoch 9
# Train_loss 0.56064843, Test loss : 0.52673418, Epoch 10
# Rmse lsoss -> 2.0878387815856536
# Mean absolute error -> 0.8266052007675171
# R2 score -> 75.0
# Training...
# Train_loss 0.56667206, Test loss : 0.56233486, Epoch 1
# Train_loss 0.56115459, Test loss : 0.54162021, Epoch 2
# Train_loss 0.55573236, Test loss : 0.54190038, Epoch 3
# Train_loss 0.55637248, Test loss : 0.53914896, Epoch 4
# Train_loss 0.55610562, Test loss : 0.53731439, Epoch 5
# Train_loss 0.55393379, Test loss : 0.53432790, Epoch 6
# Train_loss 0.55320303, Test loss : 0.53188015, Epoch 7
# Train_loss 0.55298878, Test loss : 0.53042407, Epoch 8
# Train_loss 0.55277855, Test loss : 0.52952326, Epoch 9
# Train_loss 0.55266617, Test loss : 0.52889526, Epoch 10
# Rmse lsoss -> 2.09762556170813
# Mean absolute error -> 0.7059040069580078
# R2 score -> 81.0
# Training...
# Train_loss 0.59302864, Test loss : 0.57380651, Epoch 1
# Train_loss 0.55296015, Test loss : 0.55938451, Epoch 2
# Train_loss 0.55394500, Test loss : 0.55792917, Epoch 3
# Train_loss 0.55341559, Test loss : 0.55649048, Epoch 4
# Train_loss 0.55337695, Test loss : 0.55447136, Epoch 5
# Train_loss 0.55250141, Test loss : 0.55582524, Epoch 6
# Train_loss 0.55212846, Test loss : 0.55688177, Epoch 7
# Train_loss 0.55199283, Test loss : 0.55727875, Epoch 8
# Train_loss 0.55196657, Test loss : 0.55727880, Epoch 9
# Train_loss 0.55195062, Test loss : 0.55715437, Epoch 10
# Rmse lsoss -> 2.2092954111399594
# Mean absolute error -> 0.7562032341957092
# R2 score -> 82.0
# Training...
# Train_loss 0.56722511, Test loss : 0.52587834, Epoch 1
# Train_loss 0.55563532, Test loss : 0.51368525, Epoch 2
# Train_loss 0.55403682, Test loss : 0.50858647, Epoch 3
# Train_loss 0.55362107, Test loss : 0.50371853, Epoch 4
# Train_loss 0.55365721, Test loss : 0.49993798, Epoch 5
# Train_loss 0.55115958, Test loss : 0.49961209, Epoch 6
# Train_loss 0.55110511, Test loss : 0.49925036, Epoch 7
# Train_loss 0.55114607, Test loss : 0.49892737, Epoch 8
# Train_loss 0.55117628, Test loss : 0.49861261, Epoch 9
# Train_loss 0.55117976, Test loss : 0.49831766, Epoch 10
# Rmse lsoss -> 1.994887134734286
# Mean absolute error -> 0.8669734597206116
# R2 score -> 72.0
# Training...
# Train_loss 0.57776899, Test loss : 0.51713909, Epoch 1
# Train_loss 0.56334183, Test loss : 0.50690693, Epoch 2
# Train_loss 0.56095347, Test loss : 0.50265069, Epoch 3
# Train_loss 0.56112831, Test loss : 0.49826033, Epoch 4
# Train_loss 0.56093872, Test loss : 0.49436047, Epoch 5
# Train_loss 0.55927830, Test loss : 0.49364588, Epoch 6
# Train_loss 0.55895078, Test loss : 0.49311105, Epoch 7
# Train_loss 0.55887205, Test loss : 0.49268554, Epoch 8
# Train_loss 0.55873000, Test loss : 0.49225964, Epoch 9
# Train_loss 0.55873227, Test loss : 0.49185109, Epoch 10
# Rmse lsoss -> 1.9816002256432574
# Mean absolute error -> 0.8616598844528198
# R2 score -> 57.99999999999999
# Training...
# Train_loss 0.59204068, Test loss : 0.53180668, Epoch 1
# Train_loss 0.55885496, Test loss : 0.52855250, Epoch 2
# Train_loss 0.55815754, Test loss : 0.52465184, Epoch 3
# Train_loss 0.55836918, Test loss : 0.52175054, Epoch 4
# Train_loss 0.55831051, Test loss : 0.52004873, Epoch 5
# Train_loss 0.55710515, Test loss : 0.52012087, Epoch 6
# Train_loss 0.55705122, Test loss : 0.51997915, Epoch 7
# Train_loss 0.55702684, Test loss : 0.51986807, Epoch 8
# Train_loss 0.55692882, Test loss : 0.51973198, Epoch 9
# Train_loss 0.55707222, Test loss : 0.51962973, Epoch 10
# Rmse lsoss -> 2.0819676945989722
# Mean absolute error -> 0.8627156615257263
# R2 score -> 75.0
# Training...
# Train_loss 0.58775241, Test loss : 0.55215766, Epoch 1
# Train_loss 0.54148703, Test loss : 0.54316897, Epoch 2
# Train_loss 0.54207008, Test loss : 0.54036315, Epoch 3
# Train_loss 0.54167976, Test loss : 0.53776604, Epoch 4
# Train_loss 0.54161367, Test loss : 0.53577552, Epoch 5
# Train_loss 0.54096610, Test loss : 0.53557954, Epoch 6
# Train_loss 0.54085611, Test loss : 0.53545330, Epoch 7
# Train_loss 0.54088348, Test loss : 0.53532084, Epoch 8
# Train_loss 0.54079074, Test loss : 0.53517438, Epoch 9
# Train_loss 0.54078734, Test loss : 0.53504494, Epoch 10
# Rmse lsoss -> 2.1388621624464417
# Mean absolute error -> 1.017928957939148
# R2 score -> 63.0
# Training...
# Train_loss 0.57787620, Test loss : 0.53501896, Epoch 1
# Train_loss 0.55411971, Test loss : 0.53315321, Epoch 2
# Train_loss 0.55318167, Test loss : 0.52985614, Epoch 3
# Train_loss 0.55322873, Test loss : 0.52689320, Epoch 4
# Train_loss 0.55318522, Test loss : 0.52475973, Epoch 5
# Train_loss 0.55181247, Test loss : 0.52499159, Epoch 6
# Train_loss 0.55181746, Test loss : 0.52495790, Epoch 7
# Train_loss 0.55181526, Test loss : 0.52485377, Epoch 8
# Train_loss 0.55181553, Test loss : 0.52468868, Epoch 9
# Train_loss 0.55180468, Test loss : 0.52452047, Epoch 10
# Rmse lsoss -> 2.111958144177765
# Mean absolute error -> 0.9672041535377502
# R2 score -> 55.00000000000001
# Training...
# Train_loss 0.57883433, Test loss : 0.56571821, Epoch 1
# Train_loss 0.55284361, Test loss : 0.55051638, Epoch 2
# Train_loss 0.55113601, Test loss : 0.54554606, Epoch 3
# Train_loss 0.55098977, Test loss : 0.54107834, Epoch 4
# Train_loss 0.55104715, Test loss : 0.53823845, Epoch 5
# Train_loss 0.55037151, Test loss : 0.53806348, Epoch 6
# Train_loss 0.55035069, Test loss : 0.53784016, Epoch 7
# Train_loss 0.55028217, Test loss : 0.53765545, Epoch 8
# Train_loss 0.55036936, Test loss : 0.53751161, Epoch 9
# Train_loss 0.55036832, Test loss : 0.53739960, Epoch 10
# Rmse lsoss -> 2.142357118487094
# Mean absolute error -> 1.0767399072647095
# R2 score -> 64.0
# Training...
# Train_loss 0.61048242, Test loss : 0.52807219, Epoch 1
# Train_loss 0.55429422, Test loss : 0.51808562, Epoch 2
# Train_loss 0.55293275, Test loss : 0.51491475, Epoch 3
# Train_loss 0.55284416, Test loss : 0.51246740, Epoch 4
# Train_loss 0.55291163, Test loss : 0.51066428, Epoch 5
# Train_loss 0.55205003, Test loss : 0.51056938, Epoch 6
# Train_loss 0.55207943, Test loss : 0.51047242, Epoch 7
# Train_loss 0.55207055, Test loss : 0.51036694, Epoch 8
# Train_loss 0.55204260, Test loss : 0.51025271, Epoch 9
# Train_loss 0.55205315, Test loss : 0.51009910, Epoch 10
# Rmse lsoss -> 2.039325331779579
# Mean absolute error -> 0.9803518652915955
# R2 score -> 67.0
# Training...
# Train_loss 0.58212804, Test loss : 0.53599288, Epoch 1
# Train_loss 0.56231419, Test loss : 0.52834925, Epoch 2
# Train_loss 0.56209972, Test loss : 0.52426657, Epoch 3
# Train_loss 0.56200188, Test loss : 0.52071667, Epoch 4
# Train_loss 0.56197954, Test loss : 0.51822794, Epoch 5
# Train_loss 0.56124040, Test loss : 0.51804210, Epoch 6
# Train_loss 0.56127341, Test loss : 0.51790093, Epoch 7
# Train_loss 0.56123817, Test loss : 0.51774053, Epoch 8
# Train_loss 0.56123619, Test loss : 0.51755869, Epoch 9
# Train_loss 0.56119218, Test loss : 0.51740196, Epoch 10
# Rmse lsoss -> 2.055248575514242
# Mean absolute error -> 1.3082436323165894
# R2 score -> 45.0
# Training...
# Train_loss 0.56085736, Test loss : 0.55400428, Epoch 1
# Train_loss 0.56051855, Test loss : 0.53385595, Epoch 2
# Train_loss 0.55557861, Test loss : 0.53166051, Epoch 3
# Train_loss 0.55617292, Test loss : 0.52686859, Epoch 4
# Train_loss 0.55582641, Test loss : 0.52338819, Epoch 5
# Train_loss 0.55389331, Test loss : 0.52115020, Epoch 6
# Train_loss 0.55329181, Test loss : 0.51926897, Epoch 7
# Train_loss 0.55294238, Test loss : 0.51809494, Epoch 8
# Train_loss 0.55282196, Test loss : 0.51729498, Epoch 9
# Train_loss 0.55276296, Test loss : 0.51670692, Epoch 10
# Rmse lsoss -> 2.048565115834368
# Mean absolute error -> 1.3245956897735596
# R2 score -> 47.0
# Training...
# Train_loss 0.57874302, Test loss : 0.56961485, Epoch 1
# Train_loss 0.55284498, Test loss : 0.55673624, Epoch 2
# Train_loss 0.55360221, Test loss : 0.55297755, Epoch 3
# Train_loss 0.55334456, Test loss : 0.54993989, Epoch 4
# Train_loss 0.55324962, Test loss : 0.54716386, Epoch 5
# Train_loss 0.55241912, Test loss : 0.54811895, Epoch 6
# Train_loss 0.55207961, Test loss : 0.54890479, Epoch 7
# Train_loss 0.55197208, Test loss : 0.54919481, Epoch 8
# Train_loss 0.55196532, Test loss : 0.54918374, Epoch 9
# Train_loss 0.55189513, Test loss : 0.54907058, Epoch 10
# Rmse lsoss -> 2.1756604912768958
# Mean absolute error -> 1.0304049253463745
# R2 score -> 61.0

# %%
print([item[-1] for item in matrix_cv_base])
print([item[-3] for item in matrix_cv_base])
# Out:
# [0.60488707, 0.93997604, 0.9888381, 0.9965336, 0.77699804, 1.1290065, 0.89029557, 0.9076589, 0.70816576, 0.9490072]
# [2.0203492151687317, 1.985661127411986, 2.0717905202820144, 2.1419488753086604, 2.1013891439303944, 2.1729701732022715, 2.0558876622751106, 2.076490863973763, 2.1064530090842237, 2.199303525439196]

# %%
print([item[-1] for item in matrix_cv_noise])
print([item[-3] for item in matrix_cv_noise])
# Out:
# [0.73923254, 0.85598344, 0.8261391, 1.2961098, 0.7907118, 1.0937132, 1.0125585, 0.8266052, 0.705904, 0.75620323]
# [2.0101397493280446, 1.9801471757616913, 2.0689195085211165, 2.1561287002721916, 2.099365220179127, 2.161639457988262, 2.047898131474555, 2.0878387815856536, 2.09762556170813, 2.2092954111399594]

# %%
print([item[-1] for item in matrix_cv_low_demand])
print([item[-3] for item in matrix_cv_low_demand])
# Out:
# [0.86697346, 0.8616599, 0.86271566, 1.017929, 0.96720415, 1.0767399, 0.98035187, 1.3082436, 1.3245957, 1.0304049]
# [1.994887134734286, 1.9816002256432574, 2.0819676945989722, 2.1388621624464417, 2.111958144177765, 2.142357118487094, 2.039325331779579, 2.055248575514242, 2.048565115834368, 2.1756604912768958]

# %%
print(np.average([item[-2] for item in matrix_cv_base]))
print(np.average([item[-2] for item in matrix_cv_noise]))
print(np.average([item[-2] for item in matrix_cv_low_demand]))
# Out:
# 72.9
# 71.0
# 60.7

# %%
matrix_cv_base_MAE = [item[-1] for item in matrix_cv_base]
matrix_cv_noise_MAE = [item[-1] for item in matrix_cv_noise]
matrix_cv_low_demand_MAE = [item[-1] for item in matrix_cv_low_demand]

# %%
print([item[-2] for item in matrix_cv_base])
print([item[-2] for item in matrix_cv_noise])
print([item[-2] for item in matrix_cv_low_demand])
# Out:
# [89.0, 68.0, 65.0, 70.0, 80.0, 60.0, 68.0, 75.0, 82.0, 72.0]
# [79.0, 73.0, 75.0, 44.0, 79.0, 61.0, 61.0, 75.0, 81.0, 82.0]
# [72.0, 57.99999999999999, 75.0, 63.0, 55.00000000000001, 64.0, 67.0, 45.0, 47.0, 61.0]

# %%
print(stats.ttest_ind([item[-2] for item in matrix_cv_base], [item[-2] for item in matrix_cv_noise]))
print(stats.ttest_ind([item[-2] for item in matrix_cv_base], [item[-2] for item in matrix_cv_low_demand]))
print(stats.ttest_ind([item[-2] for item in matrix_cv_noise], [item[-2] for item in matrix_cv_low_demand]))
# Out:
# Ttest_indResult(statistic=0.4033635932902331, pvalue=0.6914319414493316)
# Ttest_indResult(statistic=2.9445358313554153, pvalue=0.008668690071869585)
# Ttest_indResult(statistic=2.0946866022788373, pvalue=0.05061428304242321)

# %% [markdown]
#  * Summery

# %%
summery.update({ city_name: {
    "base_model": {
        "skill_score": base_model_skill,
        "MAE_score": base_model_MAE_score,
        "RMSE_score": base_model_RSME_score,
        "R2_score": base_model_R2_score
    },
    "noise_model": {
        "skill_score": noise_model_skill,
        "MAE_score": noise_model_MAE_score,
        "RMSE_score": noise_model_RSME_score,
        "R2_score": noise_model_R2_score
    },
    "low_demand_model": {
        "skill_score": low_demand_model_skill,
        "MAE_score": low_demand_model_MAE_score,
        "RMSE_score": low_demand_model_RSME_score,
        "R2_score": low_demand_model_R2_score
    }
}})
localStorage.save_to_pkl(summery)

# %% [markdown]
# - KNN, hypothesis

# %% [markdown]
# - Write about the hypothesis

# %% [markdown]
# ## Hypothesis -
#
#     * Apply KNN on the data, and see different ponts in a graph, Find similar ponts(similarity methos) and compare their evaluation and fix the data.
#     * For example, if some points falls within the same cluster and differ by their demand then their might be somw issue, in the training data
#     * Also, write about how difficlut it would be to find the similar points, as time series data works differently compare to the normal data set
